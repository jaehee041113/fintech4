# %% [markdown]
# # 상장 기업 공시 정보 수집하기
# [https://kind.krx.co.kr/corpgeneral/corpList.do?method=loadInitPage](https://kind.krx.co.kr/corpgeneral/corpList.do?method=loadInitPage)

# %%
import os
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from myfunc import text_clean

# %%
# 페이지 내부의 기업 데이터 없이 페이지 껍데기만 있는 주소
url= "https://kind.krx.co.kr/corpgeneral/corpList.do?method=loadInitPage"
r=requests.get(url) # 페이지 수집 -> 안의 내용X, 껍데기 메뉴들만 가지고 옴
print(r.status_code)
soup=bs(r.content, 'lxml')
#soup
# Out:
# 200

# %%
# 페이지 내부의 기업 데이터까지 다 나오는 html 파일 잘 가지고 옴
url="https://kind.krx.co.kr/corpgeneral/corpList.do"
payload=dict(method="searchCorpList",pageIndex=1,currentPageSize=15,orderMode=3,orderStat="D",searchType=13,fiscalYearEnd="all",location="all")
r=requests.get(url, params=payload)
print(r.url)
print(r.status_code)
soup=bs(r.content, 'lxml')
soup
# Out:
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=1&currentPageSize=15&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# <html><body><section class="scrarea type-00">
# <table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# <caption>목록</caption>
# <colgroup>
# <col width="*"/>
# <col width="15%"/>
# <col width="20%"/>
# <col width="11%"/>
# <col width="8%"/>
# <col width="10%"/>
# <col width="8%"/>
# <col width="12%"/>
# </colgroup>
# <thead>
# <tr class="first" id="title-contents">
# </tr>
# </thead>
# <tbody>
# <tr class="first">
# <td class="first" title="삼성기업인수목적13호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0115H'); return false;" title="삼성스팩13호"> 삼성스팩13호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2026-01-21</td>
# <td class="txc">12월</td>
# <td class="txc" title="성상환">성상환</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)엔비알모션"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0004V'); return false;" title="엔비알모션"> 엔비알모션</a> </td>
# <td class="textOverflow" title="기타 금속 가공제품 제조업">기타 금속 가공제품 제조업</td>
# <td class="textOverflow" title="강구 및 테이퍼롤러">강구 및 테이퍼롤러</td>
# <td class="txc">2026-01-14</td>
# <td class="txc">12월</td>
# <td class="txc" title="문두성">문두성</td>
# <td class="txc">
# </td>
# <td class="txc">경상남도</td>
# </tr>
# <tr>
# <td class="first" title="(주)지에프아이"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('49333'); return false;" title="지에프아이"> 지에프아이</a> </td>
# <td class="textOverflow" title="일반 목적용 기계 제조업">일반 목적용 기계 제조업</td>
# <td class="textOverflow" title="2차전지소화안전제품, 일반소화안전제품">2차전지소화안전제품, 일반소화안전제품</td>
# <td class="txc">2026-01-14</td>
# <td class="txc">12월</td>
# <td class="txc" title="이상섭">이상섭</td>
# <td class="txc">
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="삼미금속(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('01221'); return false;" title="삼미금속"> 삼미금속</a> </td>
# <td class="textOverflow" title="기타 금속 가공제품 제조업">기타 금속 가공제품 제조업</td>
# <td class="textOverflow" title="자동차부품, 중장비부품, 선박부품, 방산부품 등">자동차부품, 중장비부품, 선박부품, 방산부품 등</td>
# <td class="txc">2025-12-29</td>
# <td class="txc">12월</td>
# <td class="txc" title="이남영">이남영</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.sammimetal.com" target="_blank" title="http://www.sammimetal.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경상남도</td>
# </tr>
# <tr>
# <td class="first" title="(주)세미파이브"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('49047'); return false;" title="세미파이브"> 세미파이브</a> </td>
# <td class="textOverflow" title="건축기술, 엔지니어링 및 관련 기술 서비스업">건축기술, 엔지니어링 및 관련 기술 서비스업</td>
# <td class="textOverflow" title="반도체 설계 서비스">반도체 설계 서비스</td>
# <td class="txc">2025-12-29</td>
# <td class="txc">12월</td>
# <td class="txc" title="조명현">조명현</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://semifive.com" target="_blank" title="http://semifive.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)리브스메드"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('49100'); return false;" title="리브스메드"> 리브스메드</a> </td>
# <td class="textOverflow" title="의료용 기기 제조업">의료용 기기 제조업</td>
# <td class="textOverflow" title="다관절 다자유도 복강경 수술기구인 ArtiSential, ArtiSeal, ArtiStapler, LivsCam, Stark">다관절 다자유도 복강경 수술기구인 ArtiSential, ArtiSeal, ArtiStapler, LivsCam, Stark</td>
# <td class="txc">2025-12-24</td>
# <td class="txc">12월</td>
# <td class="txc" title="이정주">이정주</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.livsmed.com" target="_blank" title="http://www.livsmed.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="미래에셋비전기업인수목적10호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0097F'); return false;" title="미래에셋비전스팩10호"> 미래에셋비전스팩10호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2025-12-23</td>
# <td class="txc">12월</td>
# <td class="txc" title="윤태원">윤태원</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="미래에셋비전기업인수목적11호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0099W'); return false;" title="미래에셋비전스팩11호"> 미래에셋비전스팩11호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2025-12-22</td>
# <td class="txc">12월</td>
# <td class="txc" title="김양태">김양태</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="삼진식품(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0013V'); return false;" title="삼진식품"> 삼진식품</a> </td>
# <td class="textOverflow" title="수산물 가공 및 저장 처리업">수산물 가공 및 저장 처리업</td>
# <td class="textOverflow" title="반찬용 어묵, 국탕용 어묵 등 어묵관련 제품 판매">반찬용 어묵, 국탕용 어묵 등 어묵관련 제품 판매</td>
# <td class="txc">2025-12-22</td>
# <td class="txc">12월</td>
# <td class="txc" title="박용준">박용준</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://samjinfood.com" target="_blank" title="http://samjinfood.com"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">부산광역시</td>
# </tr>
# <tr>
# <td class="first" title="엔더블유시(주)"><img alt="코넥스" class="vmiddle legend" src="/images/common/icn_t_konex.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('05918'); return false;" title="엔더블유시"> 엔더블유시</a> </td>
# <td class="textOverflow" title="통신 및 방송 장비 제조업">통신 및 방송 장비 제조업</td>
# <td class="textOverflow" title="FTTH Drop, FTTH 커넥터류, 5G CPRI, MDU, 광접속함체">FTTH Drop, FTTH 커넥터류, 5G CPRI, MDU, 광접속함체</td>
# <td class="txc">2025-12-22</td>
# <td class="txc">12월</td>
# <td class="txc" title="김희중">김희중</td>
# <td class="txc">
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="하나36호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0101C'); return false;" title="하나36호스팩"> 하나36호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수합병">기업인수합병</td>
# <td class="txc">2025-12-22</td>
# <td class="txc">12월</td>
# <td class="txc" title="박병기">박병기</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="아이비케이에스제25호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0099X'); return false;" title="IBKS제25호스팩"> IBKS제25호스팩</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="기업인수 및 합병">기업인수 및 합병</td>
# <td class="txc">2025-12-19</td>
# <td class="txc">12월</td>
# <td class="txc" title="심기섭">심기섭</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="알지노믹스(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47683'); return false;" title="알지노믹스"> 알지노믹스</a> </td>
# <td class="textOverflow" title="자연과학 및 공학 연구개발업">자연과학 및 공학 연구개발업</td>
# <td class="textOverflow" title="인체질환치료제 및 진단제, 진단용 유전자재조합 의약품">인체질환치료제 및 진단제, 진단용 유전자재조합 의약품</td>
# <td class="txc">2025-12-18</td>
# <td class="txc">12월</td>
# <td class="txc" title="이성욱">이성욱</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.rznomics.com/" target="_blank" title="http://www.rznomics.com/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">경기도</td>
# </tr>
# <tr>
# <td class="first" title="(주)나라스페이스테크놀로지"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47834'); return false;" title="나라스페이스테크놀로지"> 나라스페이스테크놀로지</a> </td>
# <td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# <td class="textOverflow" title="초소형 인공위성 및 위성 데이터 서비스">초소형 인공위성 및 위성 데이터 서비스</td>
# <td class="txc">2025-12-17</td>
# <td class="txc">12월</td>
# <td class="txc" title="박재필">박재필</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# <tr>
# <td class="first" title="(주)아크릴"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('0007C'); return false;" title="아크릴"> 아크릴</a> </td>
# <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# <td class="textOverflow" title="통합 인공지능 플랫폼 조나단, 의료특화 인공지능 플랫폼 나디아">통합 인공지능 플랫폼 조나단, 의료특화 인공지능 플랫폼 나디아</td>
# <td class="txc">2025-12-16</td>
# <td class="txc">12월</td>
# <td class="txc" title="박외진">박외진</td>
# <td class="txc">
# <a class="btn ico homepage" href="http://www.acryl.ai/" target="_blank" title="http://www.acryl.ai/"><span>홈페이지 보기</span></a>
# </td>
# <td class="txc">서울특별시</td>
# </tr>
# </tbody>
# </table>
# </section>
# <!-- 페이징 START -->
# <section class="paging-group">
# <div class="paging type-00"><a class="pprev" href="#prevPage10" onclick="return false;"><span>이전10개 페이지</span></a><a class="prev" href="#prevPage" onclick="return false;"><span>이전 페이지</span></a>
# <a class="active" href="#page_link_1" onclick="return false;">1</a><a href="#page_link_2" onclick="fnPageGo('2');return false;">2</a><a href="#page_link_3" onclick="fnPageGo('3');return false;">3</a><a href="#page_link_4" onclick="fnPageGo('4');return false;">4</a><a href="#page_link_5" onclick="fnPageGo('5');return false;">5</a><a href="#page_link_6" onclick="fnPageGo('6');return false;">6</a><a href="#page_link_7" onclick="fnPageGo('7');return false;">7</a><a href="#page_link_8" onclick="fnPageGo('8');return false;">8</a><a href="#page_link_9" onclick="fnPageGo('9');return false;">9</a><a href="#page_link_10" onclick="fnPageGo('10');return false;">10</a>
# <a class="next" href="#nextPage" onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a class="nnext" href="#nextPage10" onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,775</em>건 : <strong>1</strong>/185
# <select id="currentPageSize" name="currentPageSize">
# <option selected="selected" value="15">15건</option>
# <option value="30">30건</option>
# <option value="50">50건</option>
# <option value="100">100건</option>
# </select>  <a class="btn-sprite btn-go vmiddle" href="#" onclick="fnSearch1();return false;" title="GO"><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script></body></html>

# %%
# 컬럼명 수집 (나중에 딕셔너리 만들 때 키로 사용)

col_names=soup.select_one("table.list.type-00,tmt30")["summary"].split(", ")
col_names
# Out:
# ['회사명', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역']

# %%
result={}

for row in soup.select("table.list.type-00.tmt30 tbody tr"):
    for key, tds in zip(col_names, row.select("td")):
        #print(tds.get_text(strip=True))
        result.setdefault(key, []).append(tds.get_text(strip=True))
        
df=pd.DataFrame(result)
df
# Out:
#          회사명                   업종  \
# 0     NH투자증권           금융 지원 서비스업
# 1     미래에셋증권           금융 지원 서비스업
# 2       신일전자     기계장비 및 관련 물품 도매업
# 3       삼성제약              의약품 제조업
# 4   삼성화재해상보험                  보험업
# ..       ...                  ...
# 70      유한양행              의약품 제조업
# 71    CJ대한통운            도로 화물 운송업
# 72        경방               종합 소매업
# 73     유수홀딩스  회사 본부 및 경영 컨설팅 서비스업
# 74  한진중공업홀딩스    연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                            증권업,종합금융  1975-09-30  12월    윤병운
# 1                              유가증권매매,유가증권위탁매매,유가증권인수  1975-09-30  12월  김미섭..
# 2               가정용 전기기구(선풍기,난로,세탁기),전자기구,연구기구 제조,수출입  1975-09-30  12월    정윤석
# 3                 의약품(까스명수,쓸기담,에프킬라에어졸,액체우황청심원) 제조,도매  1975-07-04  12월  정성택..
# 4                             손해보험의 원수,재보험,운용자산의 투자활동  1975-06-30  12월    이문화
# ..                                                ...         ...  ...    ...
# 70  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 71  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 72          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 73                                               지주사업  1956-03-03  12월    송영규
# 74                                               지주회사  1956-03-03  12월    조원국
#
#        홈페이지     지역
# 0   홈페이지 보기  서울특별시
# 1   홈페이지 보기  서울특별시
# 2   홈페이지 보기   충청남도
# 3   홈페이지 보기    경기도
# 4   홈페이지 보기  서울특별시
# ..      ...    ...
# 70  홈페이지 보기  서울특별시
# 71  홈페이지 보기  서울특별시
# 72  홈페이지 보기  서울특별시
# 73  홈페이지 보기  서울특별시
# 74  홈페이지 보기    경기도
#
# [75 rows x 8 columns]

# %%
# 한 페이지 데이터 수집

all_result = []
for row in soup.select("table.list.type-00.tmt30 tbody tr"):
    result = {}
    for idx , (key, tds) in enumerate(zip(col_names, row.select("td"))):
#         print(tds.get_text(strip=True))
        
        if idx == 0:
            market = tds.select_one("img")['alt']
            code = tds.select_one("a")["onclick"].split("'")[1]+"0"
            company_name = tds.get_text(strip=True)
            result['종류'] = market
            result['종목코드'] = code
            result['회사명'] = company_name
#             print(market, code, company_name)
        elif key == '홈페이지':
            if tds.select_one("a") != None:
                result.setdefault(key, tds.select_one("a")['href'])
            else:
                result[key] = ""
        else:
            result.setdefault(key, tds.get_text(strip=True))
#     print(result)
    all_result.append(result)  

df = pd.DataFrame(all_result)
df
# Out:
#       종류    종목코드       회사명                   업종  \
# 0   유가증권  005940    NH투자증권           금융 지원 서비스업
# 1   유가증권  006800    미래에셋증권           금융 지원 서비스업
# 2   유가증권  002700      신일전자     기계장비 및 관련 물품 도매업
# 3   유가증권  001360      삼성제약              의약품 제조업
# 4   유가증권  000810  삼성화재해상보험                  보험업
# ..   ...     ...       ...                  ...
# 70  유가증권  000100      유한양행              의약품 제조업
# 71  유가증권  000120    CJ대한통운            도로 화물 운송업
# 72  유가증권  000050        경방               종합 소매업
# 73  유가증권  000700     유수홀딩스  회사 본부 및 경영 컨설팅 서비스업
# 74  유가증권  003480  한진중공업홀딩스    연료용 가스 제조 및 배관공급업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                            증권업,종합금융  1975-09-30  12월    윤병운
# 1                              유가증권매매,유가증권위탁매매,유가증권인수  1975-09-30  12월  김미섭..
# 2               가정용 전기기구(선풍기,난로,세탁기),전자기구,연구기구 제조,수출입  1975-09-30  12월    정윤석
# 3                 의약품(까스명수,쓸기담,에프킬라에어졸,액체우황청심원) 제조,도매  1975-07-04  12월  정성택..
# 4                             손해보험의 원수,재보험,운용자산의 투자활동  1975-06-30  12월    이문화
# ..                                                ...         ...  ...    ...
# 70  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월  대표이..
# 71  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월  신영수..
# 72          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월  김준,..
# 73                                               지주사업  1956-03-03  12월    송영규
# 74                                               지주회사  1956-03-03  12월    조원국
#
#                                 홈페이지     지역
# 0                http://www.nhqv.com  서울특별시
# 1   http://securities.miraeasset.com  서울특별시
# 2            http://www.shinil.co.kr   충청남도
# 3           http://www.sspharm.co.kr    경기도
# 4         http://www.samsungfire.com  서울특별시
# ..                               ...    ...
# 70            http://www.yuhan.co.kr  서울특별시
# 71        http://www.cjlogistics.com  서울특별시
# 72        http://www.kyungbang.co.kr  서울특별시
# 73      http://www.eusu-holdings.com  서울특별시
# 74      http://www.hhic-holdings.com    경기도
#
# [75 rows x 10 columns]

# %% [markdown]
# # 전체 데이터 수집하기

# %%
import os
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from myfunc import text_clean

# %%
all_result = []
page = 1
total_pages = 1

while True:
    
    if page > total_pages:
        break
    
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method="searchCorpList", pageIndex=page, currentPageSize=100, 
                   orderMode=3, orderStat="D", searchType=13,
                   fiscalYearEnd="all", location="all")
    r = requests.get(url, params=payload)
    print(r.url)
    print(r.status_code)
    soup = bs(r.content, "lxml")

    # 전체 페이지 구하기
    if total_pages == 1:
        n_items = int(soup.select_one(".info.type-00 em").get_text().replace(",", ""))
        if n_items % 100 == 0:
            total_pages = n_items // 100
        else:
            total_pages = n_items // 100 + 1

    print(f"{page}/{total_pages}   수집중", end="\r")
    
    # 1페이지 데이터 수집 코드    
    for row in soup.select("table.list.type-00.tmt30 tbody tr"):
        result = {}
        for idx , (key, tds) in enumerate(zip(col_names, row.select("td"))):
    #         print(tds.get_text(strip=True))

            if idx == 0:
                market = tds.select_one("img")['alt']
                code = tds.select_one("a")["onclick"].split("'")[1]+"0"
                company_name = tds.get_text(strip=True)
                result['종류'] = market
                result['종목코드'] = code
                result['회사명'] = company_name
    #             print(market, code, company_name)
            elif key == '홈페이지':
                if tds.select_one("a") != None:
                    result.setdefault(key, tds.select_one("a")['href'])
                else:
                    result[key] = ""
            else:
                result.setdefault(key, tds.get_text(strip=True))
    #     print(result)
        all_result.append(result)  

    page += 1
    
    time.sleep(3)
    
df = pd.DataFrame(all_result)
df
# Out:
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=1&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=2&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=3&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=4&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=5&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=6&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=7&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=8&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=9&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=10&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=11&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=12&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=13&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=14&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=15&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=16&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=17&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=18&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=19&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=20&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=21&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=22&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=23&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=24&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=25&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=26&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=27&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# https://kind.krx.co.kr/corpgeneral/corpList.do?method=searchCorpList&pageIndex=28&currentPageSize=100&orderMode=3&orderStat=D&searchType=13&fiscalYearEnd=all&location=all
# 200
# 28/28   수집중
#         종류    종목코드       회사명                        업종  \
# 0      코스닥  0115H0   삼성스팩13호                금융 지원 서비스업
# 1      코스닥  0004V0     엔비알모션            기타 금속 가공제품 제조업
# 2      코스닥  493330     지에프아이             일반 목적용 기계 제조업
# 3      코스닥  012210      삼미금속            기타 금속 가공제품 제조업
# 4      코스닥  490470     세미파이브  건축기술, 엔지니어링 및 관련 기술 서비스업
# ...    ...     ...       ...                       ...
# 2770  유가증권  000100      유한양행                   의약품 제조업
# 2771  유가증권  000120    CJ대한통운                 도로 화물 운송업
# 2772  유가증권  000050        경방                    종합 소매업
# 2773  유가증권  000700     유수홀딩스       회사 본부 및 경영 컨설팅 서비스업
# 2774  유가증권  003480  한진중공업홀딩스         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                                기업인수합병  2026-01-21  12월
# 1                                            강구 및 테이퍼롤러  2026-01-14  12월
# 2                                  2차전지소화안전제품, 일반소화안전제품  2026-01-14  12월
# 3                            자동차부품, 중장비부품, 선박부품, 방산부품 등  2025-12-29  12월
# 4                                            반도체 설계 서비스  2025-12-29  12월
# ...                                                 ...         ...  ...
# 2770  의약품(삐콤씨, 안티푸라민, 렉라자, 로수바미브, 코푸시럽 등), 생활용품(유한락스...  1962-11-01  12월
# 2771  Contract Logistics, 포워딩, 항만하역, 해운, 택배국제특송, SCM...  1956-07-02  12월
# 2772          섬유류(면사,면혼방사,면직물,면혼방직물,화섬사,화섬직물) 제조,도매,수출입  1956-03-03  12월
# 2773                                               지주사업  1956-03-03  12월
# 2774                                               지주회사  1956-03-03  12월
#
#        대표자명                          홈페이지     지역
# 0       성상환                                서울특별시
# 1       문두성                                 경상남도
# 2       이상섭                                  경기도
# 3       이남영     http://www.sammimetal.com   경상남도
# 4       조명현           http://semifive.com    경기도
# ...     ...                           ...    ...
# 2770  대표이..        http://www.yuhan.co.kr  서울특별시
# 2771  신영수..    http://www.cjlogistics.com  서울특별시
# 2772  김준,..    http://www.kyungbang.co.kr  서울특별시
# 2773    송영규  http://www.eusu-holdings.com  서울특별시
# 2774    조원국  http://www.hhic-holdings.com    경기도
#
# [2775 rows x 10 columns]

# %% [markdown]
# # 데이터가 table(표 형식) 태그 안에 있는 경우 쉽게 수집하기
# - 코드 짤 필요 없이 pandas에 read html 쓰면 바로 데이터 프레임으로 바꿔줌
# - 간단하게 할 수 있으면 이거 쓰는 게 편함
# - 보통은 이전 위의 코드처럼 조건 바꿔서 자세히 코딩해야 함.

# %%
df_list = []
for num in range(28):
    url = "https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload = dict(method="searchCorpList", pageIndex=1, currentPageSize=100, 
                   orderMode=3, orderStat="D", searchType=13,
                   fiscalYearEnd="all", location="all")
    r = requests.get(url, params=payload)
    df = pd.read_html(r.text)[0]
    df_list.append(df)
final_df = pd.concat(df_list)
final_df
# Out:
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
# C:\Users\a\AppData\Local\Temp\ipykernel_6448\1826070762.py:8: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_html(r.text)[0]
#    Unnamed: 0                Unnamed: 1  \
# 0     삼성스팩13호                금융 지원 서비스업
# 1       엔비알모션            기타 금속 가공제품 제조업
# 2       지에프아이             일반 목적용 기계 제조업
# 3        삼미금속            기타 금속 가공제품 제조업
# 4       세미파이브  건축기술, 엔지니어링 및 관련 기술 서비스업
# ..        ...                       ...
# 95     우양에이치씨  구조용 금속제품, 탱크 및 증기발생기 제조업
# 96         더즌                    전기 통신업
# 97       심플랫폼            소프트웨어 개발 및 공급업
# 98   티엑스알로보틱스             일반 목적용 기계 제조업
# 99         한텍             일반 목적용 기계 제조업
#
#                                 Unnamed: 2  Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0                                   기업인수합병  2026-01-21        12월        성상환
# 1                               강구 및 테이퍼롤러  2026-01-14        12월        문두성
# 2                     2차전지소화안전제품, 일반소화안전제품  2026-01-14        12월        이상섭
# 3               자동차부품, 중장비부품, 선박부품, 방산부품 등  2025-12-29        12월        이남영
# 4                               반도체 설계 서비스  2025-12-29        12월        조명현
# ..                                     ...         ...        ...        ...
# 95                         화공 플랜트, 에너지 플랜트  2025-03-28        12월        김진태
# 96                   디지털뱅킹 솔루션(B2B 금융 서비스)  2025-03-24        12월        조철한
# 97  NUBISON AIoT(산업용 데이터 수집과 산업용 AI서비스 운영)  2025-03-21        12월      임대근..
# 98                   물류자동화, 로봇자동화, AMR/AGV  2025-03-20        12월        엄인섭
# 99                     열교환기 등 화공기기, 저장용 탱크  2025-03-20        12월        김강식
#
#    Unnamed: 6 Unnamed: 7
# 0         NaN      서울특별시
# 1         NaN       경상남도
# 2         NaN        경기도
# 3     홈페이지 보기       경상남도
# 4     홈페이지 보기        경기도
# ..        ...        ...
# 95    홈페이지 보기        경기도
# 96    홈페이지 보기      서울특별시
# 97    홈페이지 보기      서울특별시
# 98    홈페이지 보기        경기도
# 99    홈페이지 보기      울산광역시
#
# [2800 rows x 8 columns]
