# %% [markdown]
# # sqlalchemy_pymysql로 수집한 데이터 DB에 저장하기_환율정보

# %%
# !pip install sqlalchemy pymysql

# %%
# !pip install cryptography

# %%
import os
import pandas as pd
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
dbid=os.getenv("dbid")
dbpw=os.getenv("dbpw")
dbpw=os.getenv("dbpw")
port=os.getenv("port")

# %%
data=pd.read_csv("./data/상장기업정보.csv")
data
# Out:
#         종류    종목코드       회사명                        업종  \
# 0      코스닥  0115H0   삼성스팩13호                금융 지원 서비스업
# 1      코스닥  0004V0     엔비알모션            기타 금속 가공제품 제조업
# 2      코스닥  493330     지에프아이             일반 목적용 기계 제조업
# 3      코스닥  012210      삼미금속            기타 금속 가공제품 제조업
# 4      코스닥  490470     세미파이브  건축기술, 엔지니어링 및 관련 기술 서비스업
# ...    ...     ...       ...                       ...
# 2768  유가증권  000100      유한양행                   의약품 제조업
# 2769  유가증권  000120    CJ대한통운                 도로 화물 운송업
# 2770  유가증권  000050        경방                    종합 소매업
# 2771  유가증권  000700     유수홀딩스       회사 본부 및 경영 컨설팅 서비스업
# 2772  유가증권  003480  한진중공업홀딩스         연료용 가스 제조 및 배관공급업
#
#                                                    주요제품         상장일  결산월  \
# 0                                                기업인수합병  2026-01-21  12월
# 1                                            강구 및 테이퍼롤러  2026-01-14  12월
# 2                                  2차전지소화안전제품, 일반소화안전제품  2026-01-14  12월
# ...

# %%
# create_engine : 접속 카드 만들기
# mysql이라는 DB에 접속할 거고 + pymysql을 쓸 것이다
engine=create_engine("mysql+pymysql://{dbid}:{dbpw}@{host}:{port}")
conn=engine.connect() 
# engine.connect() : 클릭한 것과 같음
# 열린 SQL쿼리창=conn
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 # create_engine : 접속 카드 만들기
#       2 # mysql이라는 DB에 접속할 거고 + pymysql을 쓸 것이다
# ----> 3 engine=create_engine("mysql+pymysql://{dbid}:{dbpw}@{host}:{port}")
#       4 conn=engine.connect()
#       5 # engine.connect() : 클릭한 것과 같음
#       6 # 열린 SQL쿼리창=conn
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\sqlalchemy\util\deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
# 잘 안 씀
result=conn.execute(text("show databases;")) #문자열로 쿼리 입력 -> database 목록 출력
for row in result:
    print(row)

# %%
conn.execute(text("use sakila;"))

# %%
result=conn.execute(text("show tables;"))
for row in result:
    print(row)

# %%
# text에 직접 sql 쿼리 쓰는 경우 -> 우리는 판다스 써서 바로 할 거임 (아래 방법)
result=conn.execute(text("select * from film limit 10;")) 
for row in result:
    print(row)

# %%
#db 사용 후 접속 해제
conn.close()

# %% [markdown]
# # DB 선택해서 접속하기

# %%
# 워크벤치에 db 만들고 아래 코드로 접속함
engine=create_engine("mysql+pymysql://{dbid}:{dbpw}@{host}:{port}/stock_info")
conn=engine.connect()

# %% [markdown]
# # pandas dataframe DB에 저장하기
# - to_sql("테이블명", con=conn, index=False, if_exists="append")

# %%
# stock_info 아래에 stock_company_info_2026 테이블이 바로 저장됨
# 앞으로는 이렇게 바로 저장할 거임!

data.to_sql("stock_company_info_2026", con=conn, index=False, if_exists="replace")

# %% [markdown]
# # DB에서 테이블을 pandas dataframe으로 불러오기
# - read_sql("테이블명",con=conn)

# %%
# 테이블 불러오기 쉬워짐
data2=pd.read_sql("stock_company_info_2026",con=conn)
data2

# %%
# 다 하면 db에 접속 끝내주기!
conn.close()

# %% [markdown]
# ### 현재 페이지 내부 데이터까지 다 나오는 html 파일 가지고 오는 방법 - 지난 수업시간
# ### 껍데기만 가져오는 거 x, 내부 데이터까지 모두 가져오기
# - 페이지에서 -> f12-network-왼쪽파일 클릭하고-header(=url), payload

# %%
# 하나은행 현재 환율 페이지 내부 데이터까지 다 나오는 html 파일 잘 가지고 옴
# f12-network-왼쪽파일 클릭하고-header(=url), payload

url="https://www.kebhana.com/cms/rate/wpfxd651_01i.do"
payload=dict(ajax="true",tmpInqStrDt='2026-01-28',pbldDvCd=3,inqStrDt='20260128',
             inqKindCd=1,requestTarget='searchContentDiv')
r=requests.get(url, params=payload)
print(r.status_code)
#soup=bs(r.content, 'lxml')
#soup
data=pd.read_html(r.text)

# %% [markdown]
# - 데이터베이스에 접속하는 함수 만들기

# %%
def _mysql_url(dbname=None):
    '''
    dbname이 있으면 db이름을 포함한 접속 주소 출력
    dbname이 없으면 port까지만 포함해서 출력
    '''
    if dbname:
        return f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}/{dbname}"
    return f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}"

# %% [markdown]
# - db 접속 함수

# %%
def db_connect(dbname):
    engine_root=create_engine(_mysql_url())
    conn_root=engine_root.connect() #db에 접속해서 쿼리창 열어줌
    conn_root.execute(text(f"create database if not exists {dbname}")) # dbname 없으면 만들기
    print(f"{dbname} 데이터베이스 확인/생성 완료")
    conn_root.close()
    
    engine=create_engine(_mysql_url(dbname))
    conn=engine.connect() #db에 접속해서 쿼리창 리턴
    return conn

# %%
conn=db_connect("stock_info2")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 conn=db_connect("stock_info2")
#
# Cell In[14], line 2, in db_connect(dbname)
#       1 def db_connect(dbname):
# ----> 2     engine_root=create_engine(_mysql_url())
#       3     conn_root=engine_root.connect() #db에 접속해서 쿼리창 열어줌
#       4     conn_root.execute(text(f"create database if not exists {dbname}")) # dbname 없으면 만들기
#
# Cell In[13], line 8, in _mysql_url(dbname)
#       6 if dbname:
#       7     return f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}/{dbname}"
# ----> 8 return f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}"
#
# NameError: name 'host' is not defined

# %%
conn.execute(text("create table test(idx int not null, name varchar(100) not null)"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 conn.execute(text("create table test(idx int not null, name varchar(100) not null)"))
#
# NameError: name 'conn' is not defined

# %% [markdown]
# - DB에 데이터 저장하는 함수

# %%
def to_db(dbname, table_name, df):
    conn=db_connect(dbname)
    df.to_sql(table_name, con=conn, index=False, if_exists="append")
    conn.close()
    print(f"{dbname}.{table_name} 데이터 저장 완료(append)")

# %%
from dbio import from_db

# %%
stock_data=from_db("stock_info", "stock_price_2026")
stock_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 stock_data=from_db("stock_info", "stock_price_2026")
#       2 stock_data
#
# File c:\fintech04\05data_scraping\dbio.py:41, in from_db(dbname, table_name)
#      40 def from_db(dbname, table_name):
# ---> 41     conn=db_connect(dbname)
#      42     df=pd.read_sql(f"{dbname}.{table_name} 데이터 로드 완료")
#      43     conn.close()
#
# File c:\fintech04\05data_scraping\dbio.py:24, in db_connect(dbname)
#      23 def db_connect(dbname):
# ---> 24     engine_root=create_engine(_mysql_url())
#      25     conn_root=engine_root.connect() #db에 접속해서 쿼리창 열어줌
#      26     conn_root.execute(text(f"create database if not exists {dbname}")) # dbname 없으면 만들기
#
# File c:\fintech04\05data_scraping\dbio.py:21, in _mysql_url(dbname)
#      19 if dbname:
# ...

# %% [markdown]
# # 네이버 증권에서 주가 정보 수집하기

# %%
import os
import time
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
from myfunc import text_clean

# %%
# npay증권 - 삼성전자 페이지 위의 url 그대로 가져옴

url="https://finance.naver.com/item/main.naver?code=005930"
r=requests.get(url)
soup=bs(r.content, 'lxml')
soup
# Out:
# <html lang="ko">
# <head>
# <title>삼성전자 : Npay 증권</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="text/javascript" http-equiv="Content-Script-Type"/>
# <meta content="text/css" http-equiv="Content-Style-Type"/>
# <meta content="Npay 증권" name="apple-mobile-web-app-title"/>
# <meta content="https://finance.naver.com/item/main.naver?code=005930" property="og:url"/>
# <meta content="삼성전자 - Npay 증권 : Npay 증권" property="og:title"/>
# <meta content="관심종목의 실시간 주가를 가장 빠르게 확인하는 곳" property="og:description"/>
# <meta content="https://ssl.pstatic.net/static/m/stock/im/2016/08/og_stock-200.png" property="og:image"/>
# <meta content="article" property="og:type"/>
# <meta content="" property="og:article:thumbnailUrl"/>
# <meta content="Npay 증권" property="og:article:author"/>
# <meta content="http://FINANCE.NAVER.COM" property="og:article:author:url"/>
# ...

# %%
# 종목 코드 가져오기
codes=data2['종목코드']
codes[:2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # 종목 코드 가져오기
# ----> 2 codes=data2['종목코드']
#       3 codes[:2]
#
# NameError: name 'data2' is not defined

# %%
# 하나만 꺼내기
soup.select_one("#middle") # id="middle"

# %% [markdown]
# ### 위 soup.select_one("#middle")의 결과값() dataframe으로 정리하기

# %%
soup.select("#middle dl.blind")

# %%
# dd들만 뽑아오고, -3번째까지만 옴

soup.select("#middle dl.blind dd")[:-3]

# %%
for idx, dd in enumerate(soup.select("#middle dl.blind dd")[:-3]):
    if idx==0:
        print("".join(dd.get_text().split()[:3]).replace("년","-").replace("월","-").replace("일",""))

# %%
result={}

for idx, dd in enumerate(soup.select("#middle dl.blind dd")[:-3]):
    if idx==0:
        result['날짜']="".join(dd.get_text().split()[:3]).replace("년","-").replace("월","-").replace("일","")
        
    elif idx==2: 
        temp=dd.get_text().split()
        print(temp)
        result['거래소']=temp[2]
        result[temp[0]]=temp[1]
        
    elif idx==3: 
        temp=dd.get_text().split()
        #print(temp)
        result[temp[0]]=int(temp[1].replace(",",""))
        if temp[3]=="상승":
            result[temp[2]]=int(temp[4].replace(",",""))
        else:
            result[temp[2]]=-int(temp[4].replace(",",""))
            
        if temp[5]=="플러스":
            result["증가율"]=temp[6]+"%"
        else:
            result["증가율"]="-"+temp[6]+"%"
    else:
        if idx==1 or idx==11:
            temp=dd.get_text().split()
            result[temp[0]]=temp[1]
        else:
            temp=dd.get_text().split()
            result[temp[0]]=temp[1].replace(",","")
        
result

# %% [markdown]
# # 전체 상장 회사 주가 정보 수집하기

# %%
import time

# %%
# 종목코드 가져오기
codes=data2['종목코드']
codes[:2]

# %%
len(codes)

# %%
all_stock_info = []
for code in codes[:3]: # 회사 3개만 수집

    url = f"https://finance.naver.com/item/main.naver?code={code}"
    r = requests.get(url)
    soup = bs(r.content, "lxml")

    result = {} # 1개 회사의 주가
    for idx, dd in enumerate(soup.select("#middle dl.blind dd")[:-3]):
        if idx == 0:
            result['날짜'] = "".join(dd.get_text().split()[:3]).replace("년", "-").replace("월", "-").replace("일", "")
        elif idx == 2:
            temp = dd.get_text().split()
            result['거래소'] = temp[2]
            result[temp[0]] = temp[1]
        elif idx == 3:
            temp = dd.get_text().split()
            result[temp[0]] = int(temp[1].replace(",", ""))
            if temp[3] == "상승":
                result[temp[2]] = int(temp[4].replace(",", ""))
            else:
                result[temp[2]] = -int(temp[4].replace(",", ""))
            if temp[5] == "플러스":
                result["증가율"] = temp[6]+"%"
            else:
                result["증가율"] = "-"+temp[6]+"%"
        else:
            if idx == 1 or  idx == 11:
                temp = dd.get_text().split()
                result[temp[0]] = temp[1]
            else:
                temp = dd.get_text().split()
                result[temp[0]] = int(temp[1].replace(",", ""))
    all_stock_info.append(result)
    
    time.sleep(3)
             
df = pd.DataFrame(all_stock_info)
df

# %%
# 기업 1개씩 (1줄씩) 그때그때 DB에 저장

for index, code in enumerate codes[:20]: # 회사 20개 수집

    url = f"https://finance.naver.com/item/main.naver?code={code}"
    r = requests.get(url)
    soup = bs(r.content, "lxml")
    
    print(f"{index}/{len(codes)-1} 데이터 수집 중")

    result = {} # 1개 회사의 주가
    for idx, dd in enumerate(soup.select("#middle dl.blind dd")[:-3]):
        if idx == 0:
            result['날짜'] = "".join(dd.get_text().split()[:3]).replace("년", "-").replace("월", "-").replace("일", "")
        elif idx == 2:
            temp = dd.get_text().split()
            result['거래소'] = temp[2]
            result[temp[0]] = temp[1]
        elif idx == 3:
            temp = dd.get_text().split()
            result[temp[0]] = int(temp[1].replace(",", ""))
            if temp[3] == "상승":
                result[temp[2]] = int(temp[4].replace(",", ""))
            else:
                result[temp[2]] = -int(temp[4].replace(",", ""))
            if temp[5] == "플러스":
                result["증가율"] = temp[6]+"%"
            else:
                result["증가율"] = "-"+temp[6]+"%"
        else:
            if idx == 1 or  idx == 11:
                temp = dd.get_text().split()
                result[temp[0]] = temp[1]
            else:
                temp = dd.get_text().split()
                result[temp[0]] = int(temp[1].replace(",", ""))

    df = pd.DataFrame([result])
    display(df)

    time.sleep(3)
