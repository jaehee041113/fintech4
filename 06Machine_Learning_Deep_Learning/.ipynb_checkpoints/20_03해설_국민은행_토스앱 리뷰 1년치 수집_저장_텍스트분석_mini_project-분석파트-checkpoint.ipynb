# %% [markdown]
# # 국민은행_토스앱 리뷰 1년치 수집_저장_텍스트분석_mini_project
# * 1. google play에서 국민은행 스타뱅킹앱, 토스앱의 사용자 리뷰를 1년치 수집
# * 2. 수집한 리뷰를 mysql에 저장
# * 3. 수집된 데이터로 긍정/부정 리뷰 비율 분석(막대 그래프 비교)
# * 4. 워드클라우드 분석
# * 5. LDA 토픽 모델링 분석(최적 k 탐색 포함)
# * 6. word2vec 생성 후 T-sne 로 시각화
# * 7. 분석 결과를 통해 얻을 수 있는 인사이트(문제점, 개선방안) 보고서 작성

# %% [markdown]
# # 분석 파트

# %%
# ! pip install sqlalchemy pymysql cryptography python-dotenv

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib
from konlpy.tag import Mecab
mecab = Mecab()
from sqlalchemy import create_engine
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
# !pwd
# Out:
# /mnt/c/fintech4/06Machine_Learning_Deep_Learning

# %%
# !pip install cryptography

# %% [markdown]
# # DB에서 데이터 로드
# * DB는 windows에 설치되어 있는 mysql이기 때문에 ubuntu에서 바로 접속이 안됨
#   * 127.0.0.1(localhost)는 ubuntu의 localhost이기 때문
#   * windows의 ip주소를 찾아서 host 주소에 넣어주어야함
# * DB 접속 id, pw 문제
#   * DB는 local에서는 root 계정 접속이 되지만 원격은 불가능함
#   * ubuntu에서 windows에 설치된 db에 접속하는 것은 원격 접속이므로 원격 접속 전용 id, pw 생성이 필요
#   * workbench에서 새로운 user id, pw 설정 후 권한 설정
#   * 새로운 id, pw, host 번호를 이용해 DB 접속

# %%
dbname = "bank_app_reviews04"
dbid = os.getenv("user_id")
dbpw = os.getenv("user_pw")
host = os.getenv("user_host")
port = os.getenv("port")

# %%
# DB 접속 엔진
engine = create_engine(f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}/{dbname}")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 engine = create_engine(f"mysql+pymysql://{dbid}:{dbpw}@{host}:{port}/{dbname}")
#       2 conn = engine.connect()
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/sqlalchemy/engine/create.py:564, in create_engine(url, **kwargs)
#     561 kwargs.pop("empty_in_strategy", None)
#     563 # create url.URL object
# --> 564 u = _url.make_url(url)
#     566 u, plugins, kwargs = u._instantiate_plugins(kwargs)
#     568 entrypoint = u._get_entrypoint()
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/sqlalchemy/engine/url.py:856, in make_url(name_or_url)
#     840 """Given a string, produce a new URL instance.
#     841
#     842 The format of the URL generally follows `RFC-1738
#    (...)    852
#     853 """
#     855 if isinstance(name_or_url, str):
# --> 856     return _parse_url(name_or_url)
#     857 elif not isinstance(name_or_url, URL) and not hasattr(
#     858     name_or_url, "_sqla_is_testing_if_this_is_a_mock_object"
#     859 ):
#     860     raise exc.ArgumentError(
#     861         f"Expected string or URL object, got {name_or_url!r}"
#     862     )
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/sqlalchemy/engine/url.py:917, in _parse_url(name)
#     914     name = components.pop("name")
#     916     if components["port"]:
# --> 917         components["port"] = int(components["port"])
#     919     return URL.create(name, **components)  # type: ignore
#     921 else:
#
# ValueError: invalid literal for int() with base 10: 'None'

# %%
# 토스(toss)와 국민은행(kb) 데이터를 각각 가져오기
toss = pd.read_sql('viva.republica.toss', con=conn)
kb = pd.read_sql('com.kbstar.kbbank', con=conn)

# %%
toss
# Out:
#             리뷰일 평점                                              사용자리뷰  \
# 0    2026-03-04  2  만보기복권긁기가 안되고 행운복권 2원받는 운세가 안됩니다.광고는 나오지만 2원받지가...
# 1    2026-03-04  1  어제 업데이트 이후로 제대로 되는게 없을 정도로 버그덩어리가 됬네요 빨리 수정업데이...
# 2    2026-03-04  5  다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠...? 사람 놀리는것도 ...
# 3    2026-03-04  1                           토스쇼핑 주소 변경 했는데 예전집으로 가있음
# 4    2026-03-04  3  아니 당장 급하게 송금할 일이 있어서 돈을 보내야하는데 뭐 인증하니까 안전한 금융거...
# ...         ... ..                                                ...
# 5815 2025-03-05  3  갑자기 토스 앱에서 다른 계좌로 송금이 되지 않습니다 왜 그런 거죠 뱅킹에서는 아무...
# 5816 2025-03-05  5  홈화면 커스텀 해서 보고싶은 계좌 세팅 다해놨는데 뭔 자주보는 계좌니 뭐니 맘대로 ...
# 5817 2025-03-05  5                                가족들 한테 추천받아 사용중 쪼와요
# 5818 2025-03-05  1  토스증권 9시 10분 부터인거 왤케 짜치냥ㅋ 그리고 10번째 접속시 치킨 무료라더니...
# 5819 2025-03-04  1  토스 내부 업데이트 할때 마다 뭐가 안맞은지 토스내 스크롤 클릭이 안되서 지우고 깔...
#
#                                                    업체답변
# 0     안녕하세요. 고객 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 1     안녕하세요. Sun Young 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 ...
# 2     안녕하세요. 뺑귄 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 대단히 죄송합...
# 3     안녕하세요. epic life 님, 토스팀입니다. 사용에 불편을 드린것 같아 죄송합...
# 4     안녕하세요. Electric 님, 토스팀입니다.남겨주신 내용만으로는 정확한 확인이 ...
# ...                                                 ...
# 5815  안녕하세요. 윤성훈 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 ...
# 5816  안녕하세요. Philip Park 님, 토스팀입니다. 서비스 변경으로 인해 불편을 ...
# 5817                                                NaN
# 5818  안녕하세요. 꼬미 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 점...
# 5819  안녕하세요. Lucretia Paik 님, 토스팀입니다. 만족스러운 서비스를 제공하...
#
# [5820 rows x 4 columns]

# %%
toss = toss.drop_duplicates()
toss
# Out:
#             리뷰일 평점                                              사용자리뷰  \
# 0    2026-03-04  2  만보기복권긁기가 안되고 행운복권 2원받는 운세가 안됩니다.광고는 나오지만 2원받지가...
# 1    2026-03-04  1  어제 업데이트 이후로 제대로 되는게 없을 정도로 버그덩어리가 됬네요 빨리 수정업데이...
# 2    2026-03-04  5  다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠...? 사람 놀리는것도 ...
# 3    2026-03-04  1                           토스쇼핑 주소 변경 했는데 예전집으로 가있음
# 4    2026-03-04  3  아니 당장 급하게 송금할 일이 있어서 돈을 보내야하는데 뭐 인증하니까 안전한 금융거...
# ...         ... ..                                                ...
# 5815 2025-03-05  3  갑자기 토스 앱에서 다른 계좌로 송금이 되지 않습니다 왜 그런 거죠 뱅킹에서는 아무...
# 5816 2025-03-05  5  홈화면 커스텀 해서 보고싶은 계좌 세팅 다해놨는데 뭔 자주보는 계좌니 뭐니 맘대로 ...
# 5817 2025-03-05  5                                가족들 한테 추천받아 사용중 쪼와요
# 5818 2025-03-05  1  토스증권 9시 10분 부터인거 왤케 짜치냥ㅋ 그리고 10번째 접속시 치킨 무료라더니...
# 5819 2025-03-04  1  토스 내부 업데이트 할때 마다 뭐가 안맞은지 토스내 스크롤 클릭이 안되서 지우고 깔...
#
#                                                    업체답변
# 0     안녕하세요. 고객 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...
# 1     안녕하세요. Sun Young 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 ...
# 2     안녕하세요. 뺑귄 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 대단히 죄송합...
# 3     안녕하세요. epic life 님, 토스팀입니다. 사용에 불편을 드린것 같아 죄송합...
# 4     안녕하세요. Electric 님, 토스팀입니다.남겨주신 내용만으로는 정확한 확인이 ...
# ...                                                 ...
# 5815  안녕하세요. 윤성훈 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 ...
# 5816  안녕하세요. Philip Park 님, 토스팀입니다. 서비스 변경으로 인해 불편을 ...
# 5817                                                NaN
# 5818  안녕하세요. 꼬미 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 점...
# 5819  안녕하세요. Lucretia Paik 님, 토스팀입니다. 만족스러운 서비스를 제공하...
#
# [5795 rows x 4 columns]

# %%
kb = kb.drop_duplicates()
kb
# Out:
#             리뷰일 평점                                              사용자리뷰  \
# 0    2026-03-04  5  제 첫알바때부터 쭈욱 함께해온 국민은행, 그리고 스타뱅킹. 어플리케이션 사용이 편하...
# 1    2026-03-04  5                                            아주 편리하다
# 2    2026-03-04  5                                          사용하기 편하네요
# 3    2026-03-04  5                                                  굿
# 4    2026-03-04  5                                       편리합니다.연동도 잘됨
# ...         ... ..                                                ...
# 4175 2025-03-05  5                                                  굿
# 4176 2025-03-05  5                                          빠른 실행 좋아요
# 4177 2025-03-05  5                                                편해요
# 4178 2025-03-05  5                                              굿경험^^
# 4179 2025-03-05  5                                                  👍
#
#                                                    업체답변
# 0     고객님, 안녕하세요! KB스타뱅킹을 꾸준히 이용해 주셔서 진심으로 감사합니다. KB...
# 1     고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. 앞으로도 고객...
# 2     고객님 안녕하세요! KB스타뱅킹을 이용해 주시고 바쁘신 와중에 칭찬글까지 남겨주시어...
# 3     안녕하세요, 고객님. KB스타뱅킹을 꾸준히 이용해주시고 소중한 시간을 내어 칭찬 글...
# 4     안녕하세요, 고객님. KB스타뱅킹을 꾸준히 이용해주시는 고객님께 진심으로 감사의 말...
# ...                                                 ...
# 4175  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4176  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4177  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4178  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
# 4179  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...
#
# [4069 rows x 4 columns]

# %%
toss.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 5795 entries, 0 to 5819
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   리뷰일     5795 non-null   datetime64[us]
#  1   평점      5795 non-null   str
#  2   사용자리뷰   5795 non-null   str
#  3   업체답변    4969 non-null   str
# dtypes: datetime64[us](1), str(3)
# memory usage: 226.4 KB

# %% [markdown]
# # 긍정 부정 비율 분석 및 리뷰 점수 트랜드 분석

# %%
toss['평점'] = toss['평점'].astype(int)

# %%
toss[['리뷰일', '평점']].groupby("리뷰일").mean().reset_index().sort_values(by="리뷰일").plot(x='리뷰일', y='평점')
# Out:
# <Axes: xlabel='리뷰일'>

# %%
toss['평점'].value_counts()
# Out:
# 평점
# 1    3038
# 5    1123
# 3     681
# 2     505
# 4     448
# Name: count, dtype: int64

# %% [markdown]
# ### 데이터 전처리 및 감성 라벨링 (Preprocessing & Labeling)
#
# - 컴퓨터가 텍스트를 분석하기 좋게 점수를 기준으로 편을 가르는 단계
#
# - 별점(rating)을 기준으로 4-5점은 긍정(1), 1-2점은 부정(0)으로 수치화

# %%
toss['긍정'] = toss['평점'].apply(lambda x: 1 if x > 3 else 0)
toss
# Out:
#             리뷰일  평점                                              사용자리뷰  \
# 0    2026-03-04   2  만보기복권긁기가 안되고 행운복권 2원받는 운세가 안됩니다.광고는 나오지만 2원받지가...
# 1    2026-03-04   1  어제 업데이트 이후로 제대로 되는게 없을 정도로 버그덩어리가 됬네요 빨리 수정업데이...
# 2    2026-03-04   5  다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠...? 사람 놀리는것도 ...
# 3    2026-03-04   1                           토스쇼핑 주소 변경 했는데 예전집으로 가있음
# 4    2026-03-04   3  아니 당장 급하게 송금할 일이 있어서 돈을 보내야하는데 뭐 인증하니까 안전한 금융거...
# ...         ...  ..                                                ...
# 5815 2025-03-05   3  갑자기 토스 앱에서 다른 계좌로 송금이 되지 않습니다 왜 그런 거죠 뱅킹에서는 아무...
# 5816 2025-03-05   5  홈화면 커스텀 해서 보고싶은 계좌 세팅 다해놨는데 뭔 자주보는 계좌니 뭐니 맘대로 ...
# 5817 2025-03-05   5                                가족들 한테 추천받아 사용중 쪼와요
# 5818 2025-03-05   1  토스증권 9시 10분 부터인거 왤케 짜치냥ㅋ 그리고 10번째 접속시 치킨 무료라더니...
# 5819 2025-03-04   1  토스 내부 업데이트 할때 마다 뭐가 안맞은지 토스내 스크롤 클릭이 안되서 지우고 깔...
#
#                                                    업체답변  긍정
# 0     안녕하세요. 고객 님, 토스팀입니다. 만족스러운 서비스를 제공하기 위해 노력하였으나...   0
# 1     안녕하세요. Sun Young 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 ...   0
# 2     안녕하세요. 뺑귄 님, 토스팀입니다. 먼저 서비스 이용에 불편을 드려 대단히 죄송합...   1
# 3     안녕하세요. epic life 님, 토스팀입니다. 사용에 불편을 드린것 같아 죄송합...   0
# 4     안녕하세요. Electric 님, 토스팀입니다.남겨주신 내용만으로는 정확한 확인이 ...   0
# ...                                                 ...  ..
# 5815  안녕하세요. 윤성훈 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 ...   0
# 5816  안녕하세요. Philip Park 님, 토스팀입니다. 서비스 변경으로 인해 불편을 ...   1
# 5817                                                NaN   1
# 5818  안녕하세요. 꼬미 님, 토스팀입니다. 남겨주신 내용만으로는 정확한 확인이 어려운 점...   0
# 5819  안녕하세요. Lucretia Paik 님, 토스팀입니다. 만족스러운 서비스를 제공하...   0
#
# [5795 rows x 5 columns]

# %%
toss['긍정'].value_counts()
# Out:
# 긍정
# 0    4224
# 1    1571
# Name: count, dtype: int64

# %%
# 기초 시각화 (Bar Chart)
toss['긍정'].value_counts().plot(kind='bar')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 기초 시각화 (Bar Chart)
# ----> 2 toss['긍정'].value_counts().plot(kind='bar')
#
# NameError: name 'toss' is not defined

# %%
kb['평점'] = kb['평점'].astype(int)

# %%
kb[['리뷰일', '평점']].groupby("리뷰일").mean().reset_index().sort_values(by="리뷰일").plot(x='리뷰일', y='평점')
# Out:
# <Axes: xlabel='리뷰일'>

# %%
kb['긍정'] = kb['평점'].apply(lambda x: 1 if x > 3 else 0)
kb
# Out:
#             리뷰일  평점                                              사용자리뷰  \
# 0    2026-03-04   5  제 첫알바때부터 쭈욱 함께해온 국민은행, 그리고 스타뱅킹. 어플리케이션 사용이 편하...
# 1    2026-03-04   5                                            아주 편리하다
# 2    2026-03-04   5                                          사용하기 편하네요
# 3    2026-03-04   5                                                  굿
# 4    2026-03-04   5                                       편리합니다.연동도 잘됨
# ...         ...  ..                                                ...
# 4175 2025-03-05   5                                                  굿
# 4176 2025-03-05   5                                          빠른 실행 좋아요
# 4177 2025-03-05   5                                                편해요
# 4178 2025-03-05   5                                              굿경험^^
# 4179 2025-03-05   5                                                  👍
#
#                                                    업체답변  긍정
# 0     고객님, 안녕하세요! KB스타뱅킹을 꾸준히 이용해 주셔서 진심으로 감사합니다. KB...   1
# 1     고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사합니다. 앞으로도 고객...   1
# 2     고객님 안녕하세요! KB스타뱅킹을 이용해 주시고 바쁘신 와중에 칭찬글까지 남겨주시어...   1
# 3     안녕하세요, 고객님. KB스타뱅킹을 꾸준히 이용해주시고 소중한 시간을 내어 칭찬 글...   1
# 4     안녕하세요, 고객님. KB스타뱅킹을 꾸준히 이용해주시는 고객님께 진심으로 감사의 말...   1
# ...                                                 ...  ..
# 4175  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...   1
# 4176  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...   1
# 4177  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...   1
# 4178  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...   1
# 4179  고객님 안녕하세요! KB스타뱅킹을 이용해 주셔서 진심으로 감사드립니다. KB스타뱅킹...   1
#
# [4069 rows x 5 columns]

# %%
kb['긍정'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='긍정'>

# %% [markdown]
# # 워드클라우드 분석

# %%
from wordcloud import WordCloud

# %%
def text_clean(text):
    temp = re.sub(r"[^가-힣a-zA-Z0-9]", " ", text)
    temp = temp.replace("  ", " ").replace("  ", " ").strip()
    return temp

# %%
# mecab : 문장을 단어 단위로 쪼갬
def mecab_tokenizer(text):
    return [w for w in mecab.morphs(str(text)) if len(w) > 1]

# %%
toss.loc[toss['긍정'] == 1, '사용자리뷰']
# Out:
# 2       다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠...? 사람 놀리는것도 ...
# 6       '자산 변화'에서 총자산으로 설정한 금액으로 "그래프에서도 동일하게 월변화를 볼수있...
# 13            광고 보고 포인트 받아져야 되는데 다시 광고가 재생되네요. 오류 수정바랍니다.
# 16      다 좋은데 토스 행운복권 그거 매일 하는데 오늘부터 첫단계만 되고 나머지 단계로 안...
# 24      일주일 방문 미션 버그만 좀 해결해라 제발 존재하지 않는 상품은 왜 있는거야 사실 ...
#                               ...
# 5809                             환전수수료 평생 무료가 아직도 유효 한가요?
# 5811    편하게 잘 사용하고 포인트도 많이 적립할수있어서 좋음. 단, 방문미션은 정답이 맞는...
# 5812                              시간가는줄 모르게 즐거운 여행이였습니다^^
# 5816    홈화면 커스텀 해서 보고싶은 계좌 세팅 다해놨는데 뭔 자주보는 계좌니 뭐니 맘대로 ...
# 5817                                  가족들 한테 추천받아 사용중 쪼와요
# Name: 사용자리뷰, Length: 1571, dtype: str

# %%
# 은행별 긍정 부정 리뷰 모음
toss_pos = toss.loc[toss['긍정'] == 1, '사용자리뷰']
toss_neg = toss.loc[toss['긍정'] == 0, '사용자리뷰']
kb_pos = kb.loc[kb['긍정'] == 1, '사용자리뷰']
kb_neg = kb.loc[kb['긍정'] == 0, '사용자리뷰']

# %%
reviews = [toss_pos, toss_neg, kb_pos, kb_neg]
kinds = ["토스 긍정", "토스 부정", "국민 긍정", "국민 부정"]

# %%
for review, kind in zip(reviews, kinds):
    text_data = review.astype(str).tolist()
    full_text = " ".join(text_data)

    stopwords = set(['은행', '어플', '뱅킹', '앱', '하나', 'toss', '토스'])

    nouns = mecab.nouns(full_text)
    filtered = [word for word in nouns if len(word) > 1 and word not in stopwords]

    from collections import Counter
    word_freq = Counter(filtered)

    wc = WordCloud(
            font_path="NanumGothic.ttf",
            background_color="white",
            width=800,
            height=400
            ).generate_from_frequencies(word_freq)

    plt.figure(figsize=(10,5))
    plt.imshow(wc, interpolation='bilinear')
    plt.axis('off')
    plt.title(f"{kind} 사용자 리뷰")
#     plt.savefig(f"./data/{hana_pos['은행명'].unique()[0]} {hana_pos['긍정'].unique()[0]} 사용자 리뷰.png",
#                 dpi=300, bbox_inches='tight')
    plt.show()

# %% [markdown]
# # -- 일단 워드클라우드까지만 이해하기
# # LDA 너무 복잡

# %% [markdown]
# # LDA 기반 토픽 모델링

# %%
# =========================
# ✅ MeCab tokenizer 통일 버전 (전체 코드)
# - best_k(최적 토픽 수 탐색)과 실제 LDA 학습/출력까지
#   모두 동일한 tokenizer/벡터화 기준으로 맞춘 코드
# =========================
import re
import numpy as np
import pandas as pd

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

from gensim import corpora
from gensim.models.coherencemodel import CoherenceModel

# %%
# -------------------------
# 1) 토크나이저 (요청하신 방식)
# -------------------------
def mecab_tokenizer(text):
    return [w for w in mecab.morphs(str(text)) if len(w) > 1]


# -------------------------
# 2) 최적 토픽 수 탐색 (중복 토큰화 제거 + 필터 일관성)
#    - 반환: (best_k, filtered_texts, tokenized_texts)
#      -> 바깥에서 같은 문서셋으로 LDA 학습 가능
# -------------------------
def find_optimal_topics(texts, start=2, end=20, min_df=5, max_df=0.9, topn=10, random_state=42):
    # 1) 토큰화 1회 + 길이필터 (원문/토큰 함께 보존)
    pairs = [(t, mecab_tokenizer(t)) for t in texts]
    pairs = [(t, tok) for (t, tok) in pairs if len(tok) >= 2]

    filtered_texts = [t for (t, tok) in pairs]        # List[str]
    tokenized_texts = [tok for (t, tok) in pairs]     # List[List[str]]

    if len(tokenized_texts) < 5:
        return start, filtered_texts, tokenized_texts

    # 2) 토픽 상한 자동 축소
    max_k = min(end, max(start, len(tokenized_texts) // 2))
    if max_k < start:
        return start, filtered_texts, tokenized_texts

    # 3) coherence 계산용 dictionary
    dictionary = corpora.Dictionary(tokenized_texts)

    print("단어 개수:", len(dictionary))
    print("샘플 단어:", list(dictionary.token2id.keys())[:20])

    # 4) DTM 생성 (입력은 원문 텍스트, tokenizer는 mecab)
    vectorizer = CountVectorizer(
        tokenizer=mecab_tokenizer,
        preprocessor=None,
        token_pattern=None,
        lowercase=False,
        min_df=min_df,
        max_df=max_df
    )

    try:
        doc_term_matrix = vectorizer.fit_transform(filtered_texts)
    except ValueError:
        print(" (find_optimal_topics) 벡터화 오류 -> 기본 토픽 수 반환.")
        return start, filtered_texts, tokenized_texts

    if doc_term_matrix.shape[1] == 0:
        print(" (find_optimal_topics) min_df/max_df로 단어 전부 제거 -> 기본 토픽 수 반환.")
        return start, filtered_texts, tokenized_texts

    feature_names = vectorizer.get_feature_names_out()

    best_score = -1
    best_n = start

    for n_topics in range(start, max_k + 1):
        lda_model = LatentDirichletAllocation(
            n_components=n_topics,
            random_state=random_state,
            learning_method="batch"
        )
        lda_model.fit(doc_term_matrix)

        topics = [
            [feature_names[i] for i in topic.argsort()[:-topn-1:-1]]
            for topic in lda_model.components_
        ]

        cm = CoherenceModel(
            topics=topics,
            texts=tokenized_texts,
            dictionary=dictionary,
            coherence="c_v"
        )
        score = cm.get_coherence()

        print(f"  → 토픽 수: {n_topics}, Coherence Score: {score:.4f}")

        if score > best_score:
            best_score = score
            best_n = n_topics

    print(f"  ➡️ 최적 토픽 수: {best_n} (Score: {best_score:.4f})")
    return best_n, filtered_texts, tokenized_texts

# %%
# -------------------------
# 3) 실제 토픽 모델링 실행 (pos_neg_dict 루프)
#    - best_k 계산에 사용한 "filtered_texts"로 그대로 LDA 학습 (일관성)
#    - topic_words_map 저장 (나중에 Word2Vec/t-SNE만 따로 가능)
# -------------------------
print("--- 토픽 모델링 시작 ---")

VEC_MIN_DF = 10
VEC_MAX_DF = 0.9

TOPN_WORDS_PRINT = 10
TOPN_COHERENCE = 10

START_K = 2
END_K = 20

topic_words_map = {}  # (bank_eng, senti) -> set(topic words)

for review, kind in zip(reviews, kinds):
    review = review.apply(text_clean)
    series = review.dropna()

    if len(series) < 20:
        print(f"{kind} 리뷰 수 부족 ({len(series)}개) - 스킵")
        continue

    texts = series.tolist()

    # 1) 최적 토픽 수 + 필터된 문서셋을 함께 받기
    best_k, filtered_texts, tokenized_texts = find_optimal_topics(
        texts=texts,
        start=START_K,
        end=END_K,
        min_df=VEC_MIN_DF,
        max_df=VEC_MAX_DF,
        topn=TOPN_COHERENCE,
        random_state=42
    )

    # 필터 후 문서가 너무 적으면 스킵 (토큰 기준이 더 중요)
    if len(tokenized_texts) < 20:
        print(f"{kind}) 유효 토큰 문서 부족 ({len(tokenized_texts)}개) - 스킵")
        continue

    # 2) 실제 학습도 "filtered_texts"로 통일 (중요!)
    vectorizer = CountVectorizer(
        tokenizer=mecab_tokenizer,
        preprocessor=None,
        token_pattern=None,
        lowercase=False,
        min_df=VEC_MIN_DF,
        max_df=VEC_MAX_DF
    )

    try:
        review_vec = vectorizer.fit_transform(filtered_texts)
    except ValueError:
        print(f"{kind}) 벡터화 오류 - 스킵")
        continue

    if review_vec.shape[1] == 0:
        print(f"{kind}) min_df={VEC_MIN_DF} 조건 만족 단어 없음 - 스킵")
        continue

    lda = LatentDirichletAllocation(
        n_components=best_k,
        random_state=42,
        learning_method="batch"
    )
    lda.fit(review_vec)

    words = vectorizer.get_feature_names_out()

    # 토픽 단어 출력 + 저장
    all_topic_words = set()

    print(f"\n{kind} 토픽 {best_k}개 - 상위 단어")
    print("=" * 60)
    for i, topic in enumerate(lda.components_):
        top_idx = topic.argsort()[-TOPN_WORDS_PRINT:][::-1]
        top_words = [words[idx] for idx in top_idx]
        print(f"토픽 #{i}: {top_words}\n")
        all_topic_words.update(top_words)

    a[(kind)] = all_topic_words

print("--- 토픽 모델링 종료 ---")
# Out:
# --- 토픽 모델링 시작 ---
# 단어 개수: 3338
# 샘플 단어: ['같이', '귀신', '나오', '놀리', '던가', '들어오', '바로', '사람', '아니', '아서', '어쩌면', '준다고', '할인', '그래프', '금액', '늘릴', '다면', '동일', '메뉴', '변화']
#   → 토픽 수: 2, Coherence Score: 0.5274
#   → 토픽 수: 3, Coherence Score: 0.5497
#   → 토픽 수: 4, Coherence Score: 0.5529
#   → 토픽 수: 5, Coherence Score: 0.5592
#   → 토픽 수: 6, Coherence Score: 0.5587
#   → 토픽 수: 7, Coherence Score: 0.5668
#   → 토픽 수: 8, Coherence Score: 0.5395
#   → 토픽 수: 9, Coherence Score: 0.5420
#   → 토픽 수: 10, Coherence Score: 0.5129
#   → 토픽 수: 11, Coherence Score: 0.5753
#   → 토픽 수: 12, Coherence Score: 0.5213
#   → 토픽 수: 13, Coherence Score: 0.5642
#   → 토픽 수: 14, Coherence Score: 0.5635
#   → 토픽 수: 15, Coherence Score: 0.5628
#   → 토픽 수: 16, Coherence Score: 0.5391
#   → 토픽 수: 17, Coherence Score: 0.5675
#   → 토픽 수: 18, Coherence Score: 0.5525
#   → 토픽 수: 19, Coherence Score: 0.5417
#   → 토픽 수: 20, Coherence Score: 0.5155
#   ➡️ 최적 토픽 수: 11 (Score: 0.5753)
#
# 토스 긍정 토픽 11개 - 상위 단어
# ============================================================
# 토픽 #0: ['토스', '만들', '세요', '습니다', '나요', '메신저', '결제', '입니다', '페이', '어요']
#
# 토픽 #1: ['습니다', '으면', '에서', '자산', '으로', '확인', '토스', '기능', '합니다', '주식']
#
# 토픽 #2: ['토스', '습니다', '은행', '해서', 'UI', '에서', '가능', '으로', '최고', '기능']
#
# 토픽 #3: ['광고', '토스', '는데', '미션', '포인트', '은데', '다른', '습니다', '아니', '상품']
#
# 토픽 #4: ['계좌', '네요', '화면', '업데이트', '보이', '불편', '자주', '순서', '사용', '는데']
#
# 토픽 #5: ['증권', '토스', '업데이트', '주식', '는데', '에서', '으로', '어요', '차트', '너무']
#
# 토픽 #6: ['습니다', '사용', '토스', '으로', '합니다', '어서', '에서', '는데', '문제', '게임']
#
# 토픽 #7: ['아요', '너무', '어요', '사용', '편하', '토스', '는데', '네요', '고양이', '아주']
#
# 토픽 #8: ['카드', '세요', '추가', '토스', '네요', '제발', '은데', '으로', '에서', '충전']
#
# 토픽 #9: ['는데', '토스', '합니다', '다시', '네요', '감사', '해야', '에서', '갑자기', '뱅크']
#
# 토픽 #10: ['편리', '습니다', '사용', '합니다', '토스', '아요', '너무', '이용', '해요', '으면']
#
# 단어 개수: 6912
# 샘플 단어: ['광고', '나오', '됩니다', '만보기', '복권', '운세', '지가', '지만', '행운', '네요', '덩어리', '버그', '빨리', '세요', '수정', '어제', '업데이트', '이후', '정도', '제대로']
#   → 토픽 수: 2, Coherence Score: 0.5831
#   → 토픽 수: 3, Coherence Score: 0.5296
#   → 토픽 수: 4, Coherence Score: 0.5313
#   → 토픽 수: 5, Coherence Score: 0.5333
#   → 토픽 수: 6, Coherence Score: 0.5737
#   → 토픽 수: 7, Coherence Score: 0.5738
#   → 토픽 수: 8, Coherence Score: 0.5949
#   → 토픽 수: 9, Coherence Score: 0.5870
#   → 토픽 수: 10, Coherence Score: 0.5977
#   → 토픽 수: 11, Coherence Score: 0.5816
#   → 토픽 수: 12, Coherence Score: 0.5817
#   → 토픽 수: 13, Coherence Score: 0.5891
#   → 토픽 수: 14, Coherence Score: 0.5873
#   → 토픽 수: 15, Coherence Score: 0.5626
#   → 토픽 수: 16, Coherence Score: 0.5699
#   → 토픽 수: 17, Coherence Score: 0.5911
#   → 토픽 수: 18, Coherence Score: 0.5821
#   → 토픽 수: 19, Coherence Score: 0.5705
#   → 토픽 수: 20, Coherence Score: 0.5488
#   ➡️ 최적 토픽 수: 10 (Score: 0.5977)
#
# 토스 부정 토픽 10개 - 상위 단어
# ============================================================
# 토픽 #0: ['인증', '토스', '라고', '는데', '번호', '계속', '오류', '네요', '늘리', '고객']
#
# 토픽 #1: ['계좌', '화면', '불편', '카드', '세요', '충전', '는데', '사용', '네요', '에서']
#
# 토픽 #2: ['토스', '증권', '주식', '네요', '너무', '세요', '는데', '다른', '차트', '접속']
#
# 토픽 #3: ['는데', '토스', '연결', '에서', '삭제', '계속', '라는', '다시', '업데이트', '라고']
#
# 토픽 #4: ['토스', '는데', '네요', '으로', '부터', '에서', '습니다', '사용', '어요', '까지']
#
# 토픽 #5: ['결제', '이벤트', '페이', '세요', '그만', '광고', '페이스', '토스', '으로', '아니']
#
# 토픽 #6: ['토스', '는데', '너무', '보이', '계좌', '네요', '확인', '업데이트', '합니다', '사용']
#
# 토픽 #7: ['업데이트', '너무', '네요', '불편', '사용', '습니다', '는데', '으로', '토스', '화면']
#
# 토픽 #8: ['광고', '알림', '복권', '는데', '만보기', '포인트', '나오', '네요', '계속', '너무']
#
# 토픽 #9: ['고양이', '키우', '사료', '장난감', '광고', '네요', '시간', '없애', '갈수록', '는데']
#
# 단어 개수: 1731
# 샘플 단어: ['kb', '국민은행', '그리고', '느끼', '다고', '딱히', '뱅킹', '부터', '불편', '사용', '생각', '스타', '습니다', '알바', '어플리케이션', '으로', '입니다', '증권', '쭈욱', '편하']
#   → 토픽 수: 2, Coherence Score: 0.3447
#   → 토픽 수: 3, Coherence Score: 0.3519
#   → 토픽 수: 4, Coherence Score: 0.3424
#   → 토픽 수: 5, Coherence Score: 0.4053
#   → 토픽 수: 6, Coherence Score: 0.3507
#   → 토픽 수: 7, Coherence Score: 0.3866
#   → 토픽 수: 8, Coherence Score: 0.3938
#   → 토픽 수: 9, Coherence Score: 0.4238
#   → 토픽 수: 10, Coherence Score: 0.3546
#   → 토픽 수: 11, Coherence Score: 0.3994
#   → 토픽 수: 12, Coherence Score: 0.3740
#   → 토픽 수: 13, Coherence Score: 0.3635
#   → 토픽 수: 14, Coherence Score: 0.3422
#   → 토픽 수: 15, Coherence Score: 0.3327
#   → 토픽 수: 16, Coherence Score: 0.3599
#   → 토픽 수: 17, Coherence Score: 0.3763
#   → 토픽 수: 18, Coherence Score: 0.3695
#   → 토픽 수: 19, Coherence Score: 0.4182
#   → 토픽 수: 20, Coherence Score: 0.3720
#   ➡️ 최적 토픽 수: 9 (Score: 0.4238)
#
# 국민 긍정 토픽 9개 - 상위 단어
# ============================================================
# 토픽 #0: ['편리', '해요', '아요', '빠르', '네요', '처리', '아주', '간단', '해서', '환전']
#
# 토픽 #1: ['습니다', '이용', '어서', '설명', '감사', '어요', '업무', '셔서', '친절', '안내']
#
# 토픽 #2: ['사용', '어요', '편해요', '편리', '빠른', '아요', '편하', '처리', '항상', '유용']
#
# 토픽 #3: ['는데', '국민은행', '으로', '에서', '뱅킹', '스타', 'KB', '네요', '세요', '계속']
#
# 토픽 #4: ['합니다', '감사', '편리', '계좌', '가능', '개설', '금융', '으로', '네요', '시간']
#
# 토픽 #5: ['은행', '편하', '네요', '아요', '변경', '거래', '보다', '다른', '어요', '는데']
#
# 토픽 #6: ['만족', '합니다', '친절', '매우', '정확', '신속', '서비스', '상담', '설명', '많이']
#
# 토픽 #7: ['간편', '아요', '가입', '해서', '입니다', '최고', '빠르', '쉬워요', '이해', '상품']
#
# 토픽 #8: ['너무', '아요', '아주', '처음', '네요', '직관', '인식', '인증', '편함', '지만']
#
# 단어 개수: 2895
# 샘플 단어: ['개발', '거래', '건가요', '국민은행', '그나마', '너무', '네요', '는데', '던데', '때문', '려고요', '리뷰', '만든', '모든', '바꿨', '바로', '뱅크', '불편', '사용', '세요']
#   → 토픽 수: 2, Coherence Score: 0.4228
#   → 토픽 수: 3, Coherence Score: 0.4948
#   → 토픽 수: 4, Coherence Score: 0.5648
#   → 토픽 수: 5, Coherence Score: 0.6025
#   → 토픽 수: 6, Coherence Score: 0.5735
#   → 토픽 수: 7, Coherence Score: 0.5516
#   → 토픽 수: 8, Coherence Score: 0.5330
#   → 토픽 수: 9, Coherence Score: 0.5180
#   → 토픽 수: 10, Coherence Score: 0.5523
#   → 토픽 수: 11, Coherence Score: 0.5668
#   → 토픽 수: 12, Coherence Score: 0.5323
#   → 토픽 수: 13, Coherence Score: 0.5223
#   → 토픽 수: 14, Coherence Score: 0.5730
#   → 토픽 수: 15, Coherence Score: 0.5509
#   → 토픽 수: 16, Coherence Score: 0.5249
#   → 토픽 수: 17, Coherence Score: 0.5326
#   → 토픽 수: 18, Coherence Score: 0.5454
#   → 토픽 수: 19, Coherence Score: 0.5473
#   → 토픽 수: 20, Coherence Score: 0.5209
#   ➡️ 최적 토픽 수: 5 (Score: 0.6025)
#
# 국민 부정 토픽 5개 - 상위 단어
# ============================================================
# 토픽 #0: ['알림', '는데', '계속', '설치', '네요', '삭제', '세요', '부터', '자꾸', '됩니다']
#
# 토픽 #1: ['걸음', '업데이트', '측정', '습니다', '연동', '는데', '네요', '에서', '사용', '모바일']
#
# 토픽 #2: ['은행', '네요', '으로', '는데', '너무', '다른', '인증', '카드', '국민은행', '해서']
#
# 토픽 #3: ['계좌', '만들', '는데', '아니', '가입', '개설', '확인', '진짜', '통장', '으로']
#
# 토픽 #4: ['인식', '신분증', '는데', '얼굴', '인증', '번호', '촬영', '네요', '으로', '사진']
#
# --- 토픽 모델링 종료 ---

# %%
topic_words_map.items()
# Out:
# dict_items([('토스 긍정', {'증권', '화면', '순서', '포인트', '결제', '으면', '제발', '가능', '업데이트', '보이', '갑자기', '감사', '다른', '계좌', '해서', '아주', '편하', '만들', '습니다', '은행', '으로', '확인', 'UI', '이용', '해야', '광고', '아니', '어서', '게임', '상품', '토스', '세요', '합니다', '자주', '에서', '사용', '다시', '문제', '은데', '어요', '불편', '카드', '아요', '나요', '네요', '고양이', '기능', '최고', '차트', '자산', '입니다', '는데', '메신저', '미션', '추가', '주식', '편리', '해요', '뱅크', '페이', '충전', '너무'}), ('토스 부정', {'증권', '화면', '시간', '포인트', '결제', '나오', '보이', '업데이트', '고객', '다른', '계좌', '오류', '접속', '복권', '사료', '라는', '이벤트', '습니다', '으로', '확인', '라고', '만보기', '광고', '아니', '없애', '토스', '까지', '세요', '사용', '합니다', '에서', '연결', '다시', '알림', '갈수록', '인증', '삭제', '어요', '불편', '카드', '번호', '키우', '네요', '고양이', '계속', '차트', '는데', '장난감', '페이스', '주식', '부터', '그만', '늘리', '페이', '충전', '너무'}), ('국민 긍정', {'시간', '편함', '뱅킹', '환전', '상담', '가입', '처음', '가능', '만족', '감사', 'KB', '거래', '계좌', '다른', '해서', '아주', '편하', '항상', '습니다', '간단', '으로', '은행', '이용', '스타', '신속', '업무', '어서', '개설', '빠르', '상품', '친절', '세요', '직관', '사용', '국민은행', '에서', '합니다', '이해', '편해요', '어요', '빠른', '많이', '설명', '인증', '지만', '유용', '인식', '매우', '서비스', '아요', '금융', '네요', '정확', '계속', '최고', '처리', '입니다', '쉬워요', '는데', '해요', '안내', '편리', '셔서', '변경', '보다', '간편', '너무'}), ('국민 부정', {'설치', '얼굴', '가입', '업데이트', '걸음', '다른', '계좌', '해서', '측정', '모바일', '만들', '연동', '습니다', '은행', '으로', '확인', '촬영', '아니', '개설', '세요', '사용', '국민은행', '에서', '알림', '진짜', '삭제', '인증', '사진', '인식', '카드', '번호', '네요', '자꾸', '계속', '신분증', '됩니다', '는데', '부터', '통장', '너무'})])

# %%
# Out:
# ['만보기복권긁기가 안되고 행운복권 2원받는 운세가 안됩니다 광고는 나오지만 2원받지가 안됩니다',
#  '어제 업데이트 이후로 제대로 되는게 없을 정도로 버그덩어리가 됬네요 빨리 수정업데이트 해주세요',
#  '다 먹고 나오면 할인해준다고 알람뜨는거 킹받아서 어쩌면좋죠  사람 놀리는것도 아니고 가게 들어오면 바로바로 뜨던가 귀신같이 나오면 뜸',
#  '토스쇼핑 주소 변경 했는데 예전집으로 가있음',
#  '아니 당장 급하게 송금할 일이 있어서 돈을 보내야하는데 뭐 인증하니까 안전한 금융거래를 위해 3일뒤부터 송금가능하다고 하면 저같은 사람들은 대체 뭘 어쩌라는 겁니까 아무리 3일뒤에는 송금에 제한이 없다 하더라도 당장 급한 상황에서 어떻게 할 도리가 없는데 인증할 때도 아무런 보고가 없어가지고 그냥 단순한 인증인줄 알았는데 3일에 제한이 걸리는 건 줄 누가 압니까 담부터 이런 인증 절차 진행할때 미리 사전보고 같은 걸 해주셨으면 좋겠습니다',
#  '도드람농협 수협 계좌 안불러와지는데 개선 부탁좀요',
#  '자산 변화 에서 총자산으로 설정한 금액으로 그래프에서도 동일하게 월변화를 볼수있게 해 주세요 설정한 자산으로는 힘들다면 토스증권 에 자산의 월간변화를 볼수 있는 메뉴를 추가 해 주세요 사용자를 늘릴 수 있는 편의사항입니다',
#  '앱이 너무 무거워서 버그랑 렉이 너무 심함 이걸 몇개월 방치하는게 어이가 없음 쇼핑이니 광고니 계속 쓸데없는것만 늘어나고 ui가 편해서 토스 썼는데 렉이 너무 심해져서 오히려 불편해짐',
#  '처음 설치하면 홈화면까지 가는데 쓸데없는 절차가 왜 이렇거 많은지 짜증나서 삭제했어요',
#  '지금 앱 업데이트 후에 행운 복권 포인트 받기가 안됩니다 광고를 봤는데도 그러네요',
#  '서버 관리 안하냐 진짜 주식 사는데 체결이 3분 뒤에 계속 쳐 되서 손해는 손해대로 보고 이익은 볼건 못보고 진짜 짜증나네',
#  '업데이후 혜택부분에서 오류가 생기는거같아요',
#  '카메라 사용 불가능한 환경인데 인증마다 모바일 신분증은 사용도안되고 무조건 신분증 촬영만 하라는건 좀',
#  '광고 보고 포인트 받아져야 되는데 다시 광고가 재생되네요 오류 수정바랍니다',
#  '2월부터 앱이 전체적으로 너무 느려짐 버퍼링걸린것처럼 너무 답답함 내폰 문제인가 싶은데 다른앱들은 다 정상적으로 잘됨 특히 토스증권은 진짜진짜 느려져서 뭘할수가 없음 오늘 사이드카 빌동됐는데도 대응을 못하고있음 캐시삭제같은것도 진작했음',
#  '아니 광고보는거 까지는 알겠는데 만보기 복권도 안 까지고 왜 행운복권 잘주다가 광고만 보게하고 다음 스탭으로 넘어가지지도 않네요 소수의 포인트라지만 광고만 보게하고 안주면 기분 엄청나쁘네요',
#  '다 좋은데 토스 행운복권 그거 매일 하는데 오늘부터 첫단계만 되고 나머지 단계로 안넘어가는데 뭐가 문제죠 광고 보고 다음단계 터치 하면 넘어가는데 아예 안넘어가네요 해결좀 해주세요',
#  '쇼핑쿠폰 주셔서 쓰려하는데 중국산 저품질 상품이 너무 많아서 살게 없어요 알리같은 느낌',
#  '어제 오전인 3월 3일부터 갑자기 토스 고양이 키우기에서 갑자기 사료와 장난감 제작완료가 됐는데 광고를 다 봐도 내가 키우는 고양이 화면으로 넘어간 상태로 멈춰버려요 수정 부탁드려요 26년 3월 3일 밤 토스 고객센터 가니까 지금 발생하는 문제라고 최대한 빨리 수정하겠다고 나오더라고요 토스 앱 자체 문제였음 26년 3월 4일 오전 6시반 확인하니 토스 앱에서 수정 완료됐는지 잘 되네요',
#  '어제 버전 업데이트하고나서 행운복권 버튼누르기 만보기 함께토스켜기 모두 버그 투성이네요 버전 업 전에 테스트 안 하나요',
#  '웬만해선 리뷰 잘 안 쓰는데 고양이 때문에 짜증나서 리뷰 씁니다 업데이트 이후로 장난감 사료 미션이 전혀 되지 않고 리뷰 답글 보면 하나같이 매크로 답변에 전혀 영양가 없는 내용들이 수두룩합니다 업데이트 할거면 똑바로 하던가 제대로 된 답변을 하던가 하세요 둘다 제대로 하지도 못하면서 무슨 앱을 사용하라는 건가요 매크로 답변 쓸거면 그딴식 운영하지 마세요',
#  '갑자기 어제부터 만보기 걸음수를 채워 복권을 모아도 긁을수가 없습니다 광고만 실컷 보고 복권긁기는 계속 안되고 고객센터는 상담원연결도 잘 안되고 연결후엔 조치해준다고 기다리라고한뒤 또 함흥차사네요 고양이키우기도 광고봐도 모으기가 전혀 안됩니다 광고만 실컷보게 만들고 적립은 안해주는건 도대체 뭔가요 핸드폰 기종은 갤럭시 S23울트라인데 최근 업뎃완료 후 그런건지 확인 후 빠른 조치 바랍니다',
#  '기기변경 후 토스앱을 재설치해도 게임을 할때 미니앱에 문제가 발생했습니다 메세지가 뜨면서 게임 로딩이 안됩니다 어떻게 해결해야 하나요 기기는 s20 에서 s23 로 변경하였습니다',
#  '3월들어서 인게임 광고 관련 버그가 심해졌어요',
#  '일주일 방문 미션 버그만 좀 해결해라 제발 존재하지 않는 상품은 왜 있는거야 사실 토스는 과소비를 막기 위해 일부러 광고제품을 숨기는게 아닐까 안좋은 기억을 심어두면 두고두고 상품을 볼때마다 안 살 마음을 줄 수 있잖아',
#  '고객센터에도 맨앞에 뜨긴 하는데 지금 토스 고양이 광고를 봐도 하나도 안 넘어가네요 아까부터 상자 7개 모은거 열려고 했는데요 시간되서 사료받기도 하나도 안되고요',
#  '만보기 복권긁기도안대고 랜덤으로뜨는복권얻기도안됩니다',
#  '왜 평정이 낮은지 이해했습니다',
#  '요즘 결제 내역에서 지 맘대로 내역 수정하는 경우가 있어요 3000원인데 취소선 긋고 0원으로 만들어요 왜 이럴까요',
#  '복권 긁으려 하는데 전혀 안 됩니다',
#  '버그에 오류 투성이',
#  '만보기에서 복권을받는데 30초보면은 복권을 받을수 있는데 광고를봐도 복권이 안나와요 복권긁기도 안되네요',
#  '오늘 복권이 실행이 안되서 캐쉬삭제 데이터 삭제 어플 삭제 하고 있음 광고보기하고 나오면 복권긁는 화면이 안나옴 기타 다른 몇가지 안되는거 있는데 나열하기 귀찮음 다시 설치중인데 그래도 안되면 오늘은 꽝',
#  '복권 긁기가 갑자기 안 되는데 이거 왜 그런거죠',
#  '주식하는데 렉이 왜이리 심해짐',
#  '지금 광고만 보이고 안넘어가네요 몇시간 째',
#  '광고보고 포인트받기 광고보고 만보기 복권긁기 아무것도 안되며 심지어 자정이후 열심히 걷고 광고본거 사라진다는게 아주 기쁘게 만드심 이럴거면 뭐하러 업데이트 했음 걍 냅두지',
#  '광고 보고 만보기 복권 긁기가 안됩니다 만보기 걷고서 복권 긁는 것도 안되고요 고양기 사료 받는거 광고 봐도 안되고요 토스 제거 후 다시 다운 받아야 하나요',
#  '토스 만보기 복권 긁기 광고를 4번을 봤는데도 광고만 계속 나오고 복권 긁기가 안되네요',
#  '업데이트후 토스 만보기 오류나요 광고를 봐도 복권이 긁혀지지 않아요',
#  '만보기 광고는 나오는데 왜 복권긁는거 안되나요 내 만보걸음 보상 어떻게 할꺼야',
#  '광고봐도 버튼이 안눌러자고 다시 개로운 광고보라고떠요',
#  '오늘업뎃이후 20받기 로또 만보기복권이 광고후 열리지않네요 빠른 조치바랍니다 내 아까운 티끌 돌려줘요',
#  '아니 업데이트하자마자 로또도 못받고 복권도안긁히고 아무것도 안되잖아요 버그를 잡았다더니 버그를 심은거아니냐고요',
#  '알람이 일정 시간만 지나면 저절로 사라지고 없습니다 다른 어플은 안 그래요',
#  '고양이 레벨관련 터치되지않은 현상',
#  '만보기 복권 에러가 너무 자주발생하군요 진짜 뭐가문젠데 또안되나요 왜광고만 보여주고 복권은 못긁고 뭔에러가 이렇게 자주놔는지 뭔',
#  '걷기 포인트에서 렉이 걸려서 돈받기가 안됩니다',
#  '첫 해외주식 사려고하는데 몇달째 주요내용 확인하고 다음단계 누르는 단계에서 계속 시스템오류라고 떠요 토스 전화연결도 잘 안되고  하 왜이러는건가요',
#  '토스증권 너무너무 느림 배터리 소모도 엄청남',
#  '만보기 복권 긁기가 안되요',
#  '만보기 복권이 긁히지가 않음 광고만 계속 보게 만드네',
#  '토스 복권 을 클릭 하면 광고 만 나오고 실행 않되네요 업데이트 했는데도 실행 않되요',
#  '업데이트 하고나서 고양이키우기에 광고보고 받는 보상이 안되요 토스친구 에도 가끔나오는 친구 이것도 광고봐도 보상이 안나와요 왜갑자기 이러는거죠 어제까지 잘 하고있었는데 무슨오류인가요',
#  '사료받기 누르고 광고 봄 사료 적립 안됨 다시 누름 또 광고 봄 적립 안 됨 껐다가 키고 광고 봄 적립 안 됨 사료 하나 얻어보겠다고 광고 10개봄 장난감랜덤상자 오픈 누름 안됨 또 함 안됨 껐다가 켜서 광고봐도 안됨 5분뒤해봄 장난감 받음 상자하나 더잇어서 광고 봄 적립 안됨 짧은광고에서 10초 나오는거 그렇다 침 돈 벌어야하니까 근데 광고 10개봐야 되는 이 오류는 답글로 확인하겠다만하고 개선의지가 있긴함 댓글 어지간하면 안 쓰는데 내가 뭐하는 짓인가 싶어 현타와서 씀 돈 뽑아먹을 생각만 하지말고 피드백 반영좀 제발',
#  '어린이 요금 청소년 요금으로 어케 바꿔요 네이버에 검색한대로 했는데 카드 관리도 없고 그냥 다 없어요',
#  '모든 앱 소리 동시허용을 설정했음에도 광고가 기존 플레이중인 소리를 끄네 광고따위가 타 앱 동작 간섭을 하다니 하찮은 앱이 권한을 너무 세게 씀 광고시간이 5초라고 표기되어 있으나 실제로는 10초임 사용자 입력 없이는 종료되지 않아서 추가 지연도 있음 이런 거짓정보 기재는 좀 이러한 현상이 없었던 구버전에서 증권이 막혀서 업데이트했더니 발생중 당장 고쳐라 이번주 내로 고쳐지지 않으면 여기 주식 전부 타사로 옮겨버리던가 팔아치울거임',
#  '글자가 깨져서 보이는데 상담원 연결 너무 어려워요',
#  '해외주식 호가창이 문제 제일 위 아래만 나오고 나머지는 나오질 않아 똑띠 안하나 수량이 나머지는 안보이자너 머하는거에요 정규장에서 안나와요 조속한 처리바랍니다 최신버전인데 확인일랑 하시고 업데이트 하라고 말하시는것임 정규장에 들어가보면 보이는것을 그것도 확인도 못하는 매크로 답변 참 답답하다 리뷰를 적는 상담사는 최소한 해당부분에 기능이나 거래를 해보는 사람으로 해라 먼지도 모르고 매크로 답변만 하지말 정규장에 호가창을 처보라고 못찾겠어면 카카오증권 키움증권 모드 호가창이 정상인데 이너무 토스증권만 호가창이 엉망이라고 프리마켓이랑 정규장 호가창을 보세요',
#  '업데이트이후 이상해짐',
#  '업데이트하고 포인트 적립 에러 있음 두 번 적립되는건 전부 다 무한반복 되고 적립 안됨',
#  '업뎃하라고해서 했더니만 고양이 사료가 영상만보게하고 하나도 안받아져요 왜이러는건가요',
#  '너무편해요모든은행증권보험등한눈에볼수있어서',
#  '만보기 복권 긁는 화면으로 안 넘어가네요 몇 번이나 시도해도 광고는 오류도 없이 몇번이고 잘만 나오는데 고작 2원 3원 주는 복권은 오류로 절대 못 긁게 하네',
#  '이번 업데이트하고나서 만보기 고양이키우기 같은 광고후 보상받는게 되지않아서 확인부탁드립니다',
#  '친절한',
#  '갑자기 터치가 안돼요',
#  '직장하고 집주소는 왜물어보는지 모르겠네요 찾아오실려고요',
#  '광고를 봐도 넘어가지 않고 무한 로딩이 뜸 갈수록 어플이 엉망으로 업뎃되어서 버그만 많아짐',
#  '업데이트 이후 망가짐 고냥이도 안되고 광고보는거 다 망가진듯',
#  '고양이 키우기 사료 받기 장난감 받기 클릭하고 광고도 다 보고 왔는데 먹통되면 어쩌자는거임 그리고 랜던 상자 열리지도 않는건 뭐 포인트 아끼려고 그러는거임',
#  '토스증권 차트가 자꾸 옆에가 짤려요 느려서 그런것 같은데 개선 부탁드립니다',
#  '쇼핑지원금 쿠폰 팝업좀 없애요 알림옵션에도 끄는게 없고 꺼지지도 않고 스와이프로만 없애게 만들어서 악성광고마냥 클릭되게 만들어서 쇼핑창으로 계속 납치함 납치한다고 쇼핑보는것도 아니고 개빡쳐서 바로 나가게 만드는데 이게 뷰봇처럼 페이지조회수만 찔끔찔끔 늘리지 광고가됨 한두번도 아니고 맨날 뭔짓임 뱅크랑 주식만 쓰는데 빡치게 하네 카카오 쇼츠강제시청 기획자랑 친구가 만들었음',
#  '토스증권 pc에서 주식차트를 볼때 봉마다 시간이 정확하지가 않아요 예를들어서 현재시간이 18분일때 1분봉에서는 19분으로 나오고 8시일때 1시간봉에서는 10시로 나와요 그리고 주식 1주를 매수주문걸었다가 취소했는데 매수가 돼서 당황했던적도 있습니다 이 문제들만 해결해주시면 좋을것같아요',
#  '쿠폰 준다는 식으로 슬쩍 페이스페이 사용하게 하려는 아이콘들이 매우 불편합니다',
#  '평소에 리뷰같은거 안쓰는데 진짜 짜증나서 씁니다 토스증권 키면 쇼핑 팝업 뜨는거좀 없애주세요 쇼핑 키우려는건 알겠는데 거슬려서 진짜 앱 삭제하고싶어집니다 적당히해야죠 앱 킬때마다 뜨게만듭니까',
#  '연결이잘안되유',
#  '왜 자꾸 내 자산을 쳐 숨기고 난리냐',
#  '토스커뮤 알람 필요해서 켜놓으면 40분전글이 알림 울리고 꺼도 울리고 진자 열받네 어플 똑바로좀 만들어요',
#  '같은 옵션 선택하기 계속 품절 노판매 쳐뜨네 니네나 이거 실컷해라',
#  '다른 은행은 인증해야되지만 토스는 장점에도 불구하고 가끔씩 UI UX 진짜 불편하게 사람 거슬리는거 많이 만듬 그냥 다른 은행들도 토스처럼 인증이 간편해졌으면 좋겠음',
#  '뱅크 열었을때 바로 제 통장 계좌가 보였으면 좋겠어요 ui가 많이 바뀐거 같은데 계좌에 얼마있는지 찾는것도 너무 불편해요 제가 다른토스계좌에 송금한 돈 쓰려고 결제수단 바꾸는데 안되고 너무불편',
#  '하단 광고팝업창 좀 그만 올리세요 닫는거도 없고 뭐 어쩌라는건지 토스에서 생수 안살꺼라고요',
#  '일상 생활에 필요한 모든것을 토스 앱 하나로 모두 해결할 수 있어서 편리합니다 시간과 장소를 떠나 내가 원하는 정보를 모두 확인할 수있어서 편리하게 잘 사용하고 있습니다',
#  '어느순간부터 광고 보상이 지급 안되기 시작함 꾸준히 쓰지 말라는 소리인가',
#  '쇼핑도 저렴하고 이체하고 적립고 하고 좋네요',
#  '애 계좌만들어주려는데 자꾸 어플 업데이트해야된다네요 업데이트가 다됐는데 카카오증권에서 만들어줘야겠네요',
#  '계속 토스페이먼츠 계좌결제 구글 로 9900원씩 나가는데 어떻게 못하나요 정기구독된건 아무것도 없는데',
#  '최근에 존재하지 않거나 판매하지 않는 상품을 알려주는 아주 유용한 앱으로 변신중임',
#  '렉 좀 잡아주십시오 사라졌다싶으면 렉 걸려서 화면 전환이 느려지고 그러네요',
#  '요즘 앱 내의 글씨가 깨지게 나오는데 왜이렇죠 알아볼 수 없는건 아니지만 보기 불편해요 해상도 떨어진 글씨 보는것 같아요 기종은 갤럭시 플립7입니다',
#  '은행어플을 가장한 광고앱 징그럽게 광고 쳐하네',
#  '이젠 들어가자마자 밑에 뭐 띄우면서까지 페이스페이 강요하네  페이스페이 안 한다고 쫌',
#  '최악',
#  '토스는 믿을수가 없다 특히 일주일방문미션을 하연 거짓을 곳곳에 숨겨두고있다 그래서 뱅킹도 못 믿어서 예금들은 다 빼고있다 좀 신뢰성 좀 높여라 아닌가 여긴 중국개발사인가 China out',
#  '5천원 지원금 배너 페이스페이 쿠폰 작작 좀 띄웁시다 거슬려 죽겠네요 광고도 갈수록 지나치게 많아지고 혜택은 갈수록 줄어들고 고양이 키우기는 사료만 잔뜩 뿌리고 장난감은 짜게 주고 앱은 무거워지고 앞날이 보입니다',
#  '하 하 외국인이라 토스를 좀 어렵게 하게돼네요 공휴일이라서 그런지 상담원이 없어서 당장 할 수가 없어요 외국인 증명서 까지 사진 찍고 올려는 데 가족 증명이 안 돼고 상담원이랑 연결이 돼야 가족 증명이 돼고 로봇 이랑은 아예 문제를 못 내게해요 여기에서 막혔는 데 너무 짜증나네요 외국인 분들께서 토스를 깔려고 하시면 평일에 깔고 오전에서 로그인 하시는 게 좋을 것 같아요 토스가 안 좋다는 건 아니고 그냥 외국인이라서 너무 복잡하고 인증해야 할게 너무 많아서 살짝 안 좋은 기분이 들었어요  복잡한 이상 보안이 정말 좋구 청소년도 할 수 있다는 게 정말 좋아용',
#  '라이브방송 포인트 안들어옴',
#  '사기같음 만보기복권1등은커녕 천원도 당첨안됨 20원당첨이끝으로 5원10원만나옴 3년넘게 꾸준히 했는데 진짜당첨자 있는지 궁금함 못믿겠음 방문 미션도최악임 오류 뜸 찾기귀찮아짐',
#  'ui바뀌고 그나마 잘사용중인데 앱이 너무 무거운거같아요 최적화든 뭐든 하셔야할듯 신형기기는 그나마 빠른데 구형기기들은 감당못할듯',
#  '안되는 항목이 많고 느립니다',
#  '어플켜면 기본ui를 띄워야지 상품화면만 강제로 계속 쳐띄우고 자빠졌네',
#  '고양이 사료 장난감 10개 누를 때마다 사료 1개씩 주는 보상 모르시나요 뜨던 팝업이 이전 업데이트 이후로 안 뜨는데 오류 수정해주세요',
#  '초기부터 사용이 편하고 여러 포인트 주는것도 재미있어서 잘 쓰고는 있어요 그런데 요즘은 광고로 포인트 주는것이 너무 지나치게 사용자를 바보 취급하는것처럼 막 하시는것같아요 돈나무 키우기도 10개 모으면 출금한다고하고 11개써야되는 점 사람 놀리는건가요 아니면 셈을 모르는 사람 취급 차라리 10개는 바꿔주는거고 1개는 이체비용이라고 제대로 공지하던지요 광고수익을 올리려고 여러 노력하는 건 이해하지만 5초만 봐도 된다더니 30초 1분이거나 30초라더니 1 5초거나하는 등 광고 시간과 규격부터 통일하거나 검열 좀 하시는게 좋겠네요 예전에는 같은 광고라도 재미있어서 했는데 지금은 어차피 공짜로 돈주는거니 아무렇게나 해도 할거야 라고 생각하시는듯 성의가 없어보입니다 광고보고 복권받았더니 확인하려면 또 광고를 봐야하는 경우도 있고  요즘 토스에 많이 실망입니다 지금은 워낙 이용하는게 많다보니 그냥 쓰고는 있지만 포인트 쪽은 점점 짜증나서 포기하고 있어요',
#  '미션을 불리하게 많이 줄여 놓고 볼일보고 나서도 광고가 자주 뜨네요 30초 20초 나오고요 정말이지 지장이 많이가요 수정부탁 드림',
#  '업뎃 이후에 먹통 다시 깔았더니 문자인증 완료 후 정지시킨 한국 핸드폰 번호로 전화 인증하라고 해서 막힘 다른 은행사 어플은 해외 나와있으면 저절로 조회해서 인증 쉽게 할 수 있던데 빨리 개선 좀 하세요',
#  '상품 구경하고 포인트 받기 같은 옵션 선택하기에서 지금은 상품을 구경할 수 없습니다 문구가 너무 많이 떠요 한두번은 이해하는데 지속되니 답답하네요 고양이 키우기는 얻은 장난감을 하루에 다 써야 하는 것도 좀 아쉽네요 저번에 900개 넘게 모았는데 순식간에 사라져 당황했습니다 상품 구경하고 장난감 1개 사료 한개 받는거 45초 너무 길다고 생각해요 사료보다도 장난감이 더 필요하다고 생각해요 토스쇼핑 1분 구경하고 포인트 1원 받는건 빨리 스크롤하면 안된다고 하는거 개선하면 좋겠습니다',
#  '1 토스 하다가 알람 끄지도 못하게 이제는 밑에다 띄우시네요 이것 좀 안 뜨게 해주세요 너무 거슬려요 2 이번주 미션에서 아이콘 크기 좀 키워주세요 너무 작아요 3 상품 구경 하고 포인트 받기 같은 옵션 선택하기에서 현재 구경할 수 없는 상품입니다 이게 너  무 많아요',
#  '고양이 키우기 광고 천개 넘개보는게 실화',
#  '렉 너무많이걸려요',
#  '집주소 변경 확인이 왜 안되는건지 제발좀 다음으로 넘어가게 해주세요',
#  '점점 광고들이 심해지면서 이전의 1초짜리 광고가 전부 5초짜리로 변경 그렇다고 뭐 이득이 많이 들어오냐 하면 그것도 아니고 앱 로딩은 똑같이 느림 광고가 다양하지도 않고 맨날 똑같은 것들만 등장 거 이거 승인한 사람 누군진 모르겠는데 이제 당신들이 광고하던 KB 스타뱅킹이나 얌전히 쓰렵니다 그쪽도 느리긴 한데 광고 덜하더라구요',
#  '내 신용점수 보기 어떻게 없애나요 한가운데에 있어서 자꾸 실수로 눌러져서 너무 불편한데 제발 이거 위치를 바꾸거나 끄는 방법좀 알려주세요',
#  '갑자기 로그인이 풀려있는데 어떡하나요',
#  '토스가 많이 바꼈네요 사용하려는게 생겨서 다시 깔았는데 계속 첫화면에 쓰잘데기 없는것만 떠서 내계좌 연결해야 사용할수있나 싶네요 전에는 안그랬는데 불편해요',
#  '완전이상해요',
#  '갤럭시z플립7로 바꿨는데 토스 계좌 글자 슷자들이 한번씩 좀 깨져보이는 현상이 있어요 신경안쓰면 그만일수도 있지만 이런 큰 화면에서의 화질 개선이 가능하다면 부탁드립니다',
#  '만보기복권에 다크워서바이벌 몇일동안 그광고만 계속 그 광고 하나만 주구장창 나옵니다',
#  '갈수록 기능이 많아지는 많큼 배터리 잡아 먹는 기계 광고도 2배로 늘어나고 이제 3배를 향해 가는 중 일부 광고 강제 소리 켜짐이랑 오류 때문에 열 받음 테스트도 안 하고 올리나 최근 혜택들도 줄이거나 난이도 높여서 운영이 큰 문제인데 무슨 답변을 엉망이라서 사용 줄일거고 똑같으먼 그냥 삭제하고 만다 별점 더 내림',
#  '켤 때 밑에서 올라오는 광고는 너무 한거 아닙니까 하루 한 번으로 빈도를 조절하던지 없애던지 하시기 바랍니다 최악입니다',
#  '토스 1000만원 로또 받기 이벤트 어제부터 안 되는데 문의하려고 해도 AI 채팅만 연결되네요',
#  '잘 사용하고 있었는데 어제부터 포인트 획득을 위한 연결프로그램 선택시 play store가 나오지 않고 다른 앱이 나타납니다 저 같은 경우는 진에어와 토스앱이 나옵니다',
#  '인형뽑기 같은거 이벤트라도 할거면 좀 정상적으로 해라 무조건 금색은 제일 밑바닥에 쳐박혀서 2번은 무조건 파랑 뽑게 만들고 금색은 어쩌다가 걸려도 바로 놓치는구만 이 패턴만 계속 당하면 하겠냐 이벤트 참여',
#  '토스 증권으로 주식투자를 하고 있는데 실적발표 후에 재무재표 업데이트가 너무 늦는 건 왜 그런가요 하루 이틀 늦는 것도 아니고 일주일이 지나도 업데이트가 안되는 것 같은데요',
#  '토스 쇼핑 5천원 광고는 도저히 끄는법이 없습니다 이런건 금융앱이면 끄는걸 쉽게 만들어야 하는거 아닌가요 모든 알람과 마케팅 철회를 해도 뜨게만드는건 역겨운 수준인에',
#  '요즘 들어 접속도 안되고 광고만 보다 랙 걸리고 연결 안되는 경우가 많네요 개헌 좀 합시다',
#  '토스 고양이 키우기에서 사료만 너무 많이 줍니다 에너지가 2천이 넘어요 장난감을 더 받을 수 있게 개선해주세요',
#  '잘쓰고는 있는데 가끔씩 겁나 느려져요 지금도 무슨 어플키는데 20초가까이 로딩에 화면 전환도 겁나 느리고 왜 이런건가요 빠른 해결 부탁드려요',
#  '페이스결제 팝업 작작좀 해라',
#  '토스증권 주문가능금액이랑 실제금액이랑 안맞는오류',
#  '주식 시장에서 구매대기 판매대기 좀 빨리 되게끔 개선 시켜주세요 그리고 구매 판매 시간 너무 오래걸려요 물량 없다고 늦게오면 나만 손해입니다',
#  '돈모으기 미션은 이어지면서 그 미션중 하나인 만보기는 확인을 해도 연속 일수 귾어지는 이상한 현상이 있음',
#  '업데이트할때마다 앱이 구려져요 새로 업데이트한이후로 쿠폰 받아가라는 팝업창이 계속 떠서 짜증나요 팝업창 좀 안뜨게 해주세요',
#  '만보기 복권 사기 작작좀 치세요 직원들 데리고 후기조작 굿',
#  '별로임 토스들어가면 광고뜸',
#  '아니 주식창 보는데 무슨 3천원 안면식쿠폰 자꾸 띄우나 감다뒤짐',
#  '잘사용중입니다 한가지 건의사항이 있어요 앱내에서 글씨 크기를 조절할수 있었으면 합니다 토스는 단순히 금융관련 기능 만 사용하고 끝나는 앱이 아니죠 각종 커뮤니티 글을 읽는 시간이 늘어나는데 글씨크기가 너무 작아서 오래 들여다보기가 불편합니다 휴대폰 기능에서 글씨크기를 조절가능합니다만 그럼 휴대폰자체 모든 글씨가 커지죠 그건 원하지 않거든요 증권탭의 커뮤니티만이라도 글씨크기조절이 되었으면 합니다 향후 업데이트 계획에 참고 부탁드립니다',
#  '매번 로그인때마다 터치 방해하는 광고 쳐 보이게 해놔서 개노답 토스 증권 전용 앱을 따로 만들어놔라 수수료 내고 쓰는건데 도대체 왜 광고를 봐야 하냐    유료 이용에도 광고를 붙이는 개노답 토스',
#  '비트코인 자산 연결도 가능하게 해주시면 안될까욤',
#  '배터리 사용량 뭐죠 기본으로 냅두면 혼자 배터리를 다 먹네요',
#  '굿',
#  '자산 추가 계좌정보 불러오기 할 때 첫화면부터 내가 원하는 계좌가 아닌 전체를 다 로드하는건지 너무 오래걸림',
#  '토스유스 카트 투명 검정색 말고 기본 검정색 카드 재출시 원합니다',
#  '새벽에 토스증권 문자질하길레 탈퇴 탈퇴 절차 따라하는데 토스증권으로 연결되어 온갖 인증받게 하더니 탈퇴 안되어있음 개짜증나게 해놨네 기어이 탈퇴함 언젠가 쿠팡 이상으로 사고칠 것 같음',
#  '진짜로 다 좋은데 버스카트 충전 때할 천원단위만 해서 좀 아쉽네요',
#  '실수만 하지않는다면 좋은 앱입니다',
#  '좋아요',
#  '결제할 때마다 돌려받기에 오류가 있네요 분명 조건에 맞춰서 결제를 했는데 내역이 안 뜨거나 한참 후에 뜨고 리스트에서는 기회가 있다고 뜨는데 막상 포인트 받으려고 들어가보면 내역도 안 뜨고 기회도 다 썼다고 떠요 이거 꽤 예전부터 있던 오류인 걸로 아는데 빨리 픽스 부탁드려요 은근 거슬려요',
#  '카카오톡 다음으로 거지 같은 앱',
#  '지저분한 알림이 스팸문자나 카톡광고보다 더 많음 도저히 더는 못쓰겠음',
#  '이젠 쇼핑관련 안보면 없애지 못하는 팝업도 생겼네요',
#  '토스증권 고객센터 곧 연결해주겠다며 20분 넘게 트럼펫 소리 듣다가 도저히 못듣겠어서 결국 통화 못하고 끊었네요 첨듣는 노랜데 하도 들으니 계속 생각나서 더 열받네요 첨에 9분 걸린대더니 22분 넘어가는데 왜 연결 안됨 그리고 애초에 사람이 40명 넘게 기다린다던데 고객센터 인원을 그렇게 운영하는게 요즘 시대에 금융혁신앱이라 자칭하는 데에서 할 짓임 아니 채팅 상담으로라도 해결되게 해주던가 내가 문의하는 내용은 반드시 전화해야 된대  진짜 열받아서 별 한 개 줌',
#  '송금할 때 잘 쓰고 있는데 지원금 5천원쿠폰 그만 좀 띄우면 안되나요 얼굴 인증하기 싫은 사람도 있어요',
#  '토스 좋아요',
#  '알림 끄는거 개선좀해주세요 하나씩 일일히 꺼야되고 중복도 많고',
#  '광고 안눌려요',
#  '비슷비슷한 퀴즈 등이 많아서 출석 한것 같은데 안한거로 되어있다던가 함 차별화가 피요하다봄',
#  '업데이트좀하세요 s25이고 요금도 115000원짜리 쓰는데 이렇게 버벅대서 어플 쓰겠어요 아이폰쓸땐 잘됫는데 이해할수가없네 요며칠전뷰터 심각하게 버벅대여 주식하는사람들이 많아져서 그런가',
#  '광고가 지나치게 길어졌고 꼼수가 심해졌어요',
#  '업데이트 이후로 환율 위젯이 혼자 깜빡깜빡 거려요 아무것도 안보이다가 텍스트 보였다가를 반복합니다',
#  '주식 출석이벤트 때문에 토스 자쥬갔는데 50원주는게 뭔 일이람',
#  '앱 용량이 너무 커요',
#  '최근 업데이트 이후 최중요 토스트 영역에 토스 쇼핑 광고가 생겼어요 광고를 끄거나 토스트를 없앨수도 없어서 주거래 은행을 바꿀 예정입니다',
#  '개발자님 보세요 업데이트 미루다 최근에 업데이트 해서 사용중인데 앱 최적화 폭망인데요 실행시키니 한참 지나서 들어가지고 메뉴이동하고 송금 하는데도 렉 쩌네요 암걸릴거 같아요 평점이 왜 3점대인지 모니터링 좀 하시고 앱좀 가볍게 새로 업데이트 부탁 드립니다',
#  '배송지 주소 잘못 나와서 괜히 배송비 추가 8천원이 나왔다 기입한대로 나와야지 왜 다른주소가 써지냐 이런 사태 다른 쇼핑에선 단 한번도 없었다 다시는 토스쇼핑 안쓴다 몇 배를 손해본거야 네개는 더 살수 있는 걸 생돈 날리게 하고 앞으로도 영원히 여기 쇼핑부분 쓸일 없을 것이다 심지어 냉장식품회수를 이틀뒤에 하네 다 썩었어 괜히 조금 싸게 사려다 식재낭비 돈낭비 시간낭비 정신도 낭비됨 정말 다시는 쓰지 않을 것이다',
#  '앱에 너무 많은 걸 담아서 그런지 속도가 갈 수록 늦어지네요 갤s25 사용자입니다 매번 캐시 삭제할 수도 없고 예전에는 진짜 짱이었는 데',
#  '렉이 심해요',
#  '쓸데 없는 알람을 끄는데 쓸데 없이 제한이 있어서 결국 토스 알람 전체를 꺼버림 고양이 키우기를 쇼핑이랑 엮은 후로 계속 불편해져도 참고 했는데 자꾸 이러면 걍 안함',
#  '시간사기치는 광고 투성이 다들머라하니까 사기치는 광고만 나옴 1점도 아깝다',
#  '혜택 상품 구경하고 포인트 받기 같은 옵션 선택하기 란의 서비스에 문제가 많습니다 토스 측에서 요구하는 옵션과 광고 사이트에서 제시하는 옵션이 전혀 다른 경우가 많고 예 선택해야하는 옵션 그린 실제 선택가능 옵션 레드 블루 옐로우 뿐 분명 올바르게 옵션을 입력해도 옵션을 선택해주세요 라는 문구만 뜨며 진행이 안되는 경우가 많아 어쩔 수 없이 다음광고로 넘겨서 몇십번을 뺑뺑이를 돌아도 도저히 진행이 안됩니다 제발 사전에 요구하는 옵션과 제시되는 옵션이 일치하는지 확인하고 오류도 좀제대로 점검해주세요 미니앱 중 하루스토리 랑 두쫀쿠 돈모아 도 문제가 많습니다 분명 두쫀쿠를 충분히 클릭했는데도 광고가 나오질 않아 시간 낭비만 하는 경우가 많고 웹툰 웹소설을 읽고 광고보고 포인트받기 를 클릭해도 광고가 나오질않고 오히려 미니앱이 멈춰 강제종료를 해야하는 경우가 잦습니다 이전처럼 30분 뒤에 다시 시도해주세요 라는 식으로 대충 넘기지는 않길 바랍니다',
#  '요즘 토스 앱을 열면 화면 하단에 쿠폰과 지원금 등 광고팝업이 뜨는데 이게 굉장히 불편하네요 밀어서 지우려고 하면 토스쇼핑으로 넘어가져 자동으로 없어질 때까지 기다리는데 화면도 가리고 거부감이 생깁니다',
#  '쇼핑 관련 토스트 하단 알림바 좀 그만 띄우세요 쇼핑 키우려는건 알겠는데 뭐든 적당해야지 매번 띄우면 어떡합니까 메인이 금융 아니에요 너무 거슬려요 제발 쇼핑 토스트 떳다 사라지는거 그만 보게 해주세요',
#  '도대체 생계비계좌를어디서만들어요 아무리검색해도안나오는데요',
#  '미션 이따구로 할 거면 띄우지를 말던가 그간 쌓은 이미지 스스로 까먹는 역겨운 앱',
#  '2022년부터 토스증권 함 토스증권 출금완료 뜬뒤 출금해야 미수 안남 주식 수수료 0 5 거래세 0 5 ndaq spgi 두종목 사면 미국주식 전종목 사면서 알아서 위험관리도 다 되고 평생 우상향임 미국주식 세금 25  미국주식 데이장 애프터장 프리장까지 24시간 거래됨 WeBull APP으로 마켓 섹터를 봐서 플러스 높은 섹터본뒤 정배열 차트에 오르는 주식 개별주 몇개 분산 장기투자 토스증권 복기 결과 내가 미국주식으로 잃는 이유 오르다가 떨어질것만 사서 오를것만 사면 다 수익남 2019년 코로나19 폭락장 2022년 금리인상 및 우크라이나 전쟁 폭락장 2025년 ai버블 폭락장 3년주기로 폭락장 옴 40 이상 폭등한 주식은 금방 폭락함 애플 테슬라 팔란티어 패스틀리 전부 다 NYSE 상장했다가 NASDAQ으로 이전 상장됨',
#  '손닿는 곳에 페이스페이 광고 좀 그만 띄워줬으면 좋겠습니다',
#  '죄송합니다',
#  '해외 와서 결제를 전혀 못 했습니다 토스뱅크 하나만 들고 왔는데 토스 진입 자체가 아예 안 되네요 휴대폰을 껐다 켜도 캐시를 지워도 데이터를 지워도 그냥 앱을 지웠다 깔아도 알 수 없는 오류가 뜨며 들어갈 수기 없습니다 인터넷 5G로 잘만 되는 환경이고 이틀동안 해외서 잘만 되다가 갑자기 안 되구요 페이 창도 안 열려서 현금으로만 겨우겨우 결제했내요',
#  '토스의 다른 서비스를 이용하려는데 뭔 뭘먼저해보겠냐고 딱 3개 서비스만 띄워놓고 홈으로 가지지도않고',
#  '앱이 1월 기준으로 멈춰서 업데이트가 안돼요',
#  '토스증권 어플은 따로 분리해서 만들어야 할 듯 하네요',
#  '요즘 인간적으로 증권쪽 너무 느리다 이래서 큰손들이 쓰겠냐 너희가 검색도 쉽고 커뮤니티 연결해서 사용하기에 다른 증권앱에 대비 정말 보기좋거든 근데 요즘 불장이라고 서버가 너무 느려 나도 판매할때 호가가 움직이는거 놓칠까봐 겁이나 한두푼도 하니고 몇십 몇백만원씩 움직이는데 요즘 옮길까도 고민돼',
#  '언젠가 토스증권에 api를 활용한 트레이딩뷰 웹훅 연동이 가능해졌으면 좋겠어요 항상 잘 이용하고 있습니다',
#  '갈수록 혜택을 줄이려고 악을 쓰네 광고도 선을 넘고 고양이는 니들이 키워봐라',
#  '기업은행 사업자계좌도 연동 되게 해주세요 뱅크샐러드랑 기타 은행앱에서는 연동이 되어서 잔액이 보이는데 토스만 연결만되고 계좌조회랑 송금 등 기능을 사용 할 수 없네요',
#  '페이스페이 등록화면에서 멈춰서 결제가 안되유',
#  '왜 갑자기 앱 안에서 안눌려요 송금도 못하고 포인트 모으는 것도 안돼고 정말 화나네요',
#  '미션들 검색도 제대로 안되고 정답입력해도 틀리다 나오고 로딩도 심하고 문제해결이 되긴하나요 솔직히 별 하나도 아까운 정도입니다',
#  '굿굿굿',
#  '최근 업데이트 한 이후 앱이 버벅거립니다',
#  '갤럭시 웨이러블 연동 해주세요 애플은 연동 되고 갤럭시는 안되다는게 좀 그렇네요',
#  '은행앱인지 쇼핑앱인지 제일 짜증 나는거 쿠폰 알림 100원 뽑기 한마디로 개짜증',
#  '잘쓰고 있는데 처음에 비해 점점 메인 화면이 직관적이지 않아져요 증권 계좌에 예수금 평가금이 왜 다 펼쳐져서 보여지나요 클릭도 되지 않는데 굳이 펼쳐져 보일 이유가 없을것 같은데요 계좌 목록만 더 길어져서 스크롤 많이 내려야하고 헷갈려서 불편합니다',
#  '1 계좌 불러오기 하는데 새마을금고가 없어 여러번 추가 요청하기 했는데도 거의 한달째 없고 저축은행 투성이고 안되면 일부 금융기관은 연결이 불가능 하다는 안내사항 이라고 있던가요 2 라이브 마켓 방송을 보고 나오면 랜덤으로 다음 방송 보라는 화면이 나오죠 문제는 이런 경우 혜택이 마감된 방송이 나와 포인트를 못 받을수도 있어요 몇번이나 이렇습니다 이럴거면 각 방송 볼때마다 포인트를 주던가요 무작위로 다음 방송 보라고 해놓고 뭔가요 3 토스 행운퀴즈 알림받기는 해도 알림 오지도 않으면서 왜 있는거죠 전체적으로 오류 투성 난무 종합선물세트 입니다 이건 뭐와 비슷하게 떠오르는데 일단 여기까지만 합니다',
#  '토스 짱',
#  '잔액 업데이트가 정말 너무 느립니다 며칠이 지나도 잘못 나오는 건 이제 기본이네요',
#  '주식 하고 있는데 왜 갑자기 이동평균선이나 볼린저밴드의 가격이 없어진 겁니까 그냥 빈칸으로 나와버리네요 이러면 주식 토스로 못하지',
#  '내 카드에서 앞으로 납부해야 하는 신용카드 금액의 총합 표시가 없어서 불편합니다 납부해야 하는 카드 금액 총액도 표시해 주세요',
#  '업데이트 할때마다 광고 넘어기는거 제대로 되지도 않고 멈춰버리고 매번 짜증나게 업데이트는 자주 되고 좀 확인좀 합시다',
#  '돈은 누락되고 결제는 안되고 백그라운드에서 꺼지고 앱좀 제대로 쳐만들어 시간 낭비하게하네 진짜',
#  '며칠 간 쇼핑 메뉴 내 스크롤과 터치가 전혀 작동하지 않고 있습니다 어떤 조치가 필요할까요 일부 타 메뉴도 그러한 상황입니다',
#  '노트10 최적화 좀 해라',
#  '어플내 일부 글자 깨짐 흐림 이 발생하여 채팅상담사 연결하고싶은데 다 챗봇뿐이라 상황설명이 불가능하네요',
#  '쿠폰 쓰는거 싫으니까 매일마다 강요하는거 그만 하세요',
#  '쇼핑 팝업 때문에 절대로 토스에서 쇼핑 안함',
#  '건강서비스에 점찍고 포인트 받기 도형그리기 들어가면 광고보고 미션하기 있는데 이거 광고 무한로딩만 걸려서 시킨데로 캐시삭제하고 재부팅하면 잘되는데 시간 좀 지나면 또 그럽니다 이것때문에 어플 삭제후 재설치했는데도 좀 쓰다보면 또 같은현상입니다 상대적으로 다른거는 행운복권 버튼누르기 광고로딩 잘되는데 유독 건강서비스에 들어가는 미션들 상식퀴즈 맞추기 네잎클로버 찾기 등등 모든 광고가 로딩이 잘안됩니다 점검좀해주세요',
#  '광고 하단 스크롤바 안움직이는 현상좀 고치세요 하루에도 몇 번을 강제 재부팅하고 있어요',
#  '토스 앱 정말 잘 사용하고 있습니다 다름이 아니라 소비 계획을 세우고 싶은데 혹시 예산같은걸 설정 할 수 있는 기능을 만들어 주시면 안될까요 지출내역 들어가서 얼마썼는지 볼 수 있는건 아는데 메인 화면에서 내가 이 카테고리에 얼마나 썼는지 한번에 알 수 있으면 좋을 것 같아서요',
#  '고양이 키우기서 사료나 장난감 광고볼때 오른쪽에 x 뜨는 광고들 안눌러질 때가 많습니다',
#  '그냥 장점이 딱히 없어요',
#  '일주일 방문 미션에 아무런 지역 표시나 사진도 없는 24시도어락열쇠당일설치 검색하면 서울에만 몇십개 나오는 거 아시나요 미션 검수도 안하고 참 가지가지로 사람 갖고 노네요',
#  '에러가 심하게 많음 토스페이 결제 페이스페이 큐알 결제대행 원터치 결제 구글플레이 어플연결결제  오류가 너무 빈번하고 심했는데 일부 해결완료 리뷰수정 1점 3점',
#  '쓰레기같은 어플 맨날 도움안되는 쿠폰 발급로 앱 사용에 불편함을줌',
#  'ui가 매번 바뀌고 숨기고 작아지고 메뉴가 왔다갔다하고 마음만 무겁고 확인이 어렵고',
#  '광고를 다 보고나면 닫힘버튼이 활성화되고 버튼 누르면 나가기가 되어야하는데 전혀 나갈 수가 없고 어플을 완전히 꺼야 나가집니다 광고 오류인 것 같은데 빠른 시정 바랍니다',
#  '쇼핑 팝업 좀 어떻게 안됩니까 끌수있게 옵션이라도 있어야지 이게 멉니까 이런식으로 거부감 생기게 만들면 쇼핑 뿐만 아니라 토스에 좋겠습니까 초심을 잃지 않길 바랍니다',
#  '근래 버그가 너무 많음 대출 유도도 거슬림',
#  '사용성이 점점 나빠짐 이용편의 좋은건 알겠는데 수수료도 높고 1원모으기광고도 길어서 내시간아까움 페이스페이 안쓰려는데 쿠폰으로 알람계속띄워서 짜증',
#  '갑자기 이상한 팝업창이 너무많이떠요',
#  '업데이트 한 이후로 광고 스킵이 안되네요',
#  '광고 x클릭이 안됩니다',
#  '뭐야 내돈 돌려줘요 교환했더니 돈이랑 기프트카드는 다 꿀꺽하면 어떻게요',
#  '입금 출금 내역이 안뜨는 일이 너무 많아요 편리성덕에 너무 애용하는데 이럴때 답답해 죽겠어요',
#  '업데이트 또 버벅 업데이트 언제해요',
#  '개선 안해주는 토스한테 신뢰를 잃어서 토스탈퇴 삭제한 사람이면 개추',
#  '광고가 며칠전부터 멍과함께 인가 인증하는 광고가뜨는데 인증하기전까지 그어떤 버튼도 안먹는데 토스가 피싱범들이랑 손잡은건가요 아님 해킹당한건가요 답변에 답변 토스앱을 몇번이나 껐다가 켜고 해도 똑같습니다',
#  '포인트 주는 광고 X 눌러지지 않는데 해결방법이 뭔가요 앱 삭제하고 새로설치해도 안되네요',
#  '고마운 은행 앱 앞으로도 계 속 토스 이용할께요 토스 앱 관계자분들께 정말 많이 고맙습니다',
#  '포인트 얻지말라고 광고 닫기를 터치 못하게 하는건 뭐죠',
#  '일주일 방문 미션에 저장 링크 공유 넣지 말아주세요 불편해서 못하겠어요 그리고 광고랑 로또 없애주세요 되지도 않는거 이제는 그만 하고 싶어요',
#  '같은 고양이 찾기 너무 어려워 졌어요 장난감 안주려고 난이도 올린거 너무 짜증납니다 쇼핑보기 미션에서 사료랑 장난감을 받으면 매번 사료만 너무 남는데 장난감 받을 수 있는 미션을 좀 넣어주세요 균형이 안맞으니 키우기가 넘 힘들어서 스트레스 쌓여요 포인트 주던것도 점점 줄이더니 고양이 키우기도 힘들게 만들고 갈수록 혜택이 짜져서 앱테크 갈아탈듯',
#  '다좋은데일주일방문미션가끔씩재대로입력해도안된다고하네요 이것때문에일주일30원을못받는일이많아지네요',
#  '광고 보고나서 끄는 기능이 제대로 작동을 안합니다  광고 보는건 보더라도 삭제가 안되니 리워드도 제대로 못받고 성질만 더러워지네요',
#  '금융쪽은 너무 좋은데 혜택에서 광고가 너무너무너무 길어서 이젠 안함',
#  '토스 고양이 찾기미션에서 언제는 장난감 주다가 이젠 사료만 주게끔 바꿨네요 사료만 주지말고 장난감 사료를 모두 1개씩 같이 주게끔 해주세요 사료만 주니까 고양이 경험치가 잘 안 오르잖아요 그리고 고양이 같은 그림 찾기 단계는 8단계에서 6단계로 줄여주시면 안되나요 시간도 가면 갈수록 너무 짧아서 8단계까지 들어가기 힘들어요 옛날에는 같은 그림 찾기에선 그렇게 어렵지 않았다는데 왜 멋대로 시간 조작해서 이용자를 이탈시키나요 그리고 고양이를 레벨5까지 달성시켜서 얻는 브랜드콘 상품을 추가시켜주세요 지금 총 8개 밖에 안되는데 딱히 고를만한게 별로 없습니다 그리고 꾸미기에서 스킨을 추가로 내주시고 모든 스킨에 경험치획득 버프를 부여해주었으면 합니다 지금 사료보단 장난감 수급이 매우 저조한 상태입니다 제가 말한것들만 개선해도 떠나간 이용자들 많이 복귀할 겁니다 제 피드백 꼭 보시고 바로 실행시켜주세요',
#  '업뎃하고 보는게 너무 불편해졌다 기존이 눈에 더 잘들어오고 보기 좋았다 롤백해주세요 현재 25 08 01 22시30분 부터 현재 39분까지 로그인은 되나 증권창이나 거래창으로 안넘어가집니다 고객센터창도 마찬가지 일부러 이렇게 만든건가여 최근업뎃후 복권 로또 최대20원 영상시청후 먹통이네요 확인바랍니다',
#  '토스쇼핑 구경하기 보다보면 자꾸 앱이 재실행됩니다 이게 직접적인 원인은 아니겠지만 토스보다가 휴대폰이 갑자기 나가서 메인보드도 나갔어요 개선좀 하세요',
#  '여기에 쓰는게 맞는지 모르겠는데 몇몇 짧은 리워드 광고 저만 잘 안 닫히나요',
#  '토스 정말 잘 쓰고 있습니다 다만 몇 가지 요청 사항이 있어요 우선 첫째로 토스 교통카드를 쓸 때 잔액을 조회하려면 카드를 대야 하죠 그 전까진 최근에 조회한 잔액이 표기됩니다 따라서 이 시스템을 카드에서 잔액이 결제되거나 충전될 때마다 자동으로 잔액이 바뀌어 표기되도록 바꿔주실 수 있는지 여쭙습니다 둘째로 체크카드로 결제를 할 때 어디에서 얼마가 빠졌는지가 나옵니다 그런데 여기서 혹시 어떤 물품을 구입하였는지도 표기를 할 수 있게 해주실수 있는지 여쭙습니다 이 두가지 사항이 가능한지를 여쭙고 구현이 어려운 경우에는 그 이유를 알려주시면 감사하겠습니다 좋은 앱 만들어 주셔서 감사합니다',
#  '편리함에 많이 쓰고 잇는데 혜택에서 주말버튼 누르기 및 혼화면에서 토스뱅크 업무 볼때 버튼이 작동을 안한네요 이만큼 편한게 없어 모든 업무 토스로 다하는데 갑자기 어제부터 안되는건 왜 일까요 참고로 저 갤 폰 변경한지 한달 되엇고 최신버전에서 사용함',
#  '요즘 계속해서 광고본후 나가기및닫기 클릭이 안돼서 아예 전체닫기하고 나가야 하는데 빠른시일내에 개선 해주세요 유료광고 없애주세요 이광고들이 닫히는게 안되요',
#  '아니 고양이키우기 예전이 좋았었는데 광고도 네  좋은데 재생버튼 누르면 광고창이 사라져야되는데 계속 반복되네요 매일출석 어찌하라는건지 광고도 너무 많아졌어요',
#  '고양이 사료만 오지게 주네 100개받기는 시간 줄여서 장난감 받기 힘들게 만들어두고 찾기미션은 전부다 사료만 주고있어 정말 열심히 안주려는 의지가 너무나도 보인다 백날 사료만 주면 뭐하냐고 정작 레벨업할 장난감이 없는데 그렇게 사료만주면 그걸 누가 하겠냐고요 뭔 쉽게 받을 수 있게 바뀐다더니 이정도면 회원들 농락하는거다',
#  '토스에서 쿠팡냄새가 물씬',
#  '고양이 키우기 8단계 진짜 장난하나 니들 부모한테 이거 풀어보라고 해봐라 퍽이나 되겠냐 우리 부모님 이거 하다 화병났다 니들이 병원비 내줄래',
#  '통합 목록 들어가는 거 너무 번거로워요 안그래도 앱이 무거워서 로딩이 빠릿하지도 않은데 전체 목록 보려면 모두보기 누르고 전체보기까지 두 번이나 눌러야됨',
#  '시스템에 문제가 생겼다면서 아무것도 안됩니다 중요한 결제 해야하는데 왜 이런가요 시스템이 전체적으로 안되는건가요 아니면 저만 이런건가요 제발 고쳐주세요 확인이고 뭐고 하나도 안돼요 근데 옆에 광고랑 토스쇼핑  그건 아주 정상적으로 뜹니다 이게 뭐죠',
#  '광고 좀 적당히 해라 어플이 쓰레기인게 알람광고 다 꺼도 광고팝업띄움 회사가 초심잃어가고 광고에 집착하고 사용자편의 역주행중',
#  '와 진짜 어이없네  아니 왜 토스 페이 충전을 왜 자동으로 5만 원씩이나 빼감 5천 원짜리 상품 사는데 5만 원씩이나 빼갈 이유가 있어요 만 원만 빼가면 되지 어휴 그리고 계좌로 옮기려 하니까 3일 뒤에 나 옮길 수 있단다 님들 잘보고 동의하셈',
#  '토스 이름 안바꿔짐 메시지 인증까지 했는데도',
#  '엄청 조잡한 토스 어플 은행 쇼핑 주식 이것저것 닥치는대로 한어플에 다 쑤셔 넣는 토스 이러다가 재래시장도 열겠네',
#  '토스앱은 잘쓰고 있는데 토스앱에 증권이 없어졌어요 그런거는 어떻게 하면 되나요',
#  '일부 광고 X 클릭 안되는 오류 빨리 수정바람',
#  '토스에서 같은 옵션 선택 포인트 기능에서 계속 품절된 상품만 대부분 나와요',
#  '제발 부탁드려요 찾기미션 하지말아 주시던지 버튼을 눈에 안띠는 구석탱이에 놔둬주세요 자동으로 찾으면서 품절되거나 판매중지된 상품만 용케 찾아내는거 대단하시네요 덕분에 멈추고 강제중지해서 다시 실행시키기를 몇번째인지 점검이라고 허구헌날 뜨던데 도대체 관리가 이런식인지 별점 마이너스있으면 좋겠네요',
#  '현재 일본현지인데 로그인이 되지 않음 다른 은행 어플 접속 가능 확인',
#  '한가지 아쉬운건 계좌 상세 내역보기 가 없다는 예 압류상태 휴면상태 중지상태 등등',
#  '토스 업데이트 이후 주식 모아보기가 말도 안되게 느려졌고 추가로 낮에는 국장이 밤에는 미장이 상단에 올라오던게 국장이 상단에 고정되는 방식으로 다운그레이드 되서 너무 불편합니다 예전 버전으로 롤백해줬으면 좋겠습니다',
#  '토스를 꾸준히 사용하고 있습니다 1원씩 모으는 포인트 대해서 여쭤 볼려고 합니다 일주일방문 미션중 하나를 하고 포인트가 들어와야 하는데 금액을 보니 아직 5원이 지급되지 않았네요 바로바로 들어오겠끔 시스템좀 바꿔주셨으면 합니다',
#  '토스 한달전 부터인가 너무 로딩도 느리고 금액도 늦게 나오고 너무 답답합니다 저만 그런건가요',
#  '쓸데없이 광고가 많아졌고 광고가 짧았는데 길어졌고 생각없이 하는거 같아요',
#  '송금시 얼마전에 송금완료 사운드 알림이 있었는데 지금은 사라졌네요 다시 사운드알림 기능 복구 바랍니다',
#  '대출갚은지 8일짼데 20원 아직임 고양이 광고번잡해서 안한지 오래됬고 그냥 송 금 만',
#  '계좨전체보기 자산편집하기 순서바꾸기 에서 투자 증권도 순서변경가능하게 해줘요',
#  '결제한 내역 메모를 적고 완료를 누르면 바로 안뜨고 결제목록으로 가야만 메모한게 보여요',
#  '아니 뭔 모바일 인가 그걸로 1000원 충전하고 버스에 탈려니까 인식도 안돼고 여러번 했는데도 실패 케이스 빼고 했는데도 실패 청소년인데 자꾸 1500원식 내지고 600원에 맞춰서 하면 잔액이 부족한다고 뜸 처음에 뭐 그럴수도 있지라고 생각했는데 갈수록 심해지네요 아 진짜 도움에 되는게 뭐에요 별점 주는 것도 아깝습니다',
#  '돈에 환장했네 40초가 넘는 광고 뿌려두면 미쳤다고 토스 씀 쓰레기 어플',
#  '주식 판매 구매예약 취소가 반복되는데 알아봐주세요',
#  '배당금 한번에 보는 게 타증권사들이 포함이 되어있지 않아요',
#  '최고입니다',
#  '아 진짜 페이스페이 사용하게 하려고 커피쿠폰 공짜로 준것 사라지는 것처럼 알림을 몇번을 며칠동안 띄우는 건지 광고를 해도 정상적으로 해야지 피싱 사이트도 아니고 뭐하는 짓인지 증권도 옮겨 올까 했는데 짜증나서 안되겠네',
#  '토스페이 잘 쓰고는 있는데 쓸모 없는 광고를 너무 보게 해서 불편합니다 차라리 이벤트도 없애고 광고도 보고싶지 않아요',
#  '요앱이편하다고씁답니다',
#  '만보기든 돼지저금통이든 보상주는거 아니면 며칠달성 그런 쓸데없이 창 뜨지 않았으면 좋겠어요 페이스결제등록해야만 되는 쿠폰도 그만 남발했으면 해요 피로도만 높아집니다',
#  '토스증권 종토방에서 댓글 작성하려고 작성칸 누르면 기존 작성칸에 있던 문구 중 일부가 자동으로 입력됨 남겨보세요 그래서 댓글쓰려면 작성칸 누르고 저거 지우고 써야함 오류 수정좀',
#  '글꼴은 왜또 밤티되었나요 업데이트 다 해놓은상태인데도 벌써 몇주째 글씨 픽셀 다 깨져있고 보수관리 안하세요',
#  '여긴 상담사가 갑입니다 이런데 처음봤습니다 쇼핑도 쿠폰도 주먹구구식으로 운영할거면 금융앱으로나 충실했음하네요',
#  '24년 1차리뷰 쓰레기 같은 광고나 보여주는 쓰레기같은 토스의 광고정책 누가 일하고 누가 승인하는 건지 한심한 앱으로 변질 중인 것이 안타깝다 26년 2차리뷰 정신 바짝 차리고 광고지뢰 조심하면서 투자를 가장한 커미션 장사를 알아볼수 있는 사람만 쓸 것 쓰다보니 정들어서 별하나 더 준다',
#  '고양이 맞추기를 8단계 18초로 했네요 하지말라는거죠',
#  '광고 그만해라 쓰기 싫어진다',
#  '아이통장 만들기로 증권계좌 만들었는데 잠금을 풀려면 신분증이 필요한게 말이됨 아이한테 신분증이 있을거라고 생각하는거임',
#  '준 쓰레기 왜 투자 모아보기가 안맞나요 미국주식 퍼센트는 한화 달러 안맞은지 1년은 된거 같은데 심지어 남의회사꺼가 안맞다면 이해라도 해주지요 니네꺼가 안맞아요 이젠 한화수익 금액도 안맞고 앱에는 오류신고도 없고 드러워서 갈아타던가 해야지',
#  '앱이 있어야만 사용 가능한게 아니꼬와서 1점 주고 시작합니다 써보고 나중에 리뷰 수정하던가 하겠습니다',
#  '두근두근 1등찍기 선택하고 돌아가면 로그아웃되서 선택을 못하네요',
#  '업데이트가 자꾸 실패하는데 원인이 뭘까요',
#  '진짜 짜증남 토스증권 토스은행 이걸로 쓰는데 로그인도 안되고 사람돌게함 화면이 멈춤 고객센터 전화하니 삼성폰이라 충돌이 있다고 토스 캐시를 삭제하고 안되면 토스를 다시 깔아라고 하는데 몇번해도 안됨 못쓰는 앱임 진짜 내가 안써야지 아 스트레스받아',
#  '이니 쇼핑광고 팝업 안뜨게 설정이라도 하게 해줘야지 이게 뭡니까 강매시키는 겁니까 이딴 앱이 다있노',
#  '홈 들어가면 쓸데없이 쇼핑 쿠폰 5 000원 알림을 하루에 몇번을 보게 만드는거임 증권밖에 안하는데 왜 자꾸 잡스럽게 이것저것 띄우는건지 전체에서도 ui 은근슬쩍 자꾸 바뀌는데 바뀔때마다 점점 조잡해지고 눈에 거슬리는게 늘어남 화면을 쓰는사람이 편집할 수 있게 해주던가 쓰지도 않는 잡다한 앱서비스 자꾸 늘리는거임 갈수록 왜이러냐 담당자 바뀜',
#  '잘 쓰고 있었는데 업뎃하고 투자내역 자산현황 보는게 너무 불편함 총자산 실시간 업뎃도 안됨 이전으로 돌려줘요',
#  '얼굴 정보 뜯어가려는 의도가 너무 뻔히 보여서 불쾌한 앱 2차인증 다른 방법 쓰기 이름 대조 로 바로 넘어갈 수 있는걸 왜 얼굴정보 필요하다는 내용을 띄워서 시간을 질질 끄나요 심지어 각도별로 찍어야하는데 잘 되지도 않음',
#  '안녕하세요 운영장님 저는 2 3년째 토스를 사용중인 예비 고1 입니다 현재 90 할인으로 더블 파워 그립링을 300원에 구매할려고했는데 잠시 확인할려고 나갔는데 자동 결제가 되었습니다 혹시 자동 결제되어서 제품이 집에 오는건지 안 오는건지 모르는데 갑작스럽게 결제되었고 결제된 물품의 목록에도 없어서요 어떻게 된거인가요',
#  '어느날 갑자기 토스증권이 안열리는데 왜 그런건가요 어이가없네',
#  '1점도 아까움 광고 넣은거 보면 이젠 선넘었단 생각밖엔 안듬 업데이트 기획안 넣은 사람도 그렇고 그걸 승인하는 것도 보면 이제 토스는 딱히 토스가 대체불가 카톡이 아닙니다',
#  '업데이트 후에 자산목록 모아보기가 퍼센트로만 나와서 좀 불편해졌습니다 예전에는 금액도 같이 나와서 직관적으로 볼 수 있었는데 아쉽네요',
#  '고양이 장난감 100개 받는 미션 매우 어렵게 바꿨네요 시간도 줄이고 헷갈리게 만드는 것도 추가하면 뭐 그냥 하지말라는거지요',
#  '아직 익히는중 입니다',
#  '광고좀 그만 나오게 해주세요 광고보다 정신병자 되겠어요',
#  '진짜 리뷰잘안쓰는데 1초 5초광고라고 하고 1분넘는 광고 짜증날정도로 개많음 선을 넘은것같아서 슬슬 안하게됨',
#  '주식 지정가알림 내가 설정한 가격이 되면 알림 오는 동시에 지정가알림 내역에서 사라져서 불편합니다 그 가격이 될때마다 없어져서 계속 다시 설정해야하는게 번거로워요',
#  '양아치광고 하는 토스',
#  '2026 2 추가 고양이 키우기 사료와 장난감을 1일 제한을 걸어두면서 분명 짧은 광고를 보면 바로 얻을 수 있게 하겠다 했죠 처음엔 1초 광고만 나오더니 그 이후엔 5초 1초 섞어서 내고 5초 광고들을 거르니 이젠 짧은 광고라면서 1초짜리 보여주다가 말 없이 5초 여러번 닫기 버튼 눌러야하는 광고 로 늘리고 원래 10초 토스상품 구경도 45초짜리로 늘려놓고 광고 너무 많아서 지금 키우는 애만 키우고 고양이 키우기는 안하려 합니다 2025 3 추가 혜택은 혜택대로 다 줄이고 무료배송으로 홍보하던 토스 공구는 이젠 다 배송비 붙고 광고는 엄청 많아지고 앱은 버벅이고 점점 심해져요 방문시 포인트에서 알리페이 구경하고 포인트 받는걸 필수로 해놓고 개인정보 국외이전 동의하라고요 심지어 올출석 하려면 꼭 하게 만들어놓는데 그럴거면 왜 필수로 하는건가요 방문미션이라면서 정보 해외로 보내는걸 조건으로 세우는걸 이해할 수 없는데 뭔가요',
#  '광고 너무 많고 고양이 맞추기 게임 시간도 줄어든 후부터 터치해도 작동도 안 해요 트래픽은 늘리고 싶고 혜택 주자니 비용은 많이 나가서 수정하신 것 같은데 토스 앱 열 때마다 불쾌해요',
#  '아니 증권 너무 느림 버벅거려서 못팔고 못삼 짜증나네',
#  '토스가 자주 실행 되더니 보안 이슈를 느껴서 업데이를 하려고 합니다만 이상합니다    리스트에 테무 광고가 따라다니고 특별 금융법 동의를 요구하고 왜 그런가요',
#  '에러 투성이',
#  '장점 1 자산 관리 만보기 등으로 여러기능 지원 2 한국어 지원 단점 1 자동시작으로 부팅이 느려질 수 있음 2 요즘 라이브방송 적립 클릭해도 안 눌러짐 다시 들어가면 적립은 돼어 있기는 함 3 구글 광고 존재 4 무거운 앱 5 최근에 던킨 쿠폰 페이스결제 5천원 그냥 쓰는 건 줄 알았는데 어느 매장에서도 페이스결제 되는 거 못 봤다면서 5천원 쿠폰 적용이 안돼는 와중에 다른 손님 와서 쿠폰 찾아보니 만원이상 이어야 적용돼는것에 qr코드로 빵집 주인도 찾아서 제 쿠폰 적용 안 한 채로 5천원 쓴 꼴 됌 페이스매장도 던킨에 안 들어오면서 쿠폰도 내용을 토스에서 제대로 알려주지 않아 저 5천원치 빵 손해를 봤네요 그리고 공유 왜 힘들게 만들죠 하루 공유 제한 너무 적어 성공하는데 힘드네요 특히 파파이스 쿠폰 거의 금액 다 됐는데 째끔씩 금액 줄여서 800원에 돈 주고 사 먹고 싶을 정도에요',
#  '임원진이나 경영 전략이 바뀐 것 같아요 직관성이 점점 떨어지는 것 같은데요 옛날엔 한 번에 접근 가능했던 화면이 근래들어 두 번 세 번 만에 접근이 가능합니다 심지어 찾기도 힘들게 돼있어요 경영 저성장에 들어선 것 같은 기업입니다',
#  '새해부터 기분 잡치게 하네요 이벤트를 할라면 기분좋게 합시다 쇼핑해서 받은 뽑기캡슐도 다 던져버리고 이제 토스쇼핑 안합니다',
#  '광고좀 삭제해주세요 자꾸 중간에 멈추네요 고양이카우기나 짜증나게 되네요',
#  '요즘 슬슬 카톡 느낌남 무거워지고 느려지고 클릭 유도 계속하는데 1원씩 주고 대박 나면 5원 주고 예전엔 가볍고 은행앱보다 빨라서 좋았는데 요즘은 그냥 은행앱 처럼 느려짐',
#  '이벤트좀 직접해보고 만드세요',
#  '걸음수 갑자기 안되요',
#  '안그래도 만보기 따위로는 하루에 10원 겨우 받으니 걍 오늘 몇걸음 걸었구나 정도로만 썼는데 페이스페이 자꾸 유도하질 않나 고작 3원 많이 받아야 겨우 10원 받는 시도에 광고까지 태우라 하면 안 쓰고 말지 싶음',
#  '적립 먹튀가 점점 심해지네 고객센터 문의해서 적립해주는게 아니라 30분후 다시 하라하고 미션 참여한거는 적립안됨 광고 다 보고 다시 광고 떠서 뭐지했는데 광고 다보니 이미 적립한 광고라고뜸',
#  '토스 너무 좋아요',
#  '모바일 신분증 불러오기하려고했는데 몇십번해도 시스템에 문제가있다고 뜨는데 제발 좀 해결해봐요',
#  '내자산 불러오기 보면 실거래가 시세가 10 1되어 있음 엉망 관리 할꺼면 앱 안하는게 낫다',
#  '만14세미만이라 허락받는데 절차가 너무많아요 예를들면 휴대폰번호하고 얼굴보여주고 휴대폰번호를 또적어야돼서 복잡합니다',
#  '알람을 계속 끄는데 대체 왜 자꾸 새로운 광고 알림이랑 껐던 알림도 계속오는건데 그냥 내가 받고싶은 알림만 켜둘수는 없는거임',
#  '토스 어플켜고 첫 화면 뜨는게 너무 오래걸립니다 개선 꼭 부탁드립니다',
#  '업데이트 하면서 많이 바뀐 것 같은데 기존에 어플 켜면 바로 나오던 금액이 이젠 굳이 클릭하고 들어가야 보입니다 분명 아무것도 건들이지 않았는데 설정이 바뀌어서 불편해요',
#  '광고 더럽게 많네 은행앱인지 광고 앱인지 업데이트만 하면 광고만 늘어나는듯 고양이 키우기가 아니라 광고 키우기인듯 정말 하라는 업뎃은 안하고 광고만 주구장창 업뎃 열심히 하는거 같음 와 또업뎃하니 고양이키우기 더 귀찮게 해놧네 대단 아니 어떻게 업뎃하면할수록 안좋이져요 광고는 엄청 늘고 편의성은 완전 개판이네',
#  '와 이벤트 받는데 광고 30초 버튼 활성화 되는데 30초 버튼 누르고 광고 5초 그냥 생색내기네요 진짜 더럽고 치사해서 안하고 싶게 만드네요',
#  '페이스페이 광고는 이제 그만',
#  '업데이트 되면서 갑자기 글씨가 번져보여요',
#  '토스 만보기는 어떻케 사용하나요',
#  '로또나 걷기 등 광고시간이 갈수록 길어지네요 뭔 광고 보면 30초 해놓고 나가는 화면 나올려면 다시 30초를 기다려야함 걍 안하고 말지',
#  '굿',
#  '앱이 타 은행앱보다 무겁고 토스 쇼핑은 가격순으로 못보는게 아쉬움',
#  '편리하고 좋습니다',
#  '페이스페이 유도하지 말아주세요 찝찝한 방식을 왜 토스가 유도하는지 고작 5천원 커피권으로 자꾸 카톡으로 보내서 차단했네요',
#  '고양이키우기 그만 좀 바꿔 짜중나네',
#  '재미있고 시간가는줄 모르는 신선한것들이 많아서 좋아요',
#  '대출이 가능한지 불가능인지 확실히 나오게 해줘요 약올리는겁니까',
#  '그놈의 광고 로딩중은 뭘 해도 진행이 안되고 하여간 답답',
#  '개발자야 토스어플 2번정도업데이트하자구',
#  '예전부터 사용중인데 모든 알림이 너무나도 늦어요',
#  '앱인토스 앱에 광고 수십개를 봤는데 계속 에러나서 작동도 안됨 하',
#  '거지마냥 쇼핑 팝업 띄우지마라',
#  '안녕하세요 토스 잘쓰고 있습니다 다름이아니라 건의사항이 있어요 투자내역에 비트코인도 추가해주면 안될까요 저는 업비트로 매달 비트코인을 구매하고 있는데 현재 비트코인 보유량의 원화가치 정보를 업비트나 빗썸에서 가져와서 투자현황을 파악할 수 있으면 좋을 것 같아요 아니면 토스에서 코인 거래소을 만들어주셔도 좋을 것 같아요  저는 지난번에 소비내역을 직접 편집할 수 있는 기능을 요청한 적 있는데 이후에 진짜 계산기 기능이 나와서 감동했어요 혹시나 해서 이번에도 여기에 건의드려봅니다',
#  '별 하나 주기에도 아까운 최악의 어플 중구난방 상담부터 시스템부터 죄다 내놓는 서비스마저 최악 웬만해선 후기도 잘 안 남기는데 오랫동안 이용한 사람으로서 갈수록 실망감만 안겨줬고 10년 이상 잘 이용하고 있었지만 확실히 시중의 다른 은행보다도 못한 한계가 명확함 진짜 문제가 많은 이유가 있고 이리저리 악평들이 달리는데도 이유가 있지 그런데도 토스는 그런 것은 깡그리 무시 불편이 너무 커서 실망했고 토스 이용하는 지인들한테도 앞으로 비추하면서 다른 은행으로 이용하라고 권할 예정 그 정도로 크게 실망했고 그냥 이번 기회에 해지 및 앱 삭제하고 다른 시중으로 이용할 생각임 토스 관계자들은 그냥 고객 불편사항 죄다 무시함 무시하는 것에도 인내가 있는데 그게 결국 한계가 터짐',
#  '토스 접속은 되는데 그외 터치가 안됩니다',
#  '다괜찮은데 체크카드로 해외결재안되나요 신청은있나요 오프라인재외',
#  '다른 앱과 달리 토스 앱에서만 글자가 조금씩 깨지거나 뭉개지는 현상이 계속 발생합니다 기종은 갤럭시 S25fe입니다',
#  '광고시간 넘 구라가 많음 5초라면서 30초도 나오고',
#  '알림받을때 열어요',
#  '최악',
#  '통장 만들기 본인이 맞는지 확인 하는게 너무 오래 걸리네요 무슨 의도인지 모르겠지만요',
#  '잔액이 왜 새로고침해도 업데이트가 안되죠 업데이트 진짜 뭣같이 해놓으셨네',
#  '요즘 너무 느려지네요 버벅여서 이동도 힘들고 주식 구매하기도 불안정하고 왜이런거죠 다른 댓글 답변 캐시제거도 완료했구요 그냥 무거워서 그런건지 사용성이 많이 하락했어요',
#  '너무 복잡해요',
#  '고양이 키우기에서 집사미션 보상이 고양이 밑에 떴었는데 안떠서 메뉴창에 들어가야합니다 자난번에도 이래서 남겼다가 돌아왔었는데 지금 또 이러네요',
#  '죠아요',
#  '증권이나 여러 유용한 정보를 얻을수 있어서 쓰기 참 좋습니다',
#  '개발자가 힘들면 사용자가 편리하다의 예시',
#  '장난합니드까 무슨 인증을 수시로하냐고 적당히좀합시다 당신내도 bd다팔먹는거뻔히아는데',
#  '토스덕분에 걷기하고 돈벌고 건강 해졌어요 감사합니다',
#  '앱이 점점무거워지네요 캐시삭제해도 같음 카카오페이로 갈아탐',
#  '토스증권에서 주식매수 할때 매수 물량 전체 클릭하면 보유한 원화나 달러 잔고 내에서 각각 전체 수량 선택하는 기능이 있었으면 좋겠어요',
#  '같은 고양이 맞추기 제한시간 자꾸 줄어들고 광고는 길어지고 난리도 아닌데 그 마저도 기재된 시간보다 광고재생이 초과되는 식 이제 유저가 충분하니까 혜택 줄이고 카톡처럼 가는 거지',
#  '솔직히 내가 써본 은행 관련 앱 중에서는 단연 최고라고 할 수 있음',
#  '개쓸데없는 인터페이스 업데이트 그만좀 해요 진짜 깔끔한 인터페이스 때문에 토스 쓰는건데 자기네 장점을 스스로 없애버리고 있네 회사의 어디가 뇌가 없어야 이런걸 업데이트라고 내는건지 궁금할 지경이다',
#  '방문미션할때 네이버로찾고 들어가면 처음으로돌아오고 찾으면 또 다시 찾으라고하고 개선좀해요',
#  '버튼 눌러지지가 않는다',
#  '토스증권렉이심해요',
#  '토스 고양이 키우는 재미로 하는데 100개 받는 보상 너무 말도 안되게 어려워졌어요 불가능한 수준 적당히 올려야지 이게 말이되나요 최악이네요',
#  '평소 너무 잘 쓰고 있습니다 근데 갑자기 몇시간 전부터인지 앱이 자꾸 팅겨서 작동이 안되네요 주로 쓰고 있는 게 토스뱅크라 안되면 많이 불편한 상황인데 빠른 조치 부탁드립니다',
#  '여자분이 나오는 전담광고 속삭이는 말투로 속옷 차림으로 광고 하는거 듣기 거북하고 민망합니다 금지시켜던가 퇴출바랍니다',
#  '얼굴정보를 고작 5000원에 사려고하네 미친거임',
#  '여기가 뭐 중국도 아니고 그놈의 페이스페이 좀 그만 하면 안 됩니까 얼굴로 뭔 결제를 하겠다고 그리 광고를 해대고 알람을 자꾸 띄우는지  돈 옮겨다니는 은행증권사가 한국사람 인식에 얼굴 팔아 돈 거래하는거 안 내켜하는걸 왜 모를까요',
#  '예전엔 빠릿했는데 지금은 무거워져서 느릿느릿 못 쓰겠어요',
#  '부동산 가격 표시 시세로 바뀐 이후 하루에도 몇번씩 제멋대로 올라갔다 내려갔다 하네요 실거래가가 3억이 넘는데 갑자기 왜 2억으로 표시되나요',
#  '주식차트에 매매 판매 표시가 잘 안돼요 특히 미국주식은 거의 안되네요',
#  '만보기 복권 확률조작 해명하라',
#  '제발 고양이방 꾸미기 다시 내주세요',
#  '학생이라 그런지 같은 계열의 다른 앱들보다 접근하기도 쉽고 사용하기도 쉽다고 느꼈습니다 기본적인 시스템 관리나 저 같은 학생들도 쉽게 사용할 수 있도록 되어 있어서 굉장히 유용하다고 느낀 앱이에요 아직 카드가 없거나 돈 관리가 필요한 친구들은 토스를 사용해보는 것도 좋은 방법이라고 생각합니다',
#  '올해 ui업데이트 이후로 엄청 불편해졌어요 아니 점점 불편해지면 어쩌라는거에요 그냥 냅두세요 아 짜증나죽겠네요 인터페이스가 다 바뀌어서 평소 가던 메뉴를 찾을 수가 없어요',
#  '페이스페이 등록한걸 취소하는 방법 알려주세요',
#  '렉도 자주 걸리고 가끔 며칠씩 사용내역이 안 올라오다가 올라온다 싶으면 중복으로 떠서 직접 본래 뱅킹앱을 따로 찾아봐야 할 지경입니다 신경 좀 써주세요 와이파이 환경에서 해도 그래요',
#  '광고 초 줄이는거처럼 하다가 왜 삼십초짜리 보여주세요 사료 받기 하는데',
#  '업데이트만 하면 안되고 계속 재설치 해야함',
#  '편의상 토스로 내 재산총액을 확인하는데 자산변화도 제공되는데 이건 완전 엉터리로 나와서 안보네요 특정자산은 아예 전달에 0원으로 평가되는 오류가 있네요',
#  '이놈들은 중국한테 넘어가서 그런가 이벤트 해놓고 쿠폰 쓸려면 얼굴 등록 하라고 하네',
#  '제발 할인쿠폰 5천원 그만좀 알림 보내세요 사고 싶으면 말아서 살텐데 매일 5천원 쿠폰 사라진다고 알림오는것 때문에라도 탈퇴하고 싶어지네요',
#  '주식 차트 선 그리기 기능에 개선이 필요함 차트 보려고 확대하면 자꾸 새로고침됨 가끔 차트에 선 그리기 해도 아무선도 나타나지 않는 버그가 있음 트레이딩 뷰 보고 참고좀 해야할듯',
#  '설치가 불안하네요 1분이 걸리고 설치해도 열리지 않아요 폰 새로 켜도 설치에 1분 째',
#  '토스증권 렉이너무심하니 토스증권어플 따로만드세요',
#  '최근 광고에 대해 한 말씀 올립니다 되도록 언더웨어 광고는 연결이 안 되었으면 합니다 대중교통에서도 오해받고 조카들도 오해하고 수시로 그런것만 보는 변태취급받습니다 지금 1 5원 벌자고 변태프레임을 얻는건 너무 수지가 안 맞는거같네요',
#  '같은 고양이 맞추기 게임 8단계 시간 왜 이렇게 많이 줄였나요 절대 끝까지 못 맞추게 해놨네요 게다가 게임 기회도 1회로 줄어들고 진짜 못됐네요',
#  '편해서 쓰기시작했는데점점 광고판이되어가고있고 광고때문에 불편하네',
#  '갑자기 증권 종목별 계좌 수익 현황이 제대로 보이지 않네요 수익률만 보이고 수익금 내역이 없어서 불편합니다 토스는 기존 증권사들에 비해 챠트 시인성도 떨어지고 주문창도 구성이 별로이고 공시도 보기 힘든데 토스뱅크에 연결해서 조건주문 등 주문 기능이 쓰기 좋으니 쓰는겁니다 증권 사용이 더 불편해지면 기존쓰던 미래에셋에 갈 수 밖에 없어요',
#  '알림을 왜 없던걸 만들어서보내고 끄지도못하게하고 해서 그냥 다 끄고 쓸게 토스 알림중에서 쓸모있는게 있어서 켜놨는데 창조알림이라 사용시 굉장히 불편함',
#  '메인화면에서 전체 자산 나오고 투자중인것만 따로 클릭해서 한번에 볼 수 있는거 좋습니다 근데 왜 가만히 잘 있는 ui를 말없이 바꾸시나요 바꿀 때마다 제외한 자산 퇴직연금 등 이 자꾸 투자 전체합계에 합산되어 나와서 빡칩니다 그리고 이번 ui는 개별종목 수익금도 못봐서 하나하나 클릭해야하니 그것도 불편하고요 지난번 업데이트는 한 일주일지나서 제외자산 제외시켜주더니 이번에는 언제 제외시켜주실건가요 너무 불편하고 왜 업데이트할 때마다 제외자산 제외 안 시켜주는건지 테스트 좀 제대로 해주시고 올려주시면 안됩니까',
#  '이벤트 장난질 에 케이뱅크로 슬슬 예적금 옮기고 있습니다 실컷해도 이벤트 쿠폰 사용소진으로 쿠폰 사용 날짜보다 빨리 끝내버리고 금액 정해진 포인트 쌓는 건 공유 열심히 해도 택도 없고 흥 옛날 토스가 그립네요 그래서 케뱅으로 갑니다',
#  '토스쇼핑몰 쓰레기 팔아놓고 환불 못해줘서 죄송하답니다 쓰레기토스하는 토스쇼핑몰 판매자는 문닫고 검색도 안되네요 별 1개도 아깝구려',
#  '업데이트되고 터치가 안되네요 다른 어플들 다 더치가 되는데 왜 토스만 들어가면 터치가 안되는건가요 포인트 받아야 하는데 아무것도 안되요 이럴거면 업데이트를 안했을텐데 업데이트 하지 마요 터치 안되요',
#  '이 앱 신고합니다',
#  '다 좋은데 자산 변화에서 투자를 빼면 어떡합니까 비중이 제일 큰데',
#  '계좌이체등 관리가 용이합니다',
#  '아니 이번 업데이트 왜 한건가요 토스는 간편하게 좋은 초심 잃고 엄청 조잡하게 바뀌었네요 종합계좌 퍼센트만 나오고 금액은 왜 안 나와요 우리보고 계산하라고 하라는건가 다 클릭하란 말인가 생각좀 하고 업데이트 하길',
#  '유용해요 많이요',
#  '다른분 말씀처럼 업데이트이후 증권사CMA계좌가 은행코드대로 순번처럼 증권사도 코드번호로 순서매칭도 사라지고 순서가 투자 항목으로 분리되어서 불편한데 순서도 뒤죽박죽된것도 추가로 불편하고 증권사 종합계좌나 매매계좌나 CMA계좌 모두 그동안 은행처럼 토스에서 같이보여줘서 이체하기도 토스가 편했는데 업데이트이후 너무 불편하게 바뀌었습니다 인터넷광고도 인터넷가입하면 얼마주는지 토스가 토스포인트로 받을수있게 보장해주시던지 했으면 해요 그냥광고로 넣어버리고 중계만 하면 불안해서요 토스가 광고해서 약속한 사은품 토스포인트로 받게 보장해주세요 휴대폰은 잘하면서 인터넷부분홍보도 아쉬워서요',
#  '왜 전체 자산에서 서울페이나 온누리상품권은 안보이나요 네이버페이처럼 포함할 수 있도록 수정해주세요',
#  '명절지원금 당첨 쿠폰 안받는다고 광고좀 적당히쳐해라 진짜 뭐 들어갈때마다 꼬박꼬박 성실하게 묻냐 거절하기도 없고 하 돈 다빼서 카카오증권으로 가기전에 적당히 합시다 진짜',
#  '혜택 활동에서 네이버 광고를 보기 전에 매번 표시되는 네이버의 보안 확인을 완료해주세요 가 불편하고 거기에 나오는 영수증 이미지가 작아서 글자가 보이지도 않습니다',
#  '진짜 진지하게 잔액 변동되는게 너무 느림  고양이 키우기고 쇼핑이고 나발이고 이 앱의 본래 정체성은 금융 서비스를 제공하는 뱅킹앱임 돈이 얼마가 입금되어 전체 잔액이 얼마가되고 이런걸 보여줘야 의미가있지 1 2시간 지나서 갱신되면은 차라리 그 시간에 가까운 은행이나 ATM에서 잔액확인 하는게 더 빠르겠네',
#  '토스 업데이트가 안되는데요',
#  '편리하게 유용하게 쓰고 있어요 앞으로 좀더 좋은 정보 부탁드립니다',
#  'ui좀 그만 건들면 안될까 업데이트 할때마다 가독성 떨어지는데 정말 사용하기 불편하고 보기도 힘들고 찾기도 힘들고 구분도 안되고 어른들이 왜 큰글씨 은행어플을 사용하게 되었는지 간접 체험하는중 나도 곧 접을거 같네',
#  '상품 구경하고 포인트 받기 항목이 이번에 새롭게 바뀌고나서 네이버 보안 확인만 무한 반복으로 떠서 사용할 수가 없습니다',
#  '제발 제발 제발 제2의 카카오톡처럼 메신저도 만들어주세요 카카오톡이 금융앱 만든 것처럼 카카오톡 민심 떨어지고 있는 지금 중국 자본 뺐다는 토스가 메신저 앱 만들면 많이들 믿고 쓸거예요',
#  '저만 그런건지 모르겠지만 고양이 키우기 찾기미션 3초 상품 구경하기 에서 네이버 보안확인이 계속 뜹니다 한번도 아니고 3초마다 뜨는건 좀 심하네요  그리고 3초 후 다음상품 넘어가는데 7초나 걸리는 것도 너무 길어요 3초 정도면 적당할 거 같습니다  물론 네이버 측 문제지만 미션을 쿠팡에서 네이버로 바꾼 게 토스라서 여기에 적어봅니다  ex 보안 확인을 완료해 주세요 이 절차는 귀하가 실제 사용자임을 확인하여 계정을 안전하게 보호하고 스팸을 방지하는 데 도움이 됩니다 가게 전화번호의 앞에서 1번째 숫자는 무엇입니까',
#  '고양이게임이 더 어려워졌네요 8단계도 원래 잘 깼었는데 이젠 7단계도 겨우 클리어하는정도로 바뀌어서 어려워요 그리고 복권 당첨은 20원 이상 된적이 몇년동안 단 한번도 없습니다 동일한 확률로 제공된다고 하시는데 의구심이 듭니다 100만원 10만원 이런분들 당첨 멘트도 한결같고 ex 유리거울 꿈을 꾸면 이루어진다 뭐 이런식 다 짜여진뉘앙스가 느껴짐 고양이 복권도 3개 그림 모두 같게 나온적이 진심 한 번도 없어요 이거 확률 공개 해주세요 0 000n퍼센트죠 주작같아요 전화도 잘 안받고 답답하네요 어플자체는 좋고 뭐 이런저런 코너 신설하고 이벤트 해줄려고 하는 취지는 좋아요 좋은데 유저를 조롱하거나 놀리는 느낌이 들면 안되는거죠 그렇지않습니까 350일 연속해서 만보기 출석체크하는것도 무슨의미가 있는지도 모르겠고 굳이 그런걸 강조해서 보여주는것도 모르겠고요 이 글 보시는 관계자분 꼭좀 개선 부탁드립니다 토스 어플 자체는 좋아요',
#  '만보기에서 커피 쿠폰좀 그만 주세요 커피 안 마셔요 안 썼다고 카톡도 계속 보내는데 차단좀 하게 해주세요',
#  '좋음',
#  '고양이 키우기로 장난하는 거 개빡치네',
#  '',
#  '3초 구경하기 네이버 인증 락 걸리게 만들고 짜증 나게 하네',
#  '안녕하십니까아  저는 이앱이 솔직히 너무 좋습니다아 하루에 공부하고 1원받기도잇구 동그라미 뭐시기도 잇구  27000원 이상채우면 이자받기도 있어서 넘 좋습니다  그리고 제가 이앱을하면서 한 100원 정도는 번것같아용 그리고 이앱을 까시면 돈의소중함을 알게 됩니다 뭔 개소리야 그래도 저느은  이앱이좋습니다 그럼 바이바이',
#  '업데이트가 안되네요',
#  '업데이트 후 투자 계좌별 보기가 너무나 불편하게 변했어요',
#  '업데이트 후 투자 화면 UI UX에 불편을 느낍니다 계좌별 보기에서 뒤로가기를 누르면 2번전 화면으로 빠져나오는게 불편합니다 또한 투자 화면에서 연금계좌를 숨김처리 할 경우 전체 자산에서도 숨겨지는것이 불편하네요',
#  '혹시 카드 신청하면 언제쯤 오나요',
#  '갑자기업데이트가안되는 오류',
#  '고양이 키우기에 장난감 100개 주는 짝맞추기 게임이 있는데 이건 인간의 능력으로는 도저히 맞출수 없는 지경의 게임이네요 그 전에는 어떻게든 하다보면 어쩌다 90 넘기거나 다 맞추기도 하고 그랬는데 이건 뭐 손써볼수가 없음 그냥 짝맞추기는 없애는게 낫지 않나요',
#  '너무 많은 광고를 앱을 이용하기 위해서 할 수없이 본다지만 매일 똑같이 지겨운 게임만 내보내지 말고 좀 바꿔가면서 내보내라',
#  '토스에서 편의점쿠폰으로 교환가능한가요',
#  '전체투자정보 보는게 전보다 더 불편해졌어요 전체투자정보로는 잔액이 아닌 퍼센트로만 나와서 터치해줘야하고 연계투자정보도 마찬가지 업데이트할때마다 자꾸 손이 더 가게 만들어서 불편해져요 전처럼 직관적으로 터치가 많이 필요없는 상태가 훨씬 나은것 같습니다',
#  '아니 이거 업뎃 되긴해요 계속 업뎃 불가라고만 뜨고 안되는데',
#  '토스뱅크 이중이체 토스뱅크내 통장 자동이체관리에서 등록한거와 앱 메뉴에서 자동이체 등록한거에 대해 어떤 항목은 두개다 이중이체 처리되고 어떤거는 통장꺼를 중심으로 처리되고 해당건 고객센터 전화했더니 제대로 답변도 못함',
#  '1 포인트 주는 광고에 신경쓰길 대행사에 던지는 줄 모르지만 3초 보라면서 5초 5초 보라면서 5초 하나 더 게임광고는 진행상황 표기도 없고 1분 하고 추가 13초 더 모든 광고는 누르기 힘든 X 몇 번을 더 눌러야 하고 잘못 누르게 유도함 2 얼마 전 생긴 건강 메뉴 세부 메뉴가 난삽해서 뭐가 뭔지 모름 물 마시기는 먹통되어서 사용하지 않는데 알림은 계속 오고 포인트에 비해 광고는 길고 가로세로 낱말 맞추기는 단어가 조잡하고 여러 답이 있음',
#  '은행 앱으로서는 잘사용 하고있습니다 이런저런 해택도있고해서 좋은데요 고양이 키우기등 관련 광고가 너무 많습니다 하나당 45초씩 봐야되는게 1개도 아니고 4개면   본인들이 45초동안 쇼핑관련 보고 있을수있나요 1개정도야 그러타 칠수있어도 4개는  방치형 게임도 광고 평균이 10 15초입니다 길어바야 30초고  고양이키우기 외 광고들 좀 시간을 줄려주세요 특히 토스 쇼핑관련 45초 보는거 20초로해주세요 제가 토스 미션 같은거 할수있는거 한번에 다해 볼려고 해보니까 1시간 넘개 걸리는거 같은데 방치형 게임도 하루 총미션 10분 20분 사이 하는 방치형 게임이 거이 없습니다 그런데 먼 방차형 게임보다 더 오래 걸린다는게  은행 앱인지 다른 무언가인지 이해가 안감',
#  '업데이트하고 가독성 완전 떨어졌어요 도대체 왜 업데이트 한 건지  업데이트 하기 전이 훨씬 나음',
#  '사용하기 편리해요',
#  '이번 업데이트는 최악이네요 전에좋았던 기능들이 다안되고 1 IRP계좌가 강제로 증권계좌로나옴 순서이동도 막힘 2 증권과 연금과 계좌순서이동 안됨 3 증권에 개별종목별 수익금이 안나옴 수익률만나옴 다시돌려놔주세요',
#  '토스냐 벅스냐 왜 또 버벅거리나',
#  '또다시 업뎃하더니 광고가 무지막지하게 나옴 30초 보라고 하더니 끊는 형식으로 총 1분이상 보게되고 광고 닫기도 어려워짐 엑스를 눌렀는데 광고한 앱으로 들어가짐 짧은 광고라더니 1분이상 어쩔때는 2분도 넘김',
#  '가격알림과 기업소식 구분해주세요 가격알림 너무 많이와요',
#  '첫 구매시 5000원 할인 쿠폰을 받았습니다 근데 이 쿠폰을 3920원인가 3940원짜리 튀김우동이라는 컵라면에 쓸려고 하니깐 다른 상품을 구매해야 된다고 하더라고요 그래서 제가 그 쿠폰의 사용 조건을 찾아보기 위해서 받은 쿠폰이 어디있나 찾아보았는데 쿠폰함이 존재하지 않는 것 같더라고요 도대체 사용을 못하게 하거나 조건을 달아서 하는 이벤트 행사 이딴건 왜 하는 겁니까 토스를 거의 2년정도 쓰는 거 같은데 1시간 3분뒤에 쿠폰 시간도 끝나고 뭔가 갑자기 이 앱이 싫어지네요 수고하시고요 저의 토스 사용은 오늘까지 인거 같네요',
#  '사람들 고양이 키우기 매일 미션 10초 구경하는게 없어져서 아쉽네요 다시 나오게 해주시면 진심으로 다른 이용자들도 사용할수있게 다시한번만 해주시면은 감사드리겠습니다 쿠폰 혜택 20초구경하는거 안되는버그가 너무 많습니다 그래서 꼭버그수정 꼭좀 부탁드립니다 그리고 토스 업데이트후로 토스쇼핑 60초 동안 구경하면 4원씩 받는거 뜨는데 포인트를 받을라면 간편결제등록 하라고 알림이뜨네요 원래는 아예 안떴었는데 갑자기 바로 떴네요 빠른 버그바로수정조치좀 최대한 빨리 부탁드리고 토스쇼핑 다시 이용 할수 있게 간곡히 부탁드립니다',
#  '만보기 쿠폰은 또 나만 3원씩 쳐나오네 이 앱을 몇년이나 썼는데 왜 나만 당첨이 쳐 안되냐고 10만원 이상씩 뽑은놈들은 주작으로 쳐 뽑았거나 니네 지인들 뽑히게 주작질 쳐 한거겠지 주작질 쳐하니까 재밌나',
#  '토스요금제 아직 데이터 다 쓰지도 않았는데 왜 2g처럼 느리나요 개빡치네 진짜',
#  '',
#  '토스 렉 엄청 심한데 이거 안 고치나요 슬슬 짜증납니다 접속도 엄청 느리고 툭툭 끊기고 캐시 삭제 재부팅 다 해도 달라지는게 없네요',
#  '버그잡았던 명목아래 업데이트 했다고 하지만 광고 여기저기 넣어서 앱이 이상해짐',
#  '너무 이것저것 많이 집어 넣어놔서 지저분하고 효율성이 매우 떨어짐 최대한 금융에 신경 써 주세요 특히 광고 좀 줄였으면 좋겠습니다 케이뱅크 등 타 인터넷은행 벤치마킹 좀 하세요',
#  '최악 개선된 사항이 전혀 없고 버튼 누르고 광고보고 돌아오면 어플 비밀번호 두번이나 다시 입력해야되고 심지어 버튼 누른 것도 리셋 됨 5번이나 했는데 똑같네요 뭐 어쩌라는걸까요 어플을 쓰라는건가요 말라는건가요',
#  '버그 있습니다 앱 화면 로딩이나 토스증권 UI 전환로딩이 심각하게느린수준입니다',
#  '솔직히 말하면 이벤트들이 다 짜침 캐시백이라면서 1원씩 주는건 기본 이벤트의 의미가 뭔지 모르시는 듯',
#  '업데이트한 후로 계좌 보기가 넘 불편해졋어요',
#  '최근 업데이트 이후 너무너무너무 느려짐 캐쉬제거 이런거 다 했는데도 소용없음 빨리 다시 속도 개선해라',
#  '일주일 방문미션에서 오류투성이던 메뉴가격미션은 왜 없앴다가 오류 남긴 채로 다시 부활시키셨나요 고양이 키우기 45초 미션만 슬금슬금 계속 늘리는 것도 짜증났지만 참을 수 있었는데 왜 자꾸 앱을 개악시키나요  돈에 미친 비바리퍼블리카님들',
#  '신분증인식하나못하네',
#  '가끔 욕 나올때가 있을 정도로 어플이 굉장히 무거워졌지만 국내에 얘 대체할만한 어플이없다',
#  '로그아웃기능 좀만들어줘요',
#  '아니 돈좀 제때제때 주면 안됄까요 이게 돈이 안채워지잖아요',
#  '쇼핑에 상품찜하기 기능이 있엇으면 좋겠어요',
#  '뭔 점검을 하루온종일하냐 받을 돈 못받고 있다',
#  '점검중 많이뜨고 뭔 쓸모가 없어요 그냥 갈아탈게요',
#  '결제 하려는 타이밍에 점검해버리고 쓸데없는 것만 보여주고 돈 주는 척 주지도 않는 앱 상당히 별로네요',
#  '만보기 메타 광고 오류가 너어어어무 잦습니다 개선 부탁드려요',
#  '저번에 안좋게 바뀌었다고했는데 더 안좋아졌어요 자산에서 제외된 항목도 이제 투자 모아보기에서 합산해서 나와요',
#  '잦은 업데이트 지겹다 업뎃 용량도 매번 무려 135M 증권을 토스앱에서 분리해라 순수 금융앱만 필요한 사람들한테 불필요한 기능이고 앱 용량만 거대한 앱이 되가고 있다',
#  '점검 시간이 이상함 메인으로 쓰기엔 별로',
#  '메신저도 만드실수 있으신가요',
#  '아니 왜 송금이 안되죠 장난하는것도 아니고',
#  '점검은 그렇다 치는데 송금도 막아버리면 어쩌자는거냐 그것도 주말 새벽에 이것들은 생각이란걸 못하나 현재 새벽 3시 11분인데 18 송금도 안되고 체크카드 결제도 안되고  뭐하자는거야',
#  '결제오류',
#  '총 자산내역에서 자산분석 그래프가 또 사라졌어요 생겼다가 자꾸 없어지는데 다시 버튼 활성화 시켜주세요',
#  '고양이 키우기 사료 장난감 23 시간 남음 이것좀 없애주시면 좋겠습니다 포인트 지급 알림이 뜨지 않습니다',
#  '앵 다들 왜그러지 토스 편하기만 한데 애들 다 쓰길래 저도 깔아봤는데 너무 편해요 심지어 더치페이 같은 기능까지 완전 센스넘침 근데 이자 받는 저금통에서 이자가 많이 나오기를 기대하는건 아니지만 적지 않게 넣어놨는데 하루에 3 5원이 들어오니 황당하네요 그래도 아직 성인 아닌데 가상주식으로 미리 체험하는게 너무 좋은 아이디어 인 것 같아요 그리고 이벤트 같은거 재밌는데 많이 만들어주시면 좋겠어요   항상 힘내세요',
#  '로그인 QR없는게 아쉬워요',
#  '자산 보는 창이라 해야하나 홈에서 자산보는 창이랑 자산 모두 보기 누르면 저금한 돈까지 쫙 나오는 그 창들 그만 바꿔주세요 자꾸 모양이 바뀌는데 너무 자주 바뀌니까 적응도 안되고 불편합니다 제일 최근에 바뀐 창 모양은 특히 너무 불편해요 옛날처럼 다시 바꾸고 자꾸 건들지 말아주세요',
#  '점점 서비스 안좋아요 포인트인출 수수료도 그렇고 포인트쌓기 일주일 방문미션에 똑같은걸 찾아도 없는거 많아요 개선 부탁드려요',
#  '토스뱅크 뿐만 아니라 증권도 사용하기 편해서 좋아요 다만 요즘들어서 자꾸만 만보기에 오류가 생기는지 걸음측정이 잘 안되네요 그리고 미성년자의 경우 본인 스스로 저축할 수 있는 다양한 상품이 많았으면 합니다 특히 적금종류가 많았음 합니다',
#  '짧은광고 5초광고 라고 하고 짧은게 30초광고 그러다 엑스버튼도 잘 안보이게하고 모같이 겹치겜 만들어서놔서 광고사이트로 강제 이동하고 토스는 광고사측 이라고하겠죠 근데 토스도 초심잃은거같아요 이유는 지들이 더 잘알거고 사용자들 기만하는거죠',
#  '광고 작작보내라',
#  '갑자기 엄청 느려졌어요',
#  '요새토스증권너무느려져서별로임 짱나니까별하나더깎아야지',
#  '고양이 예전처럼 스타벅스 커피 주는것도아니면서 이제 장난감 100개 주는 고양이 맞추기도 기회 2번이라고 써있는데 하루 1번 주는거 진짜 엄청 쪼잔해요  오류 수정 안함 며칠 걸려서 꼴랑 1 000원짜리 주면서 점점 혜택 줄이는거 진짜 없어보임 다른 은행들 혜택 따라가지도 못하면서 쓰는 기존고객들이랑 기싸움 오짐 이제 안쓸란다',
#  '갑자기 16500원 페이레터 라는 곳 에서 사라져서 네이버에 페이레터 치고 결제내역조회 들어가면 뜬다고 해서 해봤더니 결제내역0 이라는데 진짜 어이없네요',
#  '업데이트 좀 그만해',
#  '알람만 10개 이상 꺼야할 정도로 굳이 복잡하게 만듦 핸드폰 사용 미흡한 사람들 어떻게든 못 끄게 하려고',
#  '2026년2월6일 와이파이 꺼도 접속하는데 너무버벅거림',
#  '카카오톡대신 쓸 수 있는 메신저 기능 개발해주세요',
#  '증권보다 쇼핑알림이 더 많냐 쇼핑메뉴 자체를 없애라',
#  '솔직히 다들 쓰니까 쓰긴 쓰는데 막 편하진 않습니다 뭔가 생긴 화면은 예쁜데 실속은 떨어지는 느낌입니다 그리고 태블릿과 핸드폰 모두에 설치하고 사용하는 중인데 태블릿에서 본인인증을 하면 핸드폰에선 풀리고 폰에서 하면 태블릿에서 풀립니다 이딴 현상은 왜 일어나는 거죠 다 이런가요 매우 짜증납니다 이건 좀 아닌거 같습니다 계속 본인인증 하느라 귀찮고 짜증나고 열불나고 그렇습니다 감사합니다',
#  '렉 관리좀해라 진짜',
#  '0점을 못주는게아쉽네 뭔 페이스페이 못해서 안달 아니  뭔 갑자기 개쳐어렵게 바꾸고  어이없어서 말이 뭔  계좌 송금 이랑 잔액 보기 개힘들고 찾는데 20분 걸렸다 진짜 왜 그따구로밖에 일 못하냐 내가 더 잘할듯 제대로좀쳐해라 갈아타고싶다 진짜 그러면서 돈받아쳐먹는게 배알꼴리다 어어 그래 계속 구따구로해야 사람들이 떨궈지지 그거 원하는거지',
#  '토스 장점 이체 수수료 무료이고 많은 리워드 참여로 포인트 모으는 재미가 쏠쏠해서 좋았는데 어느 순간 잦은 업데이트 이후 이상한 메뉴 계속 생기면서 충돌하는지 안되는게 너무 많고 버그인지 오류인지 포인트 적립도 안돼서 캡쳐해서 직접 토스 고객센터로 보내야 한 며칠후에 확인하고 들어오고 어떤 건 아예 참여 자체가 안되게 막아버리고 예전 토스가 아닌거 같네요 여러가지 유용한 정보들도 피드백 해줘서 좋아요 하지만 어느 순간 포인트 정말 짜게 주고 광고를 봐도 5포인트 받기도 힘든데 점점 중국식 먹튀 앱으로 가는 것 같아 안타까워요 만보기 복권 당첨도 진짜인지 알수가 없고 가스라이팅 하는 건지 현재 100일 째 단 하루도 거르지 않고 하는데 최고 많이 받은 포인트가 10원 임',
#  '앱 뽀대나게 만들면 뭐함 맞춤법도 제대로 못 맞추고 ui디자인도 간지나는 척하면서 전혀 직관적이지 못함 문과 안뽑아서 그런건지 뭔진 모르겠으나 앱이 전반적으로 멋지고 트렌디한 척하는 영포티 아저씨같음',
#  '가상자산 서비스도 연동 신용카드 할부 결제는 매달 1달치 요금만 내역에 뜨게 하기 어플내 글씨가 깨지네요',
#  '이벤트 자주해주면 좋을듯',
#  '선택 동의를 하도록 교묘하게 유도함 별점 1점 시간 지나도 진짜 화나네',
#  '고맙습니다 건강하십시요',
#  '오류가 너무 심해요 광고에 신경 쓸 시간에 고치셨으면 얼마 안되는 전액을 다른 통장에 송금하려는데 661원씩밖에 송금이 안돼요 업데이트를 해도 똑같으면 어쩌자는 거죠',
#  '별한개도 아까움 예전같은 심플함은 산으로 가고 유도 쩔고 불편해죽겠네',
#  '실행안되구만장난하나',
#  '자꾸 광고뜨고 무겁고 혜택이라해서 동의하면 또 동의하라하고 무슨 개인정보 여기저기 다 동의해야하고 진짜 주식도 일부로 바꾸고 주거래 계좌쓸려했는데 점접 너무 별로고 계속 이러면 그냥 다른거 쓸려고요 진짜 개실망 너무 실망이고 넘 짜증남 뭐 동의하래서 했더니 다른 동의 숨겨져 있고 2번째 3번째 동의 절차지나야 함 철외도 숨겨져 있고 간편한척하면서 정작 뭘 취소하거나 안내는 부족해서 나중에 보면 문제생기고 금감원 경고 받아야함 옵션도 끼워넣고 수수료비싸도 일부로 썼는데 주식할때마다 오류 벌써 10일정도 먹통에 채결 오류나고 수수료 젤 비싸면서 진짜 짜증나네',
#  '낼 카드값 내역보기에서 지난 달 내역도 추가된 것은 좋은데 내역의 합산 금액도 보여주면 좋겠습니다 일일이 더해야 돼서 불편하네요',
#  '토스증권 왜케 느려요 국장하는데 차트 로딩부터 개느려서 단타도 안되네 데이터 삭제해서 초기화 시켜놓아도 좀 지나면 다시 느려지고 증권은 그냥 네이티브로 해야하지않나 이정도 속도는 증말 심각한데 짜증나서 증플로 다시 가던가해여지 쓰글',
#  '계속 서비스 점검중이라고 떠서 사용이 안돼요 고객센터 문의를 남기려고해도 서비스 점검중이라고 떠요 토스증권만 이용가능해요 업데이트 해도 똑같아요 제발 도와주세요 제거하고 다시설치했더니 아예 앱 이용이 안돼요 일시적인 오류가 생겼다고 껐다 켜거나 잠시후 이용하라는데 왜이래요 제 증권 계좌 어쩔거에요 토스앱 아예 안돼서 컴터로도못해요 빨리 제발',
#  '같은 글에 알림 왜 이렇게 많이 보내는지 모르겠다',
#  '통장누르는데 계좌번호부터 나와야지 깔끔떤다고 기본기는 무시한 디자인병걸린 듯 사용성최악 편하고 좋은 상품들출시한건 좋은데 정보를 죄다가려놔서 개빡침 사고터지기 딱좋음',
#  '전체 외화 환율 볼때 어플이 자주 멈춰요 강제 종료하면 몇 초후에 토스가 응답없다는 메세지 떠요 갤럭시 디바이스케어도 토스에서 비정상종료가 자주발생 한다고 푸시알림 떠요 저만의 문제일까요 어떻게 해야해요 외화 전체 환율보기 이거할때만 하루에 5회쯤 이래요',
#  '안녕하세요 토스를 이용 중인 사용자입니다 좋은 소식이 있습니다 저번 보다 오늘 마지막 대불행 탈출 성공한 이유는 바로 행운복권 애정운 매우좋음8원 2배 애정운 최고 컨셉 16원 덕분에 최악의 반복적인 대불행 노출을 벗어날 정도로 더할 나위 없이 행운복권 사용대신 다른 거 해놓으니까 평생 행복하고 가장 즐거웠습니다',
#  '다 좋은데요 이런점이 불편해요 토스관계자님  1 증권사에는 은행 처럼 입출금이 가능한 알고 계시겠지만 종합계좌와 CMA계좌가 있습니다 과거에 토스에는 은행의 입출금 계좌와 이 증권사의 CMA 종합계좌 모두 은행코드와 증권사의 순서지정을 안해도 될정도로 애초에 순서대로 나열해서 보여주셨고 거기서 저장해서 평소 CMA계좌나 종합계좌에서 타행 타증권사 이체도 토스에서 편리하게 처리가 가능했으나 아시는바와 같이 최근 업데이트 이후에는 투자라는 메뉴로 증권사계좌 모든 항목들이 순서없이 뒤죽박죽 섞여 있을 뿐만 아니라 추가로 증권사 CMA인지 종합계좌인지 구분도 안되어 이체거래기능도 찾기 어렵게 토스가 후퇴된 상황입니다 다시한번 꼼꼼히 원래 토스가 그동안 잘 해왔던것처럼 세심하게 살펴봐 주신후 다시 돌려주셨으면 합니다 2 광고관련 안내입니다 토스어플을 이용하다가 보면 인터넷바꾸라는게 토스에서 이벤트로 행사사은을 내건 것인지 아닌지 혼동될때가 많습니다 공신력있는광고인지구분별해주세요',
#  '토스증권 ISA 만들어주세요 영웅문처럼 수식만들수있게 해주세요',
#  '혜택이 짜다는 단점이 있지만 여러 편의 기능들이 이에 비해 너무 편하기 때문에 좋은 앱이라고 생각합니다',
#  '토스 라방 알림받기 표시 다시 있게 해주세여 들어가서 할려니 번거롭네요',
#  '갑자기 아이콘이 사라졌어요 play스토어 에 가서 다시 다운받으려고 하니까 다운등록되어있다고 합니다 그런데 없어요 어떻게된거인가요 찿아주세요',
#  '쓰레기토스절대하지마세요 5분동안전화먹통렉이심함 방금회원가입했는데갑자기폰이먹통 짜증',
#  '혹시나 개선해주실수있는지 하는 마음으로 리뷰답니다 제가 지금 핸드폰이 압수되서 컴퓨터로 될수있나 하고 컴퓨터에서 어플을 깔수있는 앱을 다운로드했는데 안되요 제가 계좌를 잃어버려가지고 루팅된 기기라고 안되더라도요 혹시나 개선하실수있나 하는 마음에 별점은 5드립니다',
#  '쉽게 주식을 할 수 있어서 좋은데 차트를 볼 때 매물대 분석 그래프의 색이 너무 진해요 그래프가 차트를 다 가려서 너무 불편해요 색상을 변경할 수 있게 하거나 연하게 또는 반투명하게 바꿔주세요',
#  '알림 그만좀 오게 해 주세요 토스 알림설정만 몇십번은 해제한것 같은데 하루종일 알림이 오네요 새로운 서비스 생기면 알림 또 꺼야하니 광고 쇼핑 덕지덕지 불편한 앱이 되었어요 토스 앱 들어갈때마다 해외결제 알림 뜨는것좀 패치해 주세요 제 알림창 보여드리고 싶네요 알림이 1시간마다 울리니 회사에서 핸드폰을 진동모드로 설정도 못해놓아요',
#  '중국 자본이랑 결별했기 때문에 카뱅 탈퇴하고 믿고 쓰겠습니다',
#  '장난치나 페이스 결제 쿠폰 줘서 카페에 쓰러 갔더니 인증을 또 하라고 이미 인증 해서 쿠폰 준 거 아니었나요 마지막 인증 날짜도 한달도 안 지났는데 도대체 인증을 몇 번 하라는 말인지 지갑도 안 가져가서 결국 쿠폰은 쓰지도 못하고 생돈만 나갔네',
#  '아이 통장에도 이자 기능을 없앤 저금통 옵션이 생겼으면 좋을 것 같아요 단순히 돈만 저금하고 싶은데 이자 기능이 포함되어 있어 아쉽습니다',
#  '토스증권만 계좌 별명 수정 안돼요 수정해주세요',
#  '자꾸 서비스 오류라고 팝업이 뜨는데 들어가보면 설정할 곳이 안나오네요',
#  '언젠가부터 토스 페이 결제를 했는데도 고양이 밥이랑 사료를 안 주네요 사항 다 읽어 봤고 토스페이 결제 시 증정하던 거였는데 왜 안 주어지는 건가요',
#  '토스 자산분석 예전버전이 더 좋아요 부동산만 자산입니까 주식자산도 자산으로 표현해줘요',
#  '노란우산공제 적립금액도 볼 수 있게 연동 부탁드려요 중소기업중앙회 직접 가입',
#  '5 246 0 전체 페이지 Grid 버튼 배치 최악',
#  '업데이트 안되어서 지우고 다시깔음',
#  '요즘 첫 구매 쿠폰으로 다들 토스페이 이용하실텐데 얘네 양아치들이라 쓰고 남은 금액 다시 계좌에 옮기기 힘들게 꽁꽁 숨겨뒀습니다 잘 찾아보고 옮기세요 괘씸해서 다시는 이용 안 한다 쿠폰은 잘 쓰고 간다',
#  '감사합니다',
#  '뒤져',
#  '토스 쇼핑 문의 수정 삭제 기능이랑 주문 내역 삭제 기능은 왜 아직도 없는건가요',
#  '증권 가격 계속 빠지는데 현재가에 판매눌렀는데 판매대기만 걸려있고 손실만 오지게 먹여주는 토스',
#  '정말 편한데 출금내역 업데이트는 빠른반면 입금내역 업데이트가 너무 늦습니다 불러오기를 몇차례해도 반영이 늦게되다보니 사용하는데 불편함이 있어요',
#  '업데이트하고 앱내에서 터치가 안됨',
#  '최근 업데이트 후 주식 내투자 4 2 위젯이 안돼요',
#  '토스만 하면 밧데리가 너무 뜨거워서 토스만 하면 밧데리가 너무 뜨거워서',
#  '업뎃하고나서 토스머니 잔액이 홈에 바로 안뜨고 모두 보기를 눌러야 뜨는데 이딴 업뎃 한 이유가 뭐임',
#  '카드값 나오는거 이상하게 바꿔놨네 총액도 안나오고 카드값 총액 나오는것 확인 완료 별점 수정 합니다',
#  '안녕하세요 다름이 아니라 어제만 해도 있었는데 고양이 키우기 글씨가 안보여서 앱에 글남깁니다 빠른시일 부탁합니다',
#  '확실히 잘 쓰고 있는 금융앱 ui도 좋음',
#  '훌륭한 은행 기업',
#  '알람 끄라고 하는게 최선이냐 할 일드럽게 없어 야 걍 대출이 필요한 사람들한테 선별해서 보내면 될거아니야 지능',
#  '다른 금윰앱들은 14세 미만은 카드를 쓰지 못하는데 어린이 전용 카드가 있고 그 카드에 교통카드 기능도 있고 심지어 자동으로 어린이 요금으로 나와서 좋구요 또 조그만 앱테크 나 이벤트도 있어서 유용해요 그 무엇보다 부모님이 금융 관리를 해주실 수 있어서 돈을 더 아껴쓰게 되는 것 같아요',
#  '토스가 좋은 건 사실이나 UI가 다른것으로 바뀌어서 약간 불편합니다 이전 Ui를 사용가능 하게 업데이트로 롤백하거나 이전UI로 변경가능하게 선택할 수 있게 해주세요',
#  '계좌번호는남고 체크카드좀 등록하고싶은데 어디서 하나요',
#  '내소비 월평균 막대그래프에서 과거 소비액 표시가 잘못 나타나고 있는 오류가 있습니다 빨리 수정해주세요',
#  '많은도움이되고제미있기도하고머리휘전도되고싸이는제미도있고좀더다항한이이탬좀내씀하내요외르들어게임같든거나아님놀이던가제미있는걸로요수짜노이나퍼줄같든거나아님토스터굿는게임',
#  '아니 어플 관리 안하시나 어느날부터 앱이 버벅대는데 개선이 안되네',
#  '사러짐',
#  '제발 전체메뉴에 즐겨찾기 기능좀 넣어줘요 서비스가 너무 많은데 매번 찾는거 힘들어요',
#  '쇼핑 들어가서 쇼핑홈에서 스크롤하면 끝까지 안내려가고 상품이 더이상 안나와요 확인후 수정부탁드립니다',
#  '증권 차트먹통에 오류덩어리에요 신규상장이나 이슈 생기면 토스앱자체가 먹통되는듯 증권앱을 따로 분리하지 않는 이상 이건 못고칠 듯 주식은 다른앱에 비해 좀 많이 모자랍니다',
#  '주식어플이 이렇게 렉걸려서 안들어가지고 로딩이 길어지먄 어쩌자는건가요',
#  '토스증권 오류가 너무심함 화면 먹통이 계속돼요',
#  '아니 왜케 버벅댑니까 주식거래를 할 수가 없네',
#  '토스 렉 좀 잡아주세요 주식 화면이 자꾸 안 넘어가고 토스 좋은데 왜 신경 안 쓰시는 것 같아요 토스 문제 좀 문의하려고 해도 할 곳이 없네요',
#  '아니 미친 미국주식 앱 오류로 거래불가 미치겠네 버그 안고치나 아이폰에서는 멀쩡하고 갤럭시 먹통이다 1 계좌 입출굼 내역을 색깔로 구분했을 때가 보기 편했음  로 바뀌어서 한눈에 보기 엄청 불편해짐 2 금일 오전에 증권 화면의 차트와 시세창의 오류가 한동안 이어졌고 저녁에도 뜨문뜨문 발생함 pc에서도 동일현상 발생',
#  '대체 앱을 어떻게 한겁니까 뭐 제대로 뜨는게 없잖아요 차트도 동작이 됐다가 멈췄다하고 뭐어디 들어가면 검은로딩화면만 뜨고 쓰지말아달라는 겁니까  주식다팔고 안쓸까도 고민중이네요 갑자기 이상한 광고가 뜨질않나 사람 민망하게 제발 덜어내고 개선 꼭 좀 해주세요 제발',
#  '토스증권 너무 느려요 인터넷 문제인가 싶었는데 그것도 아니고 배터리 제한없음으로 해도 동일해요 접속자가 많아서 그런가 서버 확충이 필요한듯 보입니다',
#  '토스증권 쇼핑 그 밖에 것들 렉먹어서 터치도 안되고 멈춰요 또 신호도 너무 안좋아요',
#  '최악 갑자기 먹통 반응 없음 이걸로 주식을 어떻게 하란건지',
#  '렉 토악질나오네',
#  '아 지금 4천만원 넘게 아침 매매하고 있는디 토스증권으로는 하면 안되는건가요 인기 종목들 차트가 안보이는 문제가 있네요  매매를 할 수 가 없음  오늘은 별 하나 감점이에요 자세한 내용은 1월 30일 오늘 나라스페이스 한라캐스트 같이 아침에 거래대금 1000억 이상 터진 이용자수가 많은 종목들 차트가 무한 로딩중으로 떴어요 어플 껐다 켜도 계속 시도해봐도 해결이 안되는거 보아 아마 토스 이용자들이 많이 보는 종목 과부하 걸리는 것 같아요 바빠서 캡처는 못했는데 전화보다 글로 적는게 전달이 잘될 것 같아서요 바쁠때는 토스증권으로 매매하는데 저도 오늘 처음 경험하는 일입니다 다른 증권어플로 차트 보면서 호가 매매했어요 아 그리고 분봉거래대금 같이 보조지표도 차근차근 더 늘려줬으면 좋겠어요 토스증권이 가독성이 좋아서 나중에는 다른 증권사 어플 말고 토스 증권으로 정착하고 싶은 마음이라 하하',
#  '1월 30일 22시부터 접속이 안 됩니다 주식을 봐야 하는데 왜 안 들어가지나요 보상하세요 이게 뭡니까 피드백 주세요 업그레이드도 다 받았습니다 이런 일이 요즘 비일비재합니다',
#  '아니 갑자기 계좌 비밀번호를 틀린적이 없는데 계정이 잠겼습니다',
#  '쇼핑 본목록 만들어주세요',
#  '굿 랍니다',
#  '밑에 리뷰처럼 요즘 잘 안되네요 답변처럼해도 똑같은 증상이에요',
#  '딱 접근성 송금 원툴 느낌임 특히 증권 시스템 가시성도 불편하고 오류도 많고 차트 렉도 심함 그저 접근성 하나만 보고 사용중이긴 한데 수수료도 업계 최고로 받아먹을꺼면 개편좀 했으면 함 이 상태가 계속 유지되면 다른 증권 어플로 갈아탈듯',
#  '주식 차트 로딩이 늦고 장중인데 거래전이라고뜨고 이상해요',
#  '특정 알림을 끄고 켜는 방법이 직관적이지 않아서 힘들게 찾았어요 지정가 알림을 다시 켜고 싶어서 토스증권 설정 화면에서 오랫동안 찾았는데 아무리 찾아도 없었어요 결국 홈 화면에서 종 아이콘 광고 끄기 모든 알림 꺼진 알람 보기를 눌러야 알람을 다시 켤 수 있다는 걸 알았어요 광고 끄기 를 눌러야 알람 설정이 나오는 방식은 별로 사용자 친화적이지 않은 것 같아요 토스증권 기능인 지정가 알림을 홈 화면까지 나가야만 켤 수 있다는 것도요 그리고 토스증권에서 검색한 일부 특정 커뮤니티 글을 클릭하면 해당 글로 이동하는 대신 토스증권 홈 화면으로 돌아가게 되는 버그가 있어요',
#  '무슨어플이 핸드폰을껐다켜야쓸수있네요',
#  '사용하기 편하고 좋아요',
#  '인터넷도 멀쩡한데 가끔 혼자 어디서 나사 빠져가지고 하나씩 무한로딩 걸리면서 안 될 때가 종종 있음  그렇게 해서 포인트 몇 번 빼먹은 것도 짜증나는데 뭐 결제한다고 토스페이 쓰려고 했더니 또 무한로딩 걸린 채 화면이 안 넘어감 와이파이랑 데이터 다 꺼도 무한로딩 하다하다 결제까지 막히면 어쩌자는 건지  나한테만 이런 문제가 있는 것도 아니고 우리 엄마랑 주위에서도 이런 문제 언급되고 있네여 이 정도면 개개인한테 이렇게해봐라 재부팅해봐라 전에 자체 점검하고 개선 좀 해주세요 갈 수록 피곤하네',
#  '박터트렸는데 돈이 안들어옴 요즘 토스 양아치 짓거리 많이 하네 쿠폰보내기도 지멋대로 초기화하고 묻은거 어쩔수 없나봄',
#  '앱은 ui ux 전부 좋고 기능도 편리해서 만족하며 쓰고 있습니다만 만 14세미만 혜택좀 추가 부탁드립니다',
#  '예전부터 써와서 참 편해요 근데 점점 갈수록 카카오톡처럼 무거워지면서 이것저것 쓸데없는거 너무 추가하고 토스증권 좀만 쓰다보면 배터리순삭 너무 무거워졌어요 쓸데없는것좀 쳐내고 광고좀 적당히',
#  '이번달 지출 캘린더 화면 너무 불편해요 날짜 선택하면 달력이 접히지 않았으면 좋겠어요 예전에는 안 접혔는데 바뀌고나서 날짜 누르면 자꾸 접히니까 화면 정신없고 클릭을 여러번 해야하고 불편해졌어요',
#  '검색하는데 에러가 나요',
#  '쓸때없는 기능이 너무많고 상담이 너무 느립니다',
#  '토스 키면 자꾸 재부팅 되는데 뭐가 문제일까요 오래된 폰이 문제인가 왜 1G씩이나 차지하는 건지 모르겠고 너무 무거운 어플이에요',
# ...
#  '요즘 토스 왜그러죠 계속 에러에 정책이 바뀌면 사용자한테 공지를 해줘야 하는거 아닌가요',
#  '사용중 갑자기 버튼 안눌림',
#  '갈수록 광고 너무 심해짐',
#  '일주일 방문 미션 좀 어떻게 안 됩니까 맞게 썼는데 맨날 틀리다고 나오고 메뉴 맞히라는 가격도 매번 다 엉터리고 하루이틀이어야죠 매일 이러는데도 개선을 안 하는 이유가 뭔가요 이럴 거면 아예 서비스를 하지 말든가요 광고 띄울 거 다 띄워놓고 뭐하는 건지 진짜',
#  '1월 1일이후로 카드로쓴 결제내역이 안뜹니다 12월달도 우호죽순이구요 결제금액 돌려받기가 안되요 금액이 안떠요 카드내역이 없다합니다',
#  '갈수록 앱이 퇴보 억지로 ui 만드는 느낌',
#  '잘 사용은 하고있습니다만 이래저래 정보수집이 조금 안되는것같기도하고 그러네요 스스로 이것저것 통계를 내는다 맞는게 없어오',
#  '토스 증권에서 갖고 있는 주식을 확인할 때 그룹으로 묶어서 볼 수 있으면 좋겠어요 관심에서 묶는건 아는데 내가 갖고 있는 주식들을 그룹으로 묶어서 수익률을 보고 싶은데 그게 안되는거 같아요',
#  '왜 자꾸 UI를 바꾸는지 모르겠음 다른 계좌 보려면 홈 계좌 or 홈 모두보기 전체보기 해야만 볼 수 있음 홈 화면에 표시할 통장을 수정할 수 있는것도 아님 초기에는 편했는데 업데이트 할수록 번거로워지고 난잡해짐',
#  '아니 두쫀쿠 관련 알림 안 받는다고 알림 3번 껐는데 계속 꾸준하게 오네요',
#  '토스가작동이안되요',
#  '토스는 isa계좌 못만드나요',
#  '진지하게 증권탭에서 주주 아니면 커뮤니티에서 글 못쓰게 막아주셨으면 합니다 투표가 끝난지가 언젠데 아직도 주식 몇 종목에는 양극화가 심화되어 있습니다',
#  '증권 앱 터져도 공지 보이지도않는데 숨겨놓는 정신나간 쓰레기앱',
#  '삼성월렛은 카드 등록하면 실물카드 디자인 그대로 띄워주는데 토스는 실물카드 디자인과 다른 디자인을 띄워서 예를들어 내가 A B중 선택해서 발급한 디자인은 A인데 토스에서 띄우는 디자인은 B디자인 사용자입장에서 카드명을 자세히 보지않으면 무슨카드인지 헷갈리고 불편합니다 꼭 개선해주세요',
#  '토스쇼핑에서 구매할 때 포인트 사용 선택하면 전액 사용으로 되는데 자신이 원하는 포인트 금액을 정할수 있으면 좋겠습니다',
#  '투자들어가는데 세번 눌러야 하네요 너무 불편하네요 왜 은행어플 보는데 자동차 부동산을 먼저 봐야하는지 모르겠네요 편집기능도 막고 도대체 왜 이런 업뎃을 한건지 이해가 안가네요',
#  '내 계좌와 아이 계좌를 번갈아 가면서 쉽게 볼 수 있었는데 갑자기 둘 중 하나만 볼 수 있게 바뀌었네요 매우 불편해졌네요',
#  '내 자산 탭 롤백하세요 아니 진짜 더 구데기를 만들어놨네 기획자 누구야',
#  '편리하고 복잡하지 않음',
#  '장중에 오류로 매매 전혀안되고 화면도 안뜨게 되는게 말이나 됩니까 진짜 덕분에 2000만원 날렸네요 감사합니다',
#  '아마 토스증권 말고 다른 곳으로 갈아탈 듯 미장 개장할 때 렉걸려버리면 렉걸려서 사지도 못했네',
#  '한참 미장 시작했는데 오류로 매수도 안되고 갈아 탈때가 됬나보네요',
#  '관리가편함',
#  '자산리스트 보는게 업뎃 후 너무 불편하네요 두번 거쳐서 들어가는데 왜 그렇게 하신건지 도저히 이해가 안가네요 앱도 점점 무거워지고 사용자 편의성 마져 이전 처럼 은행 증권 보기 편하게 업뎃 바랍니다',
#  '뭔 점점 구려지노 광고보면 포인트 찔끔 주는데 뭔 포인트를 받았다고 앰병을 떠는지 사용자 떠나라고 하는거',
#  '사용하지않아 읍니타',
#  '계좌 송금 출금 바로바로 업뎃 안됨',
#  '업데이트 하고나서 뭐가 뭔지 모르겠고 보기가 불편해요',
#  '증권 평단가확인이 눈에안들어오는거같아요 얼마넣어놨는지만 한번에보이게해둠 불편',
#  '홈화면 바뀐거 불편해요 계좌 대출 카드 항목 순서 바꿀수있게 해주세요 대출이랑 카드 말고 투자항목을 젤 위에 보이게 하고싶어요',
#  '필수 동의 누르다가 다음에 뜨는 선택동의는 아주 칼같이 동의하기 누르자마자 철회하는 곳도 못찾게 만들어두셨네요 참 대단하십니다',
#  '진짜 최근에 사용한 뱅킹앱 중 압도적인 쓰레기 1등이다 진짜 뭔 인증서 비밀번호를 쳐만드는데 다 안된다고 하고 만들었더니 오류 뜨면서 접속을 못하게 하네 별점 하나도 아깝다 그냥',
#  '진짜 거추장스러운 보험료 매매 및 전세 자동차 등등 잡기능을 다 때려박고 온갖 광고 다 넣어서 앱 무겁게 만들고 쓸데없는 UI 변경만 계속 반복해서 사용감 나빠지게 하고 왜이러는거임 과거엔 직관적으로 내 자산만 볼 수 있었는데 가면 갈수록 산으로 가네 따라갈 게 없어서 카톡을 따라가 그리고 맨날 문제해결한답시고 재문의를 넣어달라는 둥 그딴 소리 하지 마세요 AI로 후기 관리 하세요 지들이 업데이트를 어떤 방향으로 했는지 빤히 알면서 초심으로 돌아가세요 자산 관리 앱 넘쳐나는데 지금은 귀찮으니까 쓰는겁니다',
#  '유용하네요',
#  '눈치우기 이벤트에서 5000원 받고끝내기를 누르면 시스템문제가 생겨 잠시뒤 이용하라는 멘트만계속 뜨네요 오류같아요 확인바랍니다',
#  '당첨되었습니다 뜨는글 있는데 정작 아무것도 입금같은건 하나도 없는데 장난 이벤트인가요',
#  '알림좀 적당히보내라 개빡칠라하네',
#  '만보기 연속방문 이거 없엇으면 좋겟어요 생기는것도 없는데 연속 방문 왜 하는건디 몰겟네요 포인트라도 좀 주던가 쓸데없는 연속방문이고 복권도 당첨 완전 안되고 몇년째 이용하고 잇지만 딴데로 갈아타고 싶네요',
#  '진짜 마지막 기회임 얼마안남음 사용자가 말하면 들어야됨 쿠팡처럼 지배자라고 생각하면 착각',
#  '만보기 광고 무한재생 광고 다봐도 복권은 긁을수없음 주계좌 조회 및 송금이 안됩니다 화면이 그냥 하얗게 멈추는데 조치방법 알려주세요 몇년간 잘 써왔는데 슬슬 불안해지는게 다른 은행으로 갈아탈 시점인가 싶네요 캐시 및 데이터삭제 후 재설치 해봤는데 똑같습니다',
#  '신용등급확인하기',
#  '부동산 자산으로는 거주할 용도의 주택밖에 없다고 보는 건지 상가나 토지 등등 포함 안 될 거면 총자산 보여주는 것이 무슨 의미가 있나요',
#  '초심을 잃어가는 모습이 안타깝네요 신용카드 신청에서 주소입력이 안되는 앱의 버그를 제보하려는데 고객센터 채팅 상담원 연결할 방법을 찾기도 너무 힘들고 찾아서 들어가도 연결까지 정말 오래 걸립니다 이제 서비스가 정말 안좋다고 느껴지네요 UX가 편해서 쓰고는 있지만 이대로 가면 앞으로 어찌될지 모르겠네요',
#  '스크린 화면이 계속 흰색이고 삭제했다 다시 깔아도 똑같은 문제가 지속됩니다',
#  '업데이트 하라고 뜨는데 모바일이던 와이파이상 업뎃 계속 안됨 먼문제임',
#  '모냐 왜 업데이트가 안되는건데 하',
#  '갈수록 보기힘들게 만드네 전처럼 한번에 모든계좌 보이게끔 하지',
#  '자산 관리하기에는 좋은데 업댓하면서 계좌순서좀 그만 바꿨으면 순서 맞춰놓으면 업댓하면서 초기화가 몇번인지 지금은 숨기기만되고 순서는 설정도 못함 ui변경좀 그만했으면 좋겠음',
#  '바뀐 모두보기 불편해요 정렬기능이 사라짐',
#  '고양이 키우기 광고 1초 보여준다면서 맨날 5초 광고 보라고 함',
#  '요옃일 토스 모든혜택버튼과 화면이 안뜨네요 여러번 휴대폰을 껐다켜도 안되고 앱믈 재설치해도 잘안되네요 저만 그런가요 이제껏그런적없는데 혹시 해킹인가 싶어서 걱정되네요',
#  '토스 정말 정말 좋습니다 딱한가지만 말하자먄 카드를 분실했을때 카드위치 찾기 같은 기능이 생겼으면 좋겠어요',
#  '토스 쇼핑에서 포인트 일부만 사용 가능하다고 안내문구는 보이는데 어디서 하는지는 안보입니다 포인트 사용 체크하면 자동으로 최대 적용 되어버리네요 버그인건지 제가 메뉴를 못찾은건지  답변 부탁드립니다',
#  '와 또 바꿨네 신경질나게  왜자꾸 인터페이스 바꾸는건데  원래대로 돌려놔 졸라 불편하네',
#  '엄마가 만들면서 화내서 1점',
#  '광고 선 넘네',
#  '토스 프라임 가격 자체가 다른 구독서비스에 비해 비쌈 근데 적립 후에 결제취소를 하면 해당 적립 포인트가 사라짐 해당 결제건 이후에 아무리 많이 결제했어도 소용없음 미래 예측해서 구매취소 절대 안할 건만 토스로 결제해야 손해 안봄 네이버페이가 백배나음',
#  '어째 점점 잔액 변동 반영 속도가 늦어지네요 업데이트 하면 할수록 늦어지는데 문제 있는거 아닌가요 급하게 보내야 하는데 입금된지 15분이 지나도 토스 어플 내에서는 반영이 안돼서 토스로 송금도 못하고 진짜 개짜증나요 이러다 엉뚱한데서 돈이 빠져나가 정작 필요한데에 못쓴 경우도 허다함',
#  '멀쩡하던 모바일 티머니는 왜 갑자기 안되는지 안될때 들어가라고 있는 링크를 타면 왜 사이트가 없다 뜨는지 정말 미칠 정도로 궁금하네요 그것 때문에 버스타면 20분 갈 거리를 걸어서 1시간 가니 기분이 너무 좋아요',
#  '업데이트 때마다 교모하게 사용하기 불편하게 조금씩 바뀌어지는 인터페이스에 불쾌감이 쌓여감 교묘한 수정과 불편감이 계획적인 것 같다는 느낌이 강하게 들어서 더 불쾌함 편리성 때문에 썻는데 조금씩 불편해지면 언젠가는 아예 손절할듯',
#  '업데이트 안됨',
#  '각 계좌에 잔액 실시간고침후 업데이트가 느립니다 특히나 A계좌에서 B계좌로 송금이체후 B계좌에 송금내역이요',
#  '아 토스도 이상하게 변하고 있네 제발 간단한 UI에서 이상하게 자꾸 바꾸지 말라고 왜 자꾸 가면 갈 수록 이상해지는데 사용자들 말을 좀 들어라 경영진들아',
#  '아오 예금만기 박수좀 안뜨게 해줘요 계좌 지우는데 방해됩니다 그리고 나만 주는 혜택인척 혜택대상자네 뭐네 기만적인 문구 쓰면서 알림 보내지도 마시구요 자산보기는 왜자꾸 이리저리 바꿨다 난리입니까 내비두라고요 클릭수만 더 늘어나요',
#  '최근 해외여행을 갔는데 토스어플에서 제가 어떤 나라에 있는지 파악하여 이 나라의 환율은 얼마다 결제하냐는게 자꾸 알림 팝업 창이 떠있더라구요 지워도 안없어지고 이거 어떻게 끄는지 알고싶고 gps정보 제공 동의 철회하는것도 알려주세요',
#  '가입하니까 내 계좌에서 몰래 5만원 빼갔는데 이거 불법 아니냐',
#  '아니 모바일 신분증 얼굴인식 못할거면 걍 나라에서 제공하는거 가져와서 써 몇번을 해도 안되네',
#  '전체 계좌 보러 들어가는데 바뀌기 전에는 1 2번이면 됏던걸 3번이상 터치하게 바꾸는건 ux ui 담당자 시말서 받아야할 것 같은데 하다못해 보고싶은 메인화면을 커스텀할 수 있는 선택지라도 주던가 이건 뭐 홍 택이 카카오 갔어도 바뀌는게 없냐',
#  '숨긴계좌의 계좌내역은 어디서볼수있나요 업데이트전이 더 편해요',
#  '일주일 매일 포인트 모으면 1원씩만주더니 돼지저금통은 뭔가했더니 지멋대로 초기화되고 그동안 모은 돼지포인트는 어디로갔는지 그냥 출석 이벤트 하지마세요',
#  '계좌 리스트 보기 좋았는데 업데이트하고 너무 알아보기힘드네요 업데이트전으로 돌려주세요',
#  '결제내역이 두번씩 떠요',
#  '카톡이나 토스나 UI로 이상한 행동을 한단 말이죠 기존 분류도 잘되어있고 충분히 괜찮았는데 업데이트 후에 더 복잡해진 느낌입니다 업데이트가 중요한게 아니라 소비자가 선택이라도 할수있게 해주십쇼 다른 앱을 찾아서 가는게 더 이득일듯',
#  '카카오 인증 성공 해도 실패로 뜨는 토스',
#  '증권 버튼 누르면 발견으로 들어가짐 왜이래요',
#  '예전엔 금융인증서나 이런걸로 인증되었는데 어느순간 갑자기 본인명의폰만 가능하다고 난리남 덕분에 사용 못함',
#  'UI가 너무 불편해졌어요',
#  '왜 계속 증권계좌를 잠궈서 본인인증을 시키는지 궁금함',
#  '페이 관련팀들 진짜 정신 좀 차리세요 결제나 페이 검색해서 들어가면 딱 좋게 충전 옮기기 이거 하나 박을 공간이 없어서 아직까지도 이러고 놔둡니까 하 하겠지 하겠지 하는데 페이 사용하는데 얼굴이나 위치는 도대체 알아서 뭐하게 답답다 정말',
#  '완전히 야르',
#  '5초광고라면5초짜리 나와야지 별이상한스킵도안되고AI로 돌린 이상한 광고가 1분넘게 나오질 않나 아니 모니터링이나 필터링 안해요 별 야시꾸리한 신음소리 나오는 19금 광고나와서 사람 곤란한적도 있고 요즘 갈수록 관리 안하는듯 하네요 진짜 광고때문에 정떨어질라고 합니다',
#  '아스가르드 OTP만들기 및 거래이용에 선별적입니다',
#  'UI좀 제발 건들지마세요 왜 자꾸 단계를 늘려요 한번 클릭할거 두세번 누르게 만드는 이유가 카톡처럼 체류시간 증가를 위한건가요 분명 선례가 망한게 있는데 왜 똑같이 따라하는데요 토스의 장점은 간편하고 빠른거였는데 자꾸 화려하고 복잡하게 가는건 본인들 앱 메리트를 없애는겁니다 선택권을 주고 반응이 별로면 개선을해야지 확 바꾸고 별론가요 이러면 유저만 떠납니다',
#  '이번 업데이트로 자산 정보 보는게 아주 힘들어 졌네요 예전처럼 쭉 내려가며 보면 좋은데 각항목별로 전체보기를 또 눌러야 하네요 그리고 자산 분석은 어디로 갔어요 당분간은 뱅크샐러드 써야 겠어요',
#  '업데이트로 인해 사용이 개선되지 않고 오히려 불편이 가중되었습니다 모임통장 카드임에도 불구하고 명의 기준으로 소비가 결산되어 내 소비내역에 포함된다는 점 기존에 소비내역에서 숨겨놨던 부분들이 업데이트되면서 숨기기가 해제되었다는 점이 가장 눈에 띄고 불편하고요 특정 카드는 전체 숨기기하는 기능 등이 있으면 사용이 원활할 것 같습니다',
#  '토스 사용자체는 편리하고 좋습니다 최근부터 쿠팡이나 다른 플랫폼에서 결재한 소비내역이 새로고침해도 안뜨고 안보입니다 하루빨리 이점 고쳐졌으면 좋겠습니다',
#  '처음엔 모든 계좌를 한눈에 볼 수 있었음 어느날 업뎃하고 버튼을 눌러야 모든 계좌를 볼 수 있었음 이번 업뎃으로 버튼 두번 눌러야 모든 계좌를 볼 수 있게 됨 항상 내가 아는 모든 앱의 ui는 악화되어감 익숙해지면 바꾸고 개선이 아닌 개악을 함 뭐 ui팀이 일한 티 낸답시고 그러나봄 차라리 걍 대놓고 월급루팡하지',
#  '이번달 나갈 카드금액 총액을 보여줘서 좋았는데 왜 갑자기 바뀌었나요 카드별 금액이랑 합산 총액다시 보여주세요',
#  '다가오는 카드 청구서 합계 금액을 다시 살려주세요 업데이트 하고나서 더 불편해졌어요 카드가 여러개라 결제일이 제각각인데 한달에 나갈 총액이 잘 나오던걸 왜 없앴는지 모르겠네요',
#  '공모주 청약 알림 받기가 안돼요 동의하고 알림받기 누르면 자꾸 필수약관에 동의하래요 체크를 하는 곳이 없는데',
#  '쇼핑앱 오류나서 뭘 사용하지도 못하게 만들어놓고 공지도 안띄우네',
#  '왜 토스쇼핑 구경하기 광고 보기 1분 다 채워도 포인트 안 줍니까 게다가 상품 정보 보고 있으면 스크롤 안 한다고 시간 안 차고 스크롤 좀 빠르게 내리면 빠르다고 시간 안 차고 볼만한 상품 찾느라 오르락내리락하면 오르락내리락한다고 시간 안 차고 대체 이런 기획은 누구 머리에서 나온 건지',
#  '소소하게 포인트 모을 수 있는것도 많고 유용하게 사용할 수 있는 기능이 많아 좋아요',
#  '계좌 저축 투자 연금으로 잘나누어 관리하던걸 섞어버렸네요 홈 계좌 편집도 되다 말다 해서 적응하기 힘든데 일관되게 할때가 되지 않았습니까',
#  '진짜 웬만하면 리뷰안다는데 카톡이 왜 뭣같이바뀌었는지 증명하네',
#  '저 토스쇼핑 그거 구경하고 포인트받으려고 가보니까 갑자기 5천원 쿠폰 뜨길래 당황해서 실수로 눌러 받아버렸지만 전 구매한적 없어요 그리고 그 쿠폰 쓰지도 않았어요 그러니까 빨리해결해주세요 그거 말고도 전 토스에서 쇼핑 단 한번도 한적없는데 내 쇼핑 할인쿠폰 거기 들어가면 제가 한적도 없는게 찍혀있고 좀 많아요 그래서 짜증도 나요 답장주세요',
#  '안녕하세요 최근 업데이트 이후 내 자산 모두 보기 화면이 크게 변경되었는데 기존보다 사용성이 많이 떨어져 불편합니다 특히 이해되지 않는 점은 다음과 같습니다 첫째 자산 항목별 순서 변경 제한입니다 계좌는 순서 변경이 가능한데 카드 대출 투자 보험 포인트는 사용자 임의로 순서 변경이 불가능합니다 자산 관리에서 항목 우선순위는 사용자마다 다른데 이를 서비스 기준으로 고정해 두는 것은 사용자 선택권을 과도하게 제한하는 설계라고 생각합니다 순서 변경 기능을 제공할 것이라면 전 자산 항목에 동일하게 적용되어야 한다고 봅니다 둘째 각 항목의 대표 화면 설정이 불가능합니다 카드나 계좌 등 각 항목에서 처음 표시되는 대표 항목을 사용자가 직접 선택할 수 없고 서비스가 임의로 지정하고 있습니다 자산 관리 앱의 기본적인 사용자 커스터마이징 기능이 부족하다고 느껴집니다 셋째 해지된 카드 삭제 오류입니다 작년에 이미 해지한 카드가 삭제되지 않고 오류가 발생합니다',
#  '아오 본인인증만 받아서 토스페이먼트 결제 진행하려고 하는데 토스에서 뭘 먼저 해볼까요 팝업은 왜 자꾸 뜨죠 스트레스 너무 받고 열이 너무 뻗쳐서 포기했네요',
#  '잘 사용하고 있습니다만 어플 회원가입과 계좌 연결을 하면 포인트 7만원을 준다고 해서 다 완료했는데 포인트를 주지 않는 것이 조금 당황스럽습니다 그 이벤트가 떴던 화면에는 그 내용이 더이상 뜨지도 않아요 어떻게 된건가요',
#  '자산관리가 업데이트 전이 좀 더 보기편하고 한눈에 들어오는거 같아요 자산관리 같은 메뉴는 여러가지 기능을 추가하는 것도 좋지만 간단하면서 명료하고 시인성이 좋아야 한다고 생각합니다 카드의 경우 토스 첫 화면에서도 확인이 가능한데 또 새롭게 추가할 필요가 있나라는 생각이 들구요 자동차 부동산도 굳이라는 생각이 듭니다 왜냐하면 이를 더 전문적으로 확인하고 관리할 수 있는 앱이 있기 때문입니다 그리고 너무 잦은 업데이트는 오히려 불편함을 초래하고 새로운 것에 적응을 하느라 시간이 걸리기 때문에 차라리 한번 정한 디자인이나 기능을 그대로 고수하는 것도 괜찮다고 봅니다',
#  '이거 업데이트하고서 자산 보기 너무 불편하게 바뀐거 같은데 롤백 시켜주면 안되나요 중간중간 광고 같은거 보이는 것도 너무 싫고',
#  '아  홈화면 개별로인데요   홈화면 갑자기 잘 분류해서 쓰고있는데 보기도 어렵고 투자든 저축이든 마음대로 구분해서 편했구만 아 진짜    왜 이렇게 변한건대요   아 제발 전으로 제발 돌려주세요    스트레스받아요 제발 부탁드립니다  꼭 좀 돌려주세요  진심 탈퇴하고싶을 정도입니다',
#  '고생이 많으십니다 혹시 월별 자산 합계는 이제 못 보는 건가요',
#  '왜 토스쇼핑에서 포인트를 필요한 만큼 마음대로 사용할수가 없습니까 사용하려면 전체가 적용됩니다 문의하니 규정이 바꼈다고 하는데 왜 안내에는 아직도 1원 단위로 필요한만큼 쓸수 있다고 안내되어 있는지 전처럼 사용자가 필요한 만큼 사용할수 있게 변경해주세요',
#  '트라이폴드에서 회전이안되는 유일한앱 어서고쳐주세요',
#  '그놈의 페이스페이 페이스페이 페이스페이 열심히 이벤트참여하고 토스쓰고 계좌트고 하면 뭐함 기승전페이스페이 인데 아 극혐',
#  '최근 많이 느려졌어요 주식시황 보기에 노굿',
#  '이벤트 너무 좋아요 sk하이닉스 받음 감사합니다',
#  '부정확한 자산 문구를 대문짝만하게 맨위에 박아 놓는 은행을 어떻게 믿고 써요 일단 돈 다 뺐어요 그리고 광고위치 바꾸지 않으면 절대 쓰지 않을꺼에요 광고 바로 삭제 못하게 알림 딱 그 위치에 띄우고 아주 악질에 도가 트셨어요 합법적 피싱 업체로 탈바꿈 하셨네요 탈퇴가 번거러워 나둘 뿐',
#  's24울트라 쓰는데요 요즘 로그인할때마다 렉이걸려요 계속 버벅거리고 이러는데 왜이러죠',
#  '넥스트거래 시간에 버벅거림 장난아님 돋보기 눌러서 종목탐색 하려해도 흰화면 거래를 위해 보유종목 눌러도 흰화면 정규 거래시간에도 가끔 버벅임 매수버튼을 눌러서 금액 수정을 하려고 플러스 마이너스 버튼 눌러서 안먹히면 금액을 눌러서 직접쳐넣어야 하고 금액눌려서 하려도하면 먹통되서 플러스마이너스버튼을 눌러야만 되는 경우도 생김',
#  '앱실행이 점점 느려지고 다운되는 경우가 잦아지고 있습니다 개선안되면 결국 사용자가 떠날겁니다',
#  '앱사용시 불필요한 광고가 너무 많아 정작 중요한 뱅킹을 사용하기가 익숙하기 전까지 힘들어요',
#  '토스 잘 쓰고 있습니다 라이브 광고 좀 정리해주세요 숏츠 라이브는 숏츠끼리 일반 라이브는 라이브끼리 정리 해주세요 라이브가 자동으로 넘어가서 편하긴한데 제가 뭘 봤는지 헷갈리네요',
#  '신버전 만들면서 기종제한은 왜한거예요 덕분에 내 계정 내 계좌인데 구경은커녕 아무것도 못합니다 신고할곳없나 진짜',
#  '업데이트 이후로 함께 토스켜기에 사람이 안나타납니다 다른사람은 제가 다 뜨는데 저만 문제가 있네요 확인 부탁드려요',
#  '업데이트가 안돼요 99퍼센트에서 멈춰있음',
#  '랙이 무슨 90년대냐 갤울트라 고 모든앱 증권사 다 빠른데 토스만 90년대 컴터랙걸리듯이 작동하는게 말이되냐',
#  'WTS 관리좀 합시다 쓸데없이 메뉴위치 수시로 옮기고 이런거 하지말고 오류부터 고쳐요 차트에 구매 판매 아이콘 클릭 안되는 오류는 의견보내기 해도 며칠째 안되네요 수익분석 에서 화면 UI 안맞는것도 그렇고',
#  '아니 업뎃 하고 송금 등 사용 하기 불편해 지면은',
#  '이번주 미션은 1년 365일 내내 똑같은 미션들만 있네',
#  '함께쓰는 캘린더 위젯사용 시 내용이 바로 안뜨네요 변경방법있나요',
#  '짜증남',
#  '업데이트가 안되고 멈춰요  설치 오류라는데요',
#  '수수료 제일 비쌉니다 압도적 수수료 보는 것만 하시고 타증권사 이용하세요',
#  'Google Play 서비스 오류 토스에서 설정을 완료하려면 탭을 하시오 해서 탭을 했는데 아무것도 안되고 계속 경고창만 계속 떠요',
#  '토스증권 챗봇 성능 너무 안좋은거 쓰시는거 같아요 상담원 연결은 시켜주기 싫고 챗봇은 쓰고싶고 불편하고 열받아도 적응하라고 하는거 같아요 토스 이미지 망치는거 같음',
#  '생채인식여러번 실패했더니 5시간이 지났는데도 안풀려요',
#  '설치후 시간이 지나면 용량이 급증하는거 나만 그런게 아니였구나 앱도 무거워서 자꾸 튕기고 좀 가벼운 저사양 버젼을 내주는건 안되나요',
#  '비번을 5번이나 누르게 하냐  발연아',
#  '토스 증권이 멈추며 클릭이 안되는 현상이 있어 상담 전화 기다려서 문의했는데 비슷한증상 보고 없다고 하시더니 리뷰에 보니 이미 비슷한 문제 있는 분들이 많네요 얼른 고쳐주세요 거래를 못하고있어요',
#  '이벤트 설명엔 해외주식을 선물로 준다며 증권계좌를 개설하게 유도해놓고 나중엔 아무 설명도 없이 그냥 현금으로 바꿔서주네요 만보기에서 받는 복권은 왜 받을때와 긁을때 광고를 두번이나 보게 만든건지도 의문입니다 혜택란의 여러메뉴들을 참여해서 지금까지 받은것중에 몇원짜리 현금말고는 얼굴 인식 정보를 토스에 넘겨야만 쓸수있는 페이스페이 쿠폰밖에 없었습니다',
#  '자산 화면 좀 롤백 해줘요  월급 받아야하니 일 한 티를 내려면 뭔가 업데이트는 해야겠고 딱히 떠오르는게 없으니 그냥 이것저것 바꿔본 거 같은데 더 사용하기 불편하고 구려졌어요 테스트도 안 해보고 그냥 업데이트 하나 봄',
#  '편안해요',
#  '업데이트 떠서 업데이트하려니 업데이트 99 에서 멈춰서 안됩니다',
#  '은행이랑 증권을 분리하던지 해서 어플을 가볍게 만들수는 없는지 토스증권 알림 설정하면 올때도 있고 안올때도 있고 한번 설정한 가격은 유지됐으면 좋겠는데 1회성인것도 이해안되고 잡다한 기능들 다 집어넣어서 어플은 무겁고 느리기만하고 불편해요',
#  '어제부터 메인만 들어가지고 메뉴들이 하나도 안들어가진다고요 흰화면만 뜬다고 뭐에여 대체',
#  '1개도 아까움  그지 같음',
#  '렉 지림 아니 주식을 사교 팔수가엊 움',
#  '선택 동의 항목 거부할 수 있게 수정 좀 해주세요 동의 화면이 다크패턴 수준으로 계속 노출되는데 일시적으로 끄는 것 말고 영구적으로 거부할 수 있는 선택지는 줘야 옳지 않겠어요 갈 수 록 사용자를 불편하게 하면서까지 이익 추구를 하는게 느껴져서 거부감만 더 듭니다',
#  '갤럭시 s25 울트라 oneui8 0 대응되는 위젯 만들어주세요 자꾸 없어집니다',
#  '도대체 앱열때 비번을 왜 4번이나 쳐야되는지',
#  '토스 튕겨요 지금 현재 실행하면 어플이 자동으로 종료되요',
#  '왜 업데이트가 안되는걸까요 새해부터 계속 안되네요',
#  '토스뱅크는 한도 잘 살펴보고 사용해야 할 것 같네요 보증금내려고 토뱅으로 옮겨놨더니 한도가 있었네요 사용하시는 분들 참고하셧음 해서 리뷰 남깁니다',
#  '비밀번호를 똑같이 쳤는데 계속 틀렸다고 뜨네요',
#  '업데이트 전에는 월별자산 보는거 있었는데 업데이트후 월별 자산이 안보이는데 기능없앴나요 있다면 어떻게보나요',
#  '토스뱅크 쓰지마세요 급할때 했던행동 또하고 또반복하고 절박한사람들 골탕먹이는 못된은행 같습니다 왕따를 괴롭히는 주된 은행입니다',
#  '앱 업데이트가 안돼는데 이건 왤까요',
#  '최적화좀 혀주세요 밧데리 소모가 장난아니고 미션이 왜케많은지 백수만 가능한 미션이에요',
#  '증권에 일부는 먹통이 되요',
#  '총 자산에서 자산 비중 조회 기능 복구했으면 합니다 매우 유용한 기능이였는데 사라져서 아쉽습니다 현재는 오직 증권계좌 포트폴리오 빆에 볼 수가 없네요 현금 포지션의 비중을 바로 확인 못해서 불편하네요',
#  '다른건 다 좋은데 광고 좀 걸러주세요 아니 무슨 광고에 강가 스프레이가 나와요 진짜 신고 할려하니 쉽지도 않고 너무 화나서 씁니다',
#  '5초 광고라면서 x 3번 눌러야 끝나는 사실상 20초짜리 광고는 좀',
#  '광고 적립 오류 드럽게 심하네 적립 쫌 잘되게 관리해라 답답아',
#  '업데이트가 안되네요 삭제하고 다시 설치해도 마찬가지구요',
#  '토스 갈수록 짜증나네 진짜 카드결제예정 총액 안나오잖아 볼때마다 일일이 계산해야되',
#  '토스 앱 업데이트가 99 에서 멈춰있어요 구글 플레이 스토어 캐시 삭제해도 똑같네요',
#  '무슨 얘네들 사기꾼들만 모여있나 5초 광고 있다고 해놓고 5초 5초해서 10초로 해놓고 자빠졌네 그리고는 1원만 쳐 주는 놈들 어휴',
#  '갑자기 오후부터 터치고 뭐고 아무것도 안되네요 속터지네 진짜 카카오페이랑 이원화 해야하나 이거만 믿다가 바보되겠네',
#  '설치 중 취소 누르니 무한루핑 걸리며 설치도 제거도 되지 않아요',
#  '앱 내 광고를 끄면 또 떠서 이중 광고하네요',
#  '토스 은행앱으로 사용하는분중에 많은 분들이 월별 자산 변화량 그래프로 보여 주는거 많이 이용 했을건데 도대체 제거하신 이유가 멀까요 토스를 쓰는 이유를 점점 사라지게 하고 있는 업데이트가 이해가 가지 않네요',
#  '업데이트가 99 에서 계속 멈춤 이번 버전은 문제가 있는 것 같음',
#  '이번 업데이트시 99프로에서 넘어가지를 않습니다',
#  '토스를 사용하게 되면서 계좌이체를 한달 동안 사용 되다가 갑자기 안되요 좀 고쳐 주세요',
#  '홈화면 예전으로 돌려놓으시길 증권사 계좌는 한참을 찾아야 들어갈 수 있고 필요도 없는 대출이랑 신용점수는 왜거기 자리잡고 있는건지 이번 개편 담당자 퇴사 시켜야할듯',
#  '업뎃이 안되는데요',
#  '',
#  '잘사용하고있네요',
#  '카카오에서 도망친 사람죽인 성폭행 가해자가 진짜 토스에 이직한게 맞나요 토스는 구직자에 최소한의 선도 두지 않는건가요 해명 부탁드립니다',
#  '귀여워',
#  '미국장에서 거래시 거래가능한 원화가 있을때 자동환전 되는 기능때문에 원치 않는 비싼 수수료를 내야합니다 고쳐지질 않네요 다른 증권사 앱으로 넘어 갈까봐요',
#  '왠만하면 이런 리뷰 잘 안쓰는데 업데이트 후 너무 버벅 거리네요 항목 들어갈때마다 너무 끊겨서 답답합니다 그리고 복권이나 다른 이벤트 들어갈려고 광고를 보는데 광고가 무한 되풀이되네요 얼른 개선 부탁드립니다 너무 불편하네요',
#  '노트20 이제 이거 못쓰는데 토스로 자동이체 걸어놓은거 어떻게 없앨 수 있나요',
#  '다운로드 업데이트가99 에서 계속멈춰있내요',
#  '카톡 따라가고 있음 계좌 계좌 잔액만 확인 하면 되는데 자꾸 뭔 해외계좌 거쳐서 들어가지니까 딜레이 됨 수정 요청 했으나 요지부동 어플을 눌러서 켜고 계좌 내역 보려는데 왜 있지도 않은 해외 자산을 거쳐서 가느냐는 이야기고요 24시간 상담 통해서 전달 한다고 했으나 바뀌는게 없어서 글 올리는 겁니다 다이렉트로 메일도 보냈으나 24시간 상담이 해결을 못하니 비효율적이라 여기다 글 쓴겁니다 돌아오는 답변이 같은데 왜 반복된 행동을 하겠습니까  거쳐서 거는게 뭐 1 2초 라고 할순 있는데 이체 및 내역 확인 하는것도 얼마 안걸립니다 그냥 할것 하면 되는데 왜 저기다 불필요한 동선 작업 을 추가 했는지 의문이라서요',
#  '렉이 너무 심합니다 평소 렉이 없었는데 짜증지 느껴질정도로 렉이 너무 심합니다 휴대폰 문제라고 보기엔 다른 앱들은 정상적으로 빠르게 작동이 됩니다 특정 기능에서만 렉이 발생하기 보다는 어플을 시작할 때부터 시작해서 송금 만보기 고양이 키우기 등 모든 기능에서 렉이 발생합니다 빨리 확인해주시고 조치를 취해주셨으면 합니다',
#  '앱이 너무 느려졌어요 하 조치를 취해주시기 바랍니다',
#  '월별 자산내역 보는 게 너무 별로 과거 내역이 수시로 바뀌고 변동성도 너무 큼 앱 성격이 다르긴하지만 뱅샐이랑 많이 비교됨 자산관리는 뱅샐로 하고 송금은 토스로 하는중 이상한 기능 그만 넣고 자산관리 내역좀 더 신경 써주세요 토스에서 이 부분이 가장 불만족임',
#  '어플이 머무 느려졌습니다 자산보기도 이전버전이 보기 편해요 카톡처럼 다시 돌려주세요',
#  '갤럭시 S9 모델명 SM G965N 기기 사용자입니다 이번 업데이트부터 제 기기에 다운로드를 받을 수 없습니다 토스의 증권 카드 계좌가 다 있는데 제 단말기에 대한 업데이트가 중지되어 어플 자체를 이용할 수 없습니다 구형 기기 사용자에대한 일방적인 접근성 제한이 너무하다고 생각합니다 저는 토스의 잔액 송금 등 모든 금융 서비스를 이용할 수 없습니다 고객편의와 혁신을 우선시 하는 토스팀에게 매우 실망했습니다 실물 통장이나 카드도 없기에 더욱 황당한 상황입니다 궁여지책으로 타 은행 마이데이터를 통해 간이로 금융 업무는 보지만 매우 제한적입니다 타 은행 중 그 어느곳도 구형 기기에 대한 접근성 제한이 없는 상황입니다 구형 기기에 대한 업데이트 지원을 해주시면 감사하겠습니다 작년 10to100 행사에서 본 이승건 대표님과 제가 아는 기민한 토스팀은 제 글을 검토하여 빠르게 답변 내지는 솔루션을 내줄 것이라고 믿어 의심치 않습니다',
#  '업데이트가 안됩니다',
#  '제발 토스 함께켜기좀 삭제해라 아줌마들이 맨날 토스키라고 소리지르고 문두드리고 10원도 없는 사람마냥 구는데 짜증나 죽겠다',
#  '느리고 오류많아서 스트레스 받네요',
#  '토스이벤트들 친구들한테 공유하기 카가오톡 오픈채팅에 하면 정지 or 영구정지 시키네요',
#  '잠궈다 아니고 잠그다 예요 따라서 계좌를 잠궈 가 아니고 계자를 잠가 라고 표현해야죠 앱 설계할 때 아무도 지적한 사람이 없어 신뢰할 수 있는 금융앱 맞나 싶어요',
#  'toss ui의 퇴보',
#  '아니 동 호수 없는 건물인데 주소에 동 호수 무조건 넣으라는 건 뭔데 이거 도대체 누가 프로그램한거냐 생각이 없는거냐 실력이 없는거냐 번지까지만 있는 주소는 주소 아니냐 진짜 뭐 하자는건지 모르겠다 입력하다가 안 되서 때려치웠다 진짜 쓰기 싫어진다 답변 붙어서 더 적음 건물이름이라도 적으라고 회사 주소라서 회사이름 적으니깐 동 호수 적으라면서 안 넘어가더라 내가 왜 열 받았는지도 파악 못 하고 있네 진짜 회사이름 적으니깐 동 호수나 층 구분할 수 있는 숫자 넣으라면서 안 넘어갔음 이젠 더 설명하기도 귀찮음',
#  '전 사용하기 너무 편해서 좋은데 불만이 많은 사람들이 많네요 근데 만보기 복권은 정말 당첨이 되는건가요 일년 몇개월 동안 매일매일 열심히 긁어도 몇원 짜리만 암튼 잘 사용하고 있습니다',
#  '예전엔 계좌 모두보기 누르면 한번에 다 보였는데 업뎃후론 굳이굳이 모두보기 누르고 또 계좌 전체보기 또들어가야함 개불편 왜이렇게 바꾼거임',
#  '미성년자는 탈퇴를 못하네요',
#  '와 아니 무슨 로봇인가 계속 같은 말을 반복하시네 여기는 일을 똑바로 하는 직원이 하나도 없나요 상담원은 전화를 준다더니 아직까지 연락도 없어 앱스토어 리뷰 답변자는 말귀를 못 알아듣고 계속 같은 말만 반복해    말같지도 않은 소리하면서 짜증나게 하지 마시고요 저는 그쪽에서 일으킨 문제에 제 돈 내고 제 시간 써가면서 통화할 생각도 없고 연결도 안되는 고객센터 상담할 생각도 없으니까 12월 30일 오후 3시 6분 상담기록 찾아서 저한테 전화하라고 하세요 그리고 지금 저한테 답변하시는 분은 성함이 어떻게 되시죠 맨 처음 광고가 안 꺼진다는 문의를 남겼을 때 저한테 휴대폰 설정 들어가서 캐시 삭제하라는 답변을 남긴 분도 선생님인가요',
#  '용량이 이상하게 작동합니다 처음 설치하고 몇시간동안은 390mb 정도인데 몇시간 뒤에 보면 830mb 정도로 늘어나서 이때마다 지웠다가 다시 설치를 반복하고 있습니다 데이터나 캐시에 통합되서 830mb가 나오는거면 데이터삭제나 캐시삭제만 하면 되는데 어플리케이션 용량 자체가 390mb 830mb 로 늘어나는 경우라서 삭제후 재설치만 2주 내내 반복하다가 너무 불편하기에 문의 남깁니다',
#  '일좀 해라 일좀 주식이 바로 안팔리는게 말이 되냐 수익내서 바로 팔려고 했는데 무슨 안팔려서 마이너스에 쳐먹을뻔했잖아 일좀 해라 일좀 토스야 제발',
#  '주식 렉좀 고쳐주세요 제발',
#  ...]

# %%
from gensim.models import CoherenceModel, Word2Vec
from sklearn.manifold import TSNE

# %%
# =========================
# ✅ Word2Vec + t-SNE 시각화만 (토픽 모델링 재실행 없음)
# 필요 전제: topic_words_map 이 존재해야 함
#   - topic_words_map[(bank_eng, senti)] = set(토픽 단어들)
# =========================

import numpy as np
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
from gensim.models import Word2Vec

# -------------------------
# 1) MeCab tokenizer (동일 기준)
# -------------------------
def mecab_tokenizer(text):
    return [w for w in mecab.morphs(str(text)) if len(w) > 1]

def tokenize_docs(texts):
    tokenized = []
    for t in texts:
        toks = mecab_tokenizer(t)
        if len(toks) >= 2:
            tokenized.append(toks)
    return tokenized


# -------------------------
# 2) Word2Vec 한 번만 학습 (train_df 있을 때)
# -------------------------
W2V_VECTOR_SIZE = 100
W2V_WINDOW = 5
W2V_MIN_COUNT = 2
W2V_WORKERS = 4
W2V_SG = 1
W2V_SEED = 42

w2v_model = None


all_reviews = toss['사용자리뷰'].dropna().apply(text_clean).tolist() + kb['사용자리뷰'].dropna().apply(text_clean).tolist()
all_tokenized = tokenize_docs(all_reviews)

if len(all_tokenized) >= 5:
    w2v_model = Word2Vec(
        sentences=all_tokenized,
        vector_size=W2V_VECTOR_SIZE,
        window=W2V_WINDOW,
        min_count=W2V_MIN_COUNT,
        workers=W2V_WORKERS,
        sg=W2V_SG,
        seed=W2V_SEED
    )
    print(f"✅ Word2Vec 학습 완료 | 전체 리뷰: {len(all_reviews)} | 유효 토큰 문서: {len(all_tokenized)}")
else:
    print("⚠ Word2Vec 학습용 유효 토큰 문서가 너무 적어 학습을 건너뜁니다.")



# -------------------------
# 3) t-SNE 시각화 (topic_words_map 기반)
# -------------------------
if w2v_model is None:
    print("⚠ w2v_model이 없어 t-SNE 시각화를 할 수 없습니다.")
elif 'topic_words_map' not in globals() or len(topic_words_map) == 0:
    print("⚠ topic_words_map이 없습니다. (토픽 모델링 단계에서 토픽 단어 set 저장 필요)")
else:
    for bank_senti, all_topic_words in topic_words_map.items():
        valid_words = [w for w in all_topic_words if w in w2v_model.wv]

        print(f"\n({bank_senti}) 토픽단어 {len(all_topic_words)}개 | W2V 포함 {len(valid_words)}개")

        if len(valid_words) < 3:
            print("   ⚠ Word2Vec에 있는 단어가 3개 미만이라 스킵")
            continue

        vectors = np.array([w2v_model.wv[w] for w in valid_words])

        # perplexity 자동 조절
        tsne_perplexity = min(15, max(5, (len(valid_words) - 1) // 3))
        tsne_perplexity = min(tsne_perplexity, len(valid_words) - 1)
        if tsne_perplexity < 2:
            tsne_perplexity = 2
        print(f"   ▶ t-SNE perplexity = {tsne_perplexity}")

        tsne = TSNE(
            n_components=2,
            random_state=0,
            perplexity=tsne_perplexity,
            init="pca",
            learning_rate="auto"
        )
        reduced_vecs = tsne.fit_transform(vectors)

        plt.figure(figsize=(10, 6))
        for i, word in enumerate(valid_words):
            x, y = reduced_vecs[i]
            plt.scatter(x, y)
            plt.text(x + 0.01, y + 0.01, word, fontsize=12)

        plt.title(f"{bank_senti} 토픽 단어 Word2Vec t-SNE")
        plt.grid(True)
        plt.show()
# Out:
# ✅ Word2Vec 학습 완료 | 전체 리뷰: 9864 | 유효 토큰 문서: 8524
#
# (토스 긍정) 토픽단어 62개 | W2V 포함 62개
#    ▶ t-SNE perplexity = 15
# (토스 부정) 토픽단어 56개 | W2V 포함 56개
#    ▶ t-SNE perplexity = 15
# (국민 긍정) 토픽단어 67개 | W2V 포함 67개
#    ▶ t-SNE perplexity = 15
# (국민 부정) 토픽단어 40개 | W2V 포함 40개
#    ▶ t-SNE perplexity = 13
