# %% [markdown]
# # 지도학습_분류분석_컬럼선택법_ 클래스불균형처리_ 모델성능향상시키기

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import koreanize_matplotlib

# %%
data=data = pd.read_csv("./data/salary2.csv")

# %%
data.head(2)
# Out:
#    age workclass education  education-num       marital-status  \
# 0   25   Private      11th              7        Never-married
# 1   38   Private   HS-grad              9   Married-civ-spouse
#
#            occupation relationship    race    sex  capital-gain  capital-loss  \
# 0   Machine-op-inspct    Own-child   Black   Male             0             0
# 1     Farming-fishing      Husband   White   Male             0             0
#
#    hours-per-week  native-country   class
# 0              40   United-States   <=50K
# 1              50   United-States   <=50K

# %% [markdown]
# # train데이터/test데이터 분리

# %%
from sklearn.model_selection import train_test_split

# %%
train, test = train_test_split(data, test_size=0.4, random_state=10, stratify=data['class'])

# %%
train.head() # 불규칙하게 섞여서 나옴
# Out:
#        age          workclass      education  education-num  \
# 12689   49   Self-emp-not-inc        HS-grad              9
# 30011   45            Private        HS-grad              9
# 28454   55          Local-gov        HS-grad              9
# 17394   69            Private        HS-grad              9
# 31597   21            Private   Some-college             10
#
#             marital-status          occupation     relationship    race  \
# 12689   Married-civ-spouse     Exec-managerial          Husband   White
# 30011   Married-civ-spouse   Machine-op-inspct          Husband   White
# 28454   Married-civ-spouse      Prof-specialty   Other-relative   White
# 17394   Married-civ-spouse               Sales             Wife   White
# 31597        Never-married   Machine-op-inspct        Own-child   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country  \
# 12689     Male             0             0              35   United-States
# ...

# %%
test.head()
# Out:
#        age   workclass      education  education-num       marital-status  \
# 22332   56         NaN        HS-grad              9             Divorced
# 33515   57     Private        HS-grad              9             Divorced
# 39475   37   State-gov      Doctorate             16   Married-civ-spouse
# 11140   19     Private   Some-college             10        Never-married
# 39998   41   State-gov      Bachelors             13        Never-married
#
#             occupation    relationship    race      sex  capital-gain  \
# 22332              NaN   Not-in-family   White     Male             0
# 33515     Adm-clerical       Unmarried   White   Female             0
# 39475   Prof-specialty         Husband   White     Male             0
# 11140    Other-service   Not-in-family   White   Female             0
# 39998   Prof-specialty   Not-in-family   White     Male             0
#
#        capital-loss  hours-per-week  native-country   class
# ...

# %% [markdown]
# # 전처리
# - 중복제거
# - 결측값 삭제
# - class컬럼 label encoding

# %%
train=train.drop_duplicates()
test=test.drop_duplicates()

# %%
train=train.dropna()
test=test.dropna()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le

# %% [markdown]
# # 중요 컬럼 선택하기
# - EDA를 통해서 종속변수와 중요한 관계가 있는 변수들만 선택
# - 수치형 변수는 상관분석 결과를 통해 선택, 범주형 변수는 카이제곱 통계량 분석을 통해 선택 -> 굳이 안 함
# - 머신러닝 알고리즘을 통한 1차 분석 후 중요하게 사용된 변수만 선택 -> 이거 할 거임!

# %% [markdown]
# # tree 계열 모델의 feature_importance로 선택하기

# %%
X_train=train.drop('class', axis=1)
y_train=train.drop('class', axis=1)
display(X_train.head())
y_train.value_counts()
# Out:
#        age          workclass      education  education-num  \
# 12689   49   Self-emp-not-inc        HS-grad              9
# 30011   45            Private        HS-grad              9
# 28454   55          Local-gov        HS-grad              9
# 17394   69            Private        HS-grad              9
# 31597   21            Private   Some-college             10
#
#             marital-status          occupation     relationship    race  \
# 12689   Married-civ-spouse     Exec-managerial          Husband   White
# 30011   Married-civ-spouse   Machine-op-inspct          Husband   White
# 28454   Married-civ-spouse      Prof-specialty   Other-relative   White
# 17394   Married-civ-spouse               Sales             Wife   White
# 31597        Never-married   Machine-op-inspct        Own-child   White
#
#            sex  capital-gain  capital-loss  hours-per-week  native-country
# 12689     Male             0             0              35   United-States
# ...

# %%
X_test=test.drop('class', axis=1)
y_test=test.drop('class', axis=1)
display(X_test.head())
y_test.value_counts()
# Out:
#        age   workclass      education  education-num       marital-status  \
# 33515   57     Private        HS-grad              9             Divorced
# 39475   37   State-gov      Doctorate             16   Married-civ-spouse
# 11140   19     Private   Some-college             10        Never-married
# 39998   41   State-gov      Bachelors             13        Never-married
# 24777   21     Private   Some-college             10        Never-married
#
#             occupation    relationship    race      sex  capital-gain  \
# 33515     Adm-clerical       Unmarried   White   Female             0
# 39475   Prof-specialty         Husband   White     Male             0
# 11140    Other-service   Not-in-family   White   Female             0
# 39998   Prof-specialty   Not-in-family   White     Male             0
# 24777    Other-service       Own-child   White     Male             0
#
#        capital-loss  hours-per-week  native-country
# ...

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
def to_ohe(X_train, X_test):
    cat_cols=X_train.select_dtypes(include='object').columns
    ct=ColumnTransformer(transformers=[('ohe')])

# %% [markdown]
# # 의사결정 나무 분석 후 feature_importance 추출

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dtc_import

# %% [markdown]
# # 의사결정 나무에서 중요하게 본 변수만 선택해서 분석

# %%
dtc_train.columns # 컬럼 이름 리스트
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 dtc_train.columns # 컬럼 이름 리스트
#
# NameError: name 'dtc_train' is not defined

# %%
test[dtc_train.columns]

# %% [markdown]
# # XGBoost의 경우
