# %% [markdown]
# # 비지도 학습 군집분석: 정답지가 없는 분석
# - 컴퓨터가 알아서 학습함

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import koreanize_matplotlib

# %%
data = pd.read_csv("./data/shopping-data.csv") # 쇼핑몰 고객의 연봉, 구매력
data
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    str
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), str(1)
# memory usage: 7.9 KB

# %%
data.describe() # 이상값 있는지 확인 - 중앙값, 평균값 비교
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
data.plot(kind='box')
# Out:
# <Axes: >

# %% [markdown]
# # 군집분석(계층적 군집, 비계층적 군집)
# * 계층적 군집
#   * 비지도학습
#   * 데이터가 적을 때 사용
#   * 거리 계산 지표: 유클리드, 맨하탄, 코사인 유사도
# * 계층적 군집 5가지
#   * 단일연결법(single linkage), 최단연결법: 군집과 군집 사이에서 가장 가까운 데이터를 기준으로 묶음
#   * 완전연결법(complite linkage), 최장연결법: 군집과 군집 사이에서 가장 먼 데이터를 기준으로 묶음
#   * 평균연결법(average linkage): 군집과 군집 사이의 모든 데이터의 평균 데이터로 계산(이상치에 덜 민감)
#   * 중심연결법(centroid linkage): 군집과 중심점 사이의 거리를 거리로 측정한 방법, 계산이 빠름
#   * 와드연결법(ward linkage): 군집내 오차가 최소가 되는 데이터로 계산, 군집내 분산이 최소, 조밀한 군집
# * 계층적 군집의 시각화는 덴드로그램으로 한다.

# %%
import scipy.cluster.hierarchy as shc

# %%
data = pd.get_dummies(data, drop_first=True) # True/False로 나누기
data
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male
# 0             1   19                  15                      39        True
# 1             2   21                  15                      81        True
# 2             3   20                  16                       6       False
# 3             4   23                  16                      77       False
# 4             5   31                  17                      40       False
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79       False
# 196         197   45                 126                      28       False
# 197         198   32                 126                      74        True
# 198         199   32                 137                      18        True
# 199         200   30                 137                      83        True
#
# [200 rows x 5 columns]

# %%
data2 = data.copy()

# %%
data = data.drop('CustomerID', axis=1)
data
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male
# 0     19                  15                      39        True
# 1     21                  15                      81        True
# 2     20                  16                       6       False
# 3     23                  16                      77       False
# 4     31                  17                      40       False
# ..   ...                 ...                     ...         ...
# 195   35                 120                      79       False
# 196   45                 126                      28       False
# 197   32                 126                      74        True
# 198   32                 137                      18        True
# 199   30                 137                      83        True
#
# [200 rows x 4 columns]

# %% [markdown]
# # 군집분석 - 거리가 중요하므로 스케일링 필수

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss = StandardScaler()
scaled_df = ss.fit_transform(data)
scaled_df = pd.DataFrame(scaled_df, index=data.index, columns=data.columns)
scaled_df
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male
# 0   -1.424569           -1.738999               -0.434801    1.128152
# 1   -1.281035           -1.738999                1.195704    1.128152
# 2   -1.352802           -1.700830               -1.715913   -0.886405
# 3   -1.137502           -1.700830                1.040418   -0.886405
# 4   -0.563369           -1.662660               -0.395980   -0.886405
# ..        ...                 ...                     ...         ...
# 195 -0.276302            2.268791                1.118061   -0.886405
# 196  0.441365            2.497807               -0.861839   -0.886405
# 197 -0.491602            2.497807                0.923953    1.128152
# 198 -0.491602            2.917671               -1.250054    1.128152
# 199 -0.635135            2.917671                1.273347    1.128152
#
# [200 rows x 4 columns]

# %% [markdown]
# * 싱글링키지(single linkage) = 최단연결법

# %%
plt.figure(figsize=(20, 10))
plt.title('Single linage Dendrogram')
dend = shc.dendrogram(shc.linkage(scaled_df, method='single'))
plt.show()

# %% [markdown]
# * 완전연결법(complete linkage) 최장연결법

# %%
plt.figure(figsize=(20, 10))
plt.title('complete linkage Dendrogram')
dend = shc.dendrogram(shc.linkage(scaled_df, method='complete'))
plt.show()

# %% [markdown]
# * 평균 연결법(average linkage)

# %%
plt.figure(figsize=(20, 10))
plt.title('Average linkage Dendrogram')
dend = shc.dendrogram(shc.linkage(scaled_df, method='average'))
plt.show()

# %% [markdown]
# * 중심연결법(centroid linkage)

# %%
plt.figure(figsize=(20, 10))
plt.title('Centroid linkage Dendrogram')
dend = shc.dendrogram(shc.linkage(scaled_df, method='centroid'))
plt.show()

# %% [markdown]
# * 와드연결법(ward linkage) - 군집 내 분산 최소화

# %%
plt.figure(figsize=(20, 10))
plt.title('Ward linkage Dendrogram')
dend = shc.dendrogram(shc.linkage(scaled_df, method='ward'))
plt.show()

# %% [markdown]
# # scikit-learn을 이용한 계층군집

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
single = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='single') # metric, linkage 정할 수 있음
result = single.fit_predict(scaled_df)
result
# Out:
# array([0, 0, 1, 2, 2, 2, 2, 2, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 0, 2, 0, 0,
#        2, 0, 2, 0, 2, 0, 2, 2, 0, 2, 0, 0, 2, 2, 2, 2, 2, 2, 2, 0, 0, 2,
#        2, 2, 2, 2, 2, 2, 2, 0, 2, 0, 2, 0, 2, 0, 2, 0, 0, 0, 2, 2, 0, 0,
#        2, 2, 0, 2, 0, 2, 2, 2, 0, 0, 2, 0, 2, 2, 0, 0, 0, 2, 2, 0, 2, 2,
#        2, 2, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 2, 2, 0, 0, 0, 2, 2, 0, 0, 0,
#        0, 2, 2, 0, 2, 2, 2, 2, 2, 2, 0, 2, 2, 0, 2, 2, 0, 0, 0, 0, 0, 0,
#        2, 2, 0, 2, 2, 0, 0, 2, 2, 0, 2, 2, 0, 0, 0, 2, 2, 0, 0, 0, 2, 2,
#        2, 2, 0, 2, 0, 2, 2, 2, 0, 2, 0, 2, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2,
#        0, 0, 0, 0, 2, 2, 0, 2, 2, 0, 2, 0, 2, 2, 2, 2, 0, 2, 2, 2, 2, 0,
#        0, 0])

# %%
data2['single'] = result
data2
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male  \
# 0             1   19                  15                      39        True
# 1             2   21                  15                      81        True
# 2             3   20                  16                       6       False
# 3             4   23                  16                      77       False
# 4             5   31                  17                      40       False
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79       False
# 196         197   45                 126                      28       False
# 197         198   32                 126                      74        True
# 198         199   32                 137                      18        True
# 199         200   30                 137                      83        True
#
#      single
# 0         0
# 1         0
# ...

# %%
for linkage in ['complete', 'average', 'ward']:
    single = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage=linkage)
    result = single.fit_predict(scaled_df)
    data2[linkage] = result
    display(data2)
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male  \
# 0             1   19                  15                      39        True
# 1             2   21                  15                      81        True
# 2             3   20                  16                       6       False
# 3             4   23                  16                      77       False
# 4             5   31                  17                      40       False
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79       False
# 196         197   45                 126                      28       False
# 197         198   32                 126                      74        True
# 198         199   32                 137                      18        True
# 199         200   30                 137                      83        True
#
#      single  complete
# ...

# %%
data2
# Out:
#      CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Genre_Male  \
# 0             1   19                  15                      39        True
# 1             2   21                  15                      81        True
# 2             3   20                  16                       6       False
# 3             4   23                  16                      77       False
# 4             5   31                  17                      40       False
# ..          ...  ...                 ...                     ...         ...
# 195         196   35                 120                      79       False
# 196         197   45                 126                      28       False
# 197         198   32                 126                      74        True
# 198         199   32                 137                      18        True
# 199         200   30                 137                      83        True
#
#      single  complete  average  ward
# ...

# %%
data2[data2['single']==2].describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)  \
# count  111.000000  111.000000          111.000000              111.000000
# mean    98.414414   38.261261           59.639640               51.936937
# std     57.835891   12.582608           25.799504               23.828661
# min      4.000000   18.000000           16.000000                5.000000
# 25%     47.500000   29.500000           40.000000               37.000000
# 50%     95.000000   35.000000           60.000000               50.000000
# 75%    148.500000   48.000000           77.500000               73.000000
# max    197.000000   68.000000          126.000000               99.000000
#
#        single    complete  average        ward
# count   111.0  111.000000    111.0  111.000000
# mean      2.0    1.054054      1.0    0.603604
# std       0.0    0.795874      0.0    0.717056
# min       2.0    0.000000      1.0    0.000000
# 25%       2.0    0.000000      1.0    0.000000
# ...

# %%
data2[data2['average']==0].describe()
# Out:
#        CustomerID        Age  Annual Income (k$)  Spending Score (1-100)  \
# count   47.000000  47.000000           47.000000               47.000000
# mean   108.170213  49.765957           63.957447               29.978723
# std     52.182922  13.997225           23.475202               19.664014
# min      9.000000  19.000000           19.000000                1.000000
# 25%     68.000000  41.000000           48.500000               11.500000
# 50%    108.000000  49.000000           63.000000               35.000000
# 75%    154.000000  59.500000           78.000000               47.500000
# max    199.000000  70.000000          137.000000               60.000000
#
#        single   complete  average       ward
# count    47.0  47.000000     47.0  47.000000
# mean      0.0   1.191489      0.0   1.382979
# std       0.0   0.969946      0.0   0.491369
# min       0.0   0.000000      0.0   1.000000
# 25%       0.0   0.000000      0.0   1.000000
# ...

# %% [markdown]
# # 비계층적 군집 - 데이터 수가 많을 때 사용 -> 실제로 더 많이 쓰임!
# - **k-means (k 평균 군집)** : 거리를 기반으로 군집을 형성, 이상치에 민감함
# - StandardScaler 사용 필수, 데이터에 이상치가 있으면 RobustScaler 사용 (이상치 영향 없앰)
# - 이상치가 많은 경우 - 평균이 아닌 중앙값을 이용해서 군집 형성
# - k의 개수를 구하는 것이 튜닝 방법임 -> 최적의 개수k를 구해야 함!

# %%
data=pd.read_csv("./data/고객이탈예측.csv", encoding='cp949')
data
# Out:
#             회원ID      성별  고연령  배우자 피부양자  가입기간 전화서비스             2회선이상  \
# 0     7590-VHVEG  Female    0  Yes   No     1    No  No phone service
# 1     5575-GNVDE    Male    0   No   No    34   Yes                No
# 2     3668-QPYBK    Male    0   No   No     2   Yes                No
# 3     7795-CFOCW    Male    0   No   No    45    No  No phone service
# 4     9237-HQITU  Female    0   No   No     2   Yes                No
# ...          ...     ...  ...  ...  ...   ...   ...               ...
# 7038  6840-RESVB    Male    0  Yes  Yes    24   Yes               Yes
# 7039  2234-XADUH  Female    0  Yes  Yes    72   Yes               Yes
# 7040  4801-JZAZL  Female    0  Yes  Yes    11    No  No phone service
# 7041  8361-LTMKD    Male    1  Yes   No     4   Yes               Yes
# 7042  3186-AJIEK    Male    0   No   No    66   Yes                No
#
#            인터넷서비스 온라인보안  ... 기기보호서비스 기술지원 스트리밍TV 스트리밍Movies            약정옵션  \
# ...

# %%
data['합산요금'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 data['합산요금'].astype(float)
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/pandas/core/generic.py:6541, in NDFrame.astype(self, dtype, copy, errors)
#    6537     results = [ser.astype(dtype, errors=errors) for _, ser in self.items()]
#    6539 else:
#    6540     # else, only a single dtype is given
# -> 6541     new_data = self._mgr.astype(dtype=dtype, errors=errors)
#    6542     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6543     return res.__finalize__(self, method="astype")
#
# File ~/miniforge3/envs/fintech2/lib/python3.11/site-packages/pandas/core/internals/managers.py:611, in BaseBlockManager.astype(self, dtype, errors)
#     610 def astype(self, dtype, errors: str = "raise") -> Self:
# ...

# %%
# 공백(결측치) 필터링 해줘야 함

data[data['합산요금']==' '] # -> 결측값 무조건 평균대치하면 안 됨
# 합산요금이 가입기간과 관련 있음 -> data['합산요금']==' ' 은 신규 가입자임
# 월요금을 합산요금으로 해줘야 함
# Out:
#             회원ID      성별  고연령  배우자 피부양자  가입기간 전화서비스             2회선이상 인터넷서비스  \
# 488   4472-LVYGI  Female    0  Yes  Yes     0    No  No phone service    DSL
# 753   3115-CZMZD    Male    0   No  Yes     0   Yes                No     No
# 936   5709-LVOEQ  Female    0  Yes  Yes     0   Yes                No    DSL
# 1082  4367-NUYAO    Male    0  Yes  Yes     0   Yes               Yes     No
# 1340  1371-DWPAZ  Female    0  Yes  Yes     0    No  No phone service    DSL
# 3331  7644-OMVMY    Male    0  Yes  Yes     0   Yes                No     No
# 3826  3213-VVOLG    Male    0  Yes  Yes     0   Yes               Yes     No
# 4380  2520-SGTTA  Female    0  Yes  Yes     0   Yes                No     No
# 5218  2923-ARZLG    Male    0  Yes  Yes     0   Yes                No     No
# 6670  4075-WKNIU  Female    0  Yes  Yes     0   Yes               Yes    DSL
# 6754  2775-SEFEE    Male    0   No  Yes     0   Yes               Yes    DSL
#
# ...

# %%
data.loc[data['합산요금']==' ','월요금']
# Out:
# 488     52.55
# 753     20.25
# 936     80.85
# 1082    25.75
# 1340    56.05
# 3331    19.85
# 3826    25.35
# 4380    20.00
# 5218    19.70
# 6670    73.35
# 6754    61.90
# Name: 월요금, dtype: float64

# %%
hap_price = data.loc[data['합산요금'] == ' ', '월요금'].astype(str)

# %%
hap_price
# Out:
# 488     52.55
# 753     20.25
# 936     80.85
# 1082    25.75
# 1340    56.05
# 3331    19.85
# 3826    25.35
# 4380     20.0
# 5218     19.7
# 6670    73.35
# 6754     61.9
# Name: 월요금, dtype: str

# %%
data.loc[data['합산요금'] == ' ', '합산요금'] = hap_price

# %%
data.loc[488]
# Out:
# 회원ID                         4472-LVYGI
# 성별                               Female
# 고연령                                   0
# 배우자                                 Yes
# 피부양자                                Yes
# 가입기간                                  0
# 전화서비스                                No
# 2회선이상                  No phone service
# 인터넷서비스                              DSL
# 온라인보안                               Yes
# 온라인백업                                No
# 기기보호서비스                             Yes
# 기술지원                                Yes
# 스트리밍TV                              Yes
# 스트리밍Movies                           No
# 약정옵션                           Two year
# 온라인고지서                              Yes
# 지불수단          Bank transfer (automatic)
# 월요금                               52.55
# 합산요금                              52.55
# 이탈여부                                 No
# Name: 488, dtype: object

# %%
data.loc[data['합산요금'] == ' ']
# Out:
# Empty DataFrame
# Columns: [회원ID, 성별, 고연령, 배우자, 피부양자, 가입기간, 전화서비스, 2회선이상, 인터넷서비스, 온라인보안, 온라인백업, 기기보호서비스, 기술지원, 스트리밍TV, 스트리밍Movies, 약정옵션, 온라인고지서, 지불수단, 월요금, 합산요금, 이탈여부]
# Index: []
#
# [0 rows x 21 columns]

# %%
data['합산요금'] = data['합산요금'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   회원ID        7043 non-null   str
#  1   성별          7043 non-null   str
#  2   고연령         7043 non-null   int64
#  3   배우자         7043 non-null   str
#  4   피부양자        7043 non-null   str
#  5   가입기간        7043 non-null   int64
#  6   전화서비스       7043 non-null   str
#  7   2회선이상       7043 non-null   str
#  8   인터넷서비스      7043 non-null   str
#  9   온라인보안       7043 non-null   str
#  10  온라인백업       7043 non-null   str
#  11  기기보호서비스     7043 non-null   str
#  12  기술지원        7043 non-null   str
#  13  스트리밍TV      7043 non-null   str
#  14  스트리밍Movies  7043 non-null   str
#  15  약정옵션        7043 non-null   str
#  16  온라인고지서      7043 non-null   str
#  17  지불수단        7043 non-null   str
#  18  월요금         7043 non-null   float64
#  19  합산요금        7043 non-null   float64
# ...

# %%
data['가입기간'].value_counts()
# Out:
# 가입기간
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64

# %% [markdown]
# - 범주형 변수를 one-hot encoding

# %%
data2=data.drop('회원ID', axis=1)
data2
# Out:
#           성별  고연령  배우자 피부양자  가입기간 전화서비스             2회선이상       인터넷서비스 온라인보안  \
# 0     Female    0  Yes   No     1    No  No phone service          DSL    No
# 1       Male    0   No   No    34   Yes                No          DSL   Yes
# 2       Male    0   No   No     2   Yes                No          DSL   Yes
# 3       Male    0   No   No    45    No  No phone service          DSL   Yes
# 4     Female    0   No   No     2   Yes                No  Fiber optic    No
# ...      ...  ...  ...  ...   ...   ...               ...          ...   ...
# 7038    Male    0  Yes  Yes    24   Yes               Yes          DSL   Yes
# 7039  Female    0  Yes  Yes    72   Yes               Yes  Fiber optic    No
# 7040  Female    0  Yes  Yes    11    No  No phone service          DSL   Yes
# 7041    Male    1  Yes   No     4   Yes               Yes  Fiber optic    No
# 7042    Male    0   No   No    66   Yes                No  Fiber optic   Yes
#
# ...

# %%
data2 = pd.get_dummies(data2, drop_first=True)
data2
# Out:
#       고연령  가입기간     월요금     합산요금  성별_Male  배우자_Yes  피부양자_Yes  전화서비스_Yes  \
# 0       0     1   29.85    29.85    False     True     False      False
# 1       0    34   56.95  1889.50     True    False     False       True
# 2       0     2   53.85   108.15     True    False     False       True
# 3       0    45   42.30  1840.75     True    False     False      False
# 4       0     2   70.70   151.65    False    False     False       True
# ...   ...   ...     ...      ...      ...      ...       ...        ...
# 7038    0    24   84.80  1990.50     True     True      True       True
# 7039    0    72  103.20  7362.90    False     True      True       True
# 7040    0    11   29.60   346.45    False     True      True      False
# 7041    1     4   74.40   306.60     True     True     False       True
# 7042    0    66  105.65  6844.50     True    False     False       True
#
#       2회선이상_No phone service  2회선이상_Yes  ...  스트리밍TV_Yes  \
# ...

# %% [markdown]
# - standard scaler를 이용해 스케일 맞추기

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()
scaled_df=ss.fit_transform(data2)
scaled_df=pd.DataFrame(scaled_df, index=data2.index, columns=data2.columns)
scaled_df
# Out:
#            고연령      가입기간       월요금      합산요금   성별_Male   배우자_Yes  피부양자_Yes  \
# 0    -0.439916 -1.277445 -1.160323 -0.992667 -1.009559  1.034530 -0.654012
# 1    -0.439916  0.066327 -0.259629 -0.172198  0.990532 -0.966622 -0.654012
# 2    -0.439916 -1.236724 -0.362660 -0.958122  0.990532 -0.966622 -0.654012
# 3    -0.439916  0.514251 -0.746535 -0.193706  0.990532 -0.966622 -0.654012
# 4    -0.439916 -1.236724  0.197365 -0.938930 -1.009559 -0.966622 -0.654012
# ...        ...       ...       ...       ...       ...       ...       ...
# 7038 -0.439916 -0.340876  0.665992 -0.127637  0.990532  1.034530  1.529024
# 7039 -0.439916  1.613701  1.277533  2.242641 -1.009559  1.034530  1.529024
# 7040 -0.439916 -0.870241 -1.168632 -0.852985 -1.009559  1.034530  1.529024
# 7041  2.273159 -1.155283  0.320338 -0.870566  0.990532  1.034530 -0.654012
# 7042 -0.439916  1.369379  1.358961  2.013925  0.990532 -0.966622 -0.654012
#
# ...

# %% [markdown]
# # K-means로 군집 분석

# %%
from sklearn.cluster import KMeans

# %%
# KMeans의 기본 n_clusters=8
km = KMeans(random_state=42)
km.fit(scaled_df)
result = km.labels_
result
# Out:
# array([0, 4, 4, ..., 0, 7, 3], shape=(7043,), dtype=int32)

# %%
data2['cluster8'] = result
data2
# Out:
#       고연령  가입기간     월요금     합산요금  성별_Male  배우자_Yes  피부양자_Yes  전화서비스_Yes  \
# 0       0     1   29.85    29.85    False     True     False      False
# 1       0    34   56.95  1889.50     True    False     False       True
# 2       0     2   53.85   108.15     True    False     False       True
# 3       0    45   42.30  1840.75     True    False     False      False
# 4       0     2   70.70   151.65    False    False     False       True
# ...   ...   ...     ...      ...      ...      ...       ...        ...
# 7038    0    24   84.80  1990.50     True     True      True       True
# 7039    0    72  103.20  7362.90    False     True      True       True
# 7040    0    11   29.60   346.45    False     True      True      False
# 7041    1     4   74.40   306.60     True     True     False       True
# 7042    0    66  105.65  6844.50     True    False     False       True
#
#       2회선이상_No phone service  2회선이상_Yes  ...  스트리밍Movies_No internet service  \
# ...

# %%
data2['cluster8'].value_counts()
# Out:
# cluster8
# 7    1200
# 4    1064
# 2     903
# 1     892
# 3     872
# 5     796
# 0     682
# 6     634
# Name: count, dtype: int64

# %%
data2[data2['cluster8'] == 7]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# True     898
# False    302
# Name: count, dtype: int64

# %%
data2[data2['cluster8'] == 7].describe(include='all')
# Out:
#                 고연령         가입기간          월요금         합산요금 성별_Male 배우자_Yes  \
# count   1200.000000  1200.000000  1200.000000  1200.000000    1200    1200
# unique          NaN          NaN          NaN          NaN       2       2
# top             NaN          NaN          NaN          NaN   False   False
# freq            NaN          NaN          NaN          NaN     640     928
# mean       0.249167     9.595833    77.868542   757.949750     NaN     NaN
# std        0.432711    10.024864    11.772280   796.248393     NaN     NaN
# min        0.000000     1.000000    42.900000    42.900000     NaN     NaN
# 25%        0.000000     2.000000    71.000000   144.112500     NaN     NaN
# 50%        0.000000     6.000000    79.050000   477.625000     NaN     NaN
# 75%        0.000000    14.000000    85.450000  1112.675000     NaN     NaN
# max        1.000000    56.000000   105.650000  4348.650000     NaN     NaN
#
#        피부양자_Yes 전화서비스_Yes 2회선이상_No phone service 2회선이상_Yes  ...  \
# ...

# %%
data2[data2['cluster8'] == 4]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    908
# True     156
# Name: count, dtype: int64

# %%
data2[data2['cluster8'] == 4].describe(include='all')
# Out:
#                 고연령         가입기간          월요금         합산요금 성별_Male 배우자_Yes  \
# count   1064.000000  1064.000000  1064.000000  1064.000000    1064    1064
# unique          NaN          NaN          NaN          NaN       2       2
# top             NaN          NaN          NaN          NaN    True   False
# freq            NaN          NaN          NaN          NaN     548     699
# mean       0.062970    18.122180    60.500987  1128.369502     NaN     NaN
# std        0.243023    15.712555    12.067968  1011.062861     NaN     NaN
# min        0.000000     0.000000    43.450000    43.800000     NaN     NaN
# 25%        0.000000     4.000000    50.450000   250.062500     NaN     NaN
# 50%        0.000000    14.000000    57.050000   866.425000     NaN     NaN
# 75%        0.000000    27.250000    69.412500  1794.950000     NaN     NaN
# max        1.000000    68.000000    96.800000  5135.350000     NaN     NaN
#
#        피부양자_Yes 전화서비스_Yes 2회선이상_No phone service 2회선이상_Yes  ...  \
# ...

# %%
data2[data2['cluster8'] == 4]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    908
# True     156
# Name: count, dtype: int64

# %%
data2[data2['cluster8'] == 4].describe(include='all')
# Out:
#                 고연령         가입기간          월요금         합산요금 성별_Male 배우자_Yes  \
# count   1064.000000  1064.000000  1064.000000  1064.000000    1064    1064
# unique          NaN          NaN          NaN          NaN       2       2
# top             NaN          NaN          NaN          NaN    True   False
# freq            NaN          NaN          NaN          NaN     548     699
# mean       0.062970    18.122180    60.500987  1128.369502     NaN     NaN
# std        0.243023    15.712555    12.067968  1011.062861     NaN     NaN
# min        0.000000     0.000000    43.450000    43.800000     NaN     NaN
# 25%        0.000000     4.000000    50.450000   250.062500     NaN     NaN
# 50%        0.000000    14.000000    57.050000   866.425000     NaN     NaN
# 75%        0.000000    27.250000    69.412500  1794.950000     NaN     NaN
# max        1.000000    68.000000    96.800000  5135.350000     NaN     NaN
#
#        피부양자_Yes 전화서비스_Yes 2회선이상_No phone service 2회선이상_Yes  ...  \
# ...

# %% [markdown]
# # 군집의 최적 개수 정하기
# - elbow method
# - 실루엣 지수
# - 군집분석 응집도 (요소들이 얼마나 모여있는지 판단하는 지표)
#     - 응집도가 높다(모여있다) == 분산이 작다
#     - 응집도가 낮다(흩어져있다) == 분산이 크다
#     - inertia_ 값이 작을 수록 군집이 잘 형성됨
# - elbow method: inertia_(응집도)를 출력하고 시각화 한 뒤 응집도의 감소폭이 급격한 변화가 시작되는 지즘을 최적 군집의 수로 채택

# %%
print(km.inertia_)
# Out:
# 100835.63093699011

# %% [markdown]
# # n_clusters를 1-20까지 변경하면서 inertia_ 출력 후 비교

# %%
inertia = []
for i in range(1,21):
    km = KMeans(n_clusters=i, random_state=42)
    km.fit(scaled_df)
    inertia.append(km.inertia_)
inertia
# Out:
# [218333.00000000012,
#  152479.0559937379,
#  135638.58526372534,
#  118049.58955068822,
#  111917.47124326255,
#  107077.31394401984,
#  104313.8350546055,
#  100835.63093699011,
#  98707.88612842462,
#  96791.35126700968,
#  94818.94918967718,
#  93377.42379563539,
#  91819.52450297753,
#  90440.10521805834,
#  89030.11191959867,
#  87958.18275215356,
#  87544.95178231726,
#  86602.96112714458,
#  85915.78316047114,
#  84283.8124154383]

# %%
import seaborn as sns

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=range(1,21), y=inertia, marker='o', markersize=10, markerfacecolor='red')
plt.show()

# %% [markdown]
# 꺾이는 게 완만해지는 지점 = elbow method -> 이 지점의 x축이 최적 개수임

# %%
# KMeans의 기본 n_clusters=8
km = KMeans(n_clusters=4, random_state=42)
km.fit(scaled_df)
result = km.labels_
result
# Out:
# array([0, 3, 3, ..., 0, 3, 2], shape=(7043,), dtype=int32)

# %%
data2['clusters4'] = result

# %%
data2
# Out:
#       고연령  가입기간     월요금     합산요금  성별_Male  배우자_Yes  피부양자_Yes  전화서비스_Yes  \
# 0       0     1   29.85    29.85    False     True     False      False
# 1       0    34   56.95  1889.50     True    False     False       True
# 2       0     2   53.85   108.15     True    False     False       True
# 3       0    45   42.30  1840.75     True    False     False      False
# 4       0     2   70.70   151.65    False    False     False       True
# ...   ...   ...     ...      ...      ...      ...       ...        ...
# 7038    0    24   84.80  1990.50     True     True      True       True
# 7039    0    72  103.20  7362.90    False     True      True       True
# 7040    0    11   29.60   346.45    False     True      True      False
# 7041    1     4   74.40   306.60     True     True     False       True
# 7042    0    66  105.65  6844.50     True    False     False       True
#
#       2회선이상_No phone service  2회선이상_Yes  ...  스트리밍Movies_Yes  약정옵션_One year  \
# ...

# %%
data2['clusters4'].value_counts()
# Out:
# clusters4
# 3    2721
# 2    2114
# 1    1526
# 0     682
# Name: count, dtype: int64

# %%
data2[data2['clusters4'] == 3]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    1393
# True     1328
# Name: count, dtype: int64

# %%
data2[data2['clusters4'] == 3].describe()
# Out:
#                고연령         가입기간          월요금         합산요금     cluster8  \
# count  2721.000000  2721.000000  2721.000000  2721.000000  2721.000000
# mean      0.220507    15.499816    74.284730  1180.387174     4.980154
# std       0.414665    14.200045    16.554106  1125.662769     1.939804
# min       0.000000     0.000000    42.900000    42.900000     2.000000
# 25%       0.000000     3.000000    59.900000   237.950000     4.000000
# 50%       0.000000    11.000000    75.350000   831.750000     4.000000
# 75%       0.000000    24.000000    86.550000  1836.250000     7.000000
# max       1.000000    68.000000   112.950000  5617.750000     7.000000
#
#        clusters4
# count     2721.0
# mean         3.0
# std          0.0
# min          3.0
# 25%          3.0
# 50%          3.0
# 75%          3.0
# max          3.0

# %%
data2[data2['clusters4'] == 2]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    1856
# True      258
# Name: count, dtype: int64

# %%
data2[data2['clusters4'] == 2].describe()
# Out:
#                고연령         가입기간          월요금         합산요금     cluster8  \
# count  2114.000000  2114.000000  2114.000000  2114.000000  2114.000000
# mean      0.182592    55.607852    91.370624  5115.005416     3.551088
# std       0.386423    14.963845    15.788377  1733.295655     1.152167
# min       0.000000     0.000000    49.400000    73.350000     2.000000
# 25%       0.000000    46.000000    79.712500  3872.412500     3.000000
# 50%       0.000000    59.000000    94.100000  5180.650000     3.000000
# 75%       0.000000    68.750000   104.650000  6413.050000     5.000000
# max       1.000000    72.000000   118.750000  8684.800000     5.000000
#
#        clusters4
# count     2114.0
# mean         2.0
# std          0.0
# min          2.0
# 25%          2.0
# 50%          2.0
# 75%          2.0
# max          2.0

# %% [markdown]
# # 실루엣 지수를 출력해서 최적 군집 개수 구하기
# - 실루엣 지수를 구하기 위해서는 최소 2개 이상의 군집이 필요
# - 실루엣 지수가 가장 높은 클러스터 개수가 최적 군집 개수 (1에 가까울 수록 좋음)

# %%
from sklearn.metrics import silhouette_score

# %%
sil_scores=[]
for i in range(2,21): # 실루엣은 2개 이상 필요하므로
    km2 = KMeans(n_clusters=i, random_state=42)
    km2.fit(scaled_df)
    labels = km2.labels_
    sil_scores.append(silhouette_score(scaled_df, labels))
sil_scores
# Out:
# [0.3258652454879743,
#  0.2804452435608257,
#  0.23576171079139827,
#  0.19947667968860916,
#  0.1942023354192859,
#  0.18517954103705075,
#  0.12867767199413246,
#  0.13004252885995762,
#  0.12654262815135567,
#  0.12268535473727389,
#  0.11438673001870003,
#  0.11548534988018003,
#  0.11077706954479337,
#  0.10892533061526664,
#  0.10991577445040265,
#  0.10684398657257481,
#  0.1084841823266845,
#  0.10812881050046247,
#  0.10587131128596497]

# %%
plt.figure(figsize=(20,10))
sns.lineplot(x=range(2, 21), y=sil_scores, marker='o', markersize=10, markerfacecolor='red')
plt.show()

# %%
# KMeans의 기본 n_clusters=8
km2 = KMeans(n_clusters=2, random_state=42)
km2.fit(scaled_df)
result = km2.labels_
result
# Out:
# array([0, 0, 0, ..., 0, 0, 0], shape=(7043,), dtype=int32)

# %%
data2['clusters2'] = result
data2
# Out:
#       고연령  가입기간     월요금     합산요금  성별_Male  배우자_Yes  피부양자_Yes  전화서비스_Yes  \
# 0       0     1   29.85    29.85    False     True     False      False
# 1       0    34   56.95  1889.50     True    False     False       True
# 2       0     2   53.85   108.15     True    False     False       True
# 3       0    45   42.30  1840.75     True    False     False      False
# 4       0     2   70.70   151.65    False    False     False       True
# ...   ...   ...     ...      ...      ...      ...       ...        ...
# 7038    0    24   84.80  1990.50     True     True      True       True
# 7039    0    72  103.20  7362.90    False     True      True       True
# 7040    0    11   29.60   346.45    False     True      True      False
# 7041    1     4   74.40   306.60     True     True     False       True
# 7042    0    66  105.65  6844.50     True    False     False       True
#
#       2회선이상_No phone service  2회선이상_Yes  ...  약정옵션_One year  약정옵션_Two year  \
# ...

# %%
data2[data2['clusters2'] == 0].describe()
# Out:
#                고연령         가입기간          월요금         합산요금     cluster8  \
# count  5517.000000  5517.000000  5517.000000  5517.000000  5517.000000
# mean      0.197571    32.875657    76.844254  2727.090538     3.816929
# std       0.398203    24.593647    21.924661  2355.978174     2.204514
# min       0.000000     0.000000    23.450000    23.450000     0.000000
# 25%       0.000000     9.000000    59.950000   583.000000     2.000000
# 50%       0.000000    30.000000    79.450000  2135.500000     4.000000
# 75%       0.000000    56.000000    94.450000  4527.450000     5.000000
# max       1.000000    72.000000   118.750000  8684.800000     7.000000
#
#          clusters4  clusters2
# count  5517.000000     5517.0
# mean      2.245967        0.0
# std       0.962986        0.0
# min       0.000000        0.0
# 25%       2.000000        0.0
# 50%       2.000000        0.0
# 75%       3.000000        0.0
# max       3.000000        0.0

# %%
data2[data2['clusters2'] == 1].describe()
# Out:
#                고연령         가입기간          월요금         합산요금     cluster8  \
# count  1526.000000  1526.000000  1526.000000  1526.000000  1526.000000
# mean      0.034076    30.547182    21.079194   662.690564     3.077326
# std       0.181484    24.356507     2.164221   555.527036     2.464818
# min       0.000000     0.000000    18.250000    18.800000     1.000000
# 25%       0.000000     8.000000    19.700000   157.825000     1.000000
# 50%       0.000000    25.000000    20.150000   519.200000     1.000000
# 75%       0.000000    52.750000    20.900000  1108.650000     6.000000
# max       1.000000    72.000000    26.900000  2006.950000     6.000000
#
#        clusters4  clusters2
# count     1526.0     1526.0
# mean         1.0        1.0
# std          0.0        0.0
# min          1.0        1.0
# 25%          1.0        1.0
# 50%          1.0        1.0
# 75%          1.0        1.0
# max          1.0        1.0

# %%
data2[data2['clusters2'] == 0]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    3761
# True     1756
# Name: count, dtype: int64

# %%
data2[data2['clusters2'] == 1]['이탈여부_Yes'].value_counts()
# Out:
# 이탈여부_Yes
# False    1413
# True      113
# Name: count, dtype: int64
