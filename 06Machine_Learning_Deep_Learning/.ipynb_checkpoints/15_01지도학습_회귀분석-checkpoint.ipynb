# %% [markdown]
# # 지도학습_회귀분석
# - 지도학습
# * 종속변수(target) 변수가 수치형 자료
# * 집값, 보험료, 몸무게 과 같이 연속적인 숫자로 이루어진 값을 예측
# * 회귀? => 평균으로 돌아간다.
#
# # 단순 선형 회귀분석 / 다중 선형 회귀분석
# * 단순 선형 회귀분석: 독립변수1, 종속변수1
# * 다중 선형 회귀분석: 독립변수n, 종속변수1

# %%
! pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\a\miniforge3\envs\fintech\lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from statsmodels) (2.2.6)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from statsmodels) (2.3.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\a\miniforge3\envs\fintech\lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
