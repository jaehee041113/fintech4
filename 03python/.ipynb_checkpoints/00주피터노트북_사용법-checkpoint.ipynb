# %% [markdown]
# # 주피터 노트북 사용법 \<h1>
# * 하위목록 1 \<ul> \<li>
#   * 하위목록2
# ## 주피터 노트북 사용법 \<h2>
# ### 주피터 노트북 사용법 \<h3>
# #### 주피터 노트북 사용법 \<h4>

# %%
3+5
# Out:
# 8

# %%
a+b
# Out:
# 30

# %%
b=20

# %%
a=10

# %%
print(globals())
# Out:
# {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'a+b', 'b=20', 'a=10', 'a+b', 'print(globals()', 'print(globals()', 'print(globals())'], '_oh': {4: 30}, '_dh': [WindowsPath('c:/fintech04/03python')], 'In': ['', 'a+b', 'b=20', 'a=10', 'a+b', 'print(globals()', 'print(globals()', 'print(globals())'], 'Out': {4: 30}, 'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x000002392079D660>>, 'exit': <IPython.core.autocall.ZMQExitAutocall object at 0x000002392079E110>, 'quit': <IPython.core.autocall.ZMQExitAutocall object at 0x000002392079E110>, 'open': <function open at 0x000002391F12CD30>, '_': 30, '__': '', '___': '', '_i': 'print(globals()', '_ii': 'print(globals()', '_iii': 'a+b', '_i1': 'a+b', '_i2': 'b=20',
# ...

# %% [markdown]
# # jupyter notebook 마크다운 문법

# %% [markdown]
# ## 제목
#   * 제목은 #의 개수에 따라 제목 크기가 달라진다

# %% [markdown]
# # 제목1
# ## 제목2
# ### 제목3

# %% [markdown]
# ## 문단, 줄바꿈

# %% [markdown]
# ### 문단
#   * 한 줄을 비우면 새로운 문단이 된다

# %% [markdown]
# 이것은 첫 번째 문단이다.
#
# 이것은 두 번째 문단이다.

# %% [markdown]
# ### 줄바꿈
#   * 문장 끝에 공백 2칸을 넣고 enter
#   * 문장 끝에 <br> 태그 넣기

# %% [markdown]
# 첫 줄입니다.
# 두 번째 줄입니다.

# %% [markdown]
# ## 강조
#   * 굵게 : 양쪽에 **
#   * 기울임 : *
#   * 굵고 기울임 : ***

# %% [markdown]
# **굵은글씨**

# %% [markdown]
# ## 목록
#
#   * 순서 없는 목록 : - , *
#   * 순서 있는 목록 : 1,2,3... 숫자

# %% [markdown]
# - 사과
# - 바나나

# %% [markdown]
# 1. 데이터 수집
# 2. 데이터 전처리
# 3. 모델 학습
# 4. 결과 분석

# %% [markdown]
# ## 중첩 목록
#   - 들여쓰기

# %% [markdown]
# ## 코드

# %% [markdown]
# ### 인라인 코드
# * 문장 중간에 코드를 표시할 때는 백틱 1개를 사용
# * 변수는 `x = 10` 처럼 정의한다.
# * (백틱 : 키보드 1 옆에 있음)

# %% [markdown]
# ### 코드 블록
# - 여러 줄 코드를 표시할 때는 백틱 3개를 사용
# - 언어 이름을 쓰면 문법 강조가 적용

# %% [markdown]
# ```python
# for i in range(5):
#     print(i)
# ```

# %% [markdown]
# ## 인용문 : >

# %% [markdown]
# > 데이터 분석에서 가장 중요한 것은 질문이다.

# %% [markdown]
# ## 구분선 : ---

# %% [markdown]
# ## 링크
# - [텍스트](URL) 형식

# %% [markdown]
# [구글 바로가기](https://www.google.com)

# %% [markdown]
# ## 이미지 넣기
# - ![대체텍스트](이미지경로) 형식

# %% [markdown]
# ! [토끼이미지예시](https://share.google/g1HpLYneDoofRPaDJ)

# %% [markdown]
# - 이미지 다운로드 후에 끌어와도 됨

# %% [markdown]
# ## 표 만들기
# - 표는 |로 칸을 나누고, 헤더 아래에 구분선을 넣는다.

# %% [markdown]
# | 이름 | 나이 | 전공 |
# |---|---|---|
# | 철수 | 20 | 컴퓨터 |
# | 영희 | 21 | 수학 |

# %% [markdown]
# - 정렬 방법 : 표 중간에 두 번째 행 넣으면 됨
#
# | 왼쪽 정렬 | 가운데 정렬 | 오른쪽 정렬 |
# |:---|:---:|---:|
# | A | B | C |

# %% [markdown]
# ## 체크박스
# - 체크박스는 - [ ], 체크 완료는 - [x]

# %% [markdown]
# - [x] 데이터 수집
# - [ ] 전처리
# - [ ] 모델 학습

# %% [markdown]
# ## 수식(LaTeX)
# - 라텍스 검색해보면 수식 많음

# %% [markdown]
# ### 인라인 수식
# `$y = ax + b$`
#
# $y = ax + b$

# %% [markdown]
# ### 블록 수식
# ```$$
# \sum_{i=1}^{n} x_i
# $$ ```
#
# $$
# \sum_{i=1}^{n} x_i
# $$
