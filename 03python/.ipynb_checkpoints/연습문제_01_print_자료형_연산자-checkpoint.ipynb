# %%
print(100)
# Out:
# 100

# %%
print('"Hello Python"')
# Out:
# "Hello Python"

# %%
print(10,20)
# Out:
# 10 20

# %%
print(10,20,30,sep='')
# Out:
# 102030

# %%
print(10,20,30,sep='-')
# Out:
# 10-20-30

# %%
print("Hello", end=" ")
print("Python")
# Out:
# Hello Python

# %%
print("3+5=",3+5)
# Out:
# 3+5= 8

# %%
print(20//3)
# Out:
# 6

# %%
print(20%3)
# Out:
# 2

# %%
print('apple','banana','cherry',sep='-')
# Out:
# apple-banana-cherry

# %%
print("Hello",end='')
print("World")
# Out:
# HelloWorld

# %%
a=10
b=20
print("a+b:", a+b)
# Out:
# a+b: 30

# %%
print(100//3)
# Out:
# 33

# %%
print(1,2,3,4,5,sep=' ')
# Out:
# 1 2 3 4 5

# %%
print("Python"*3)
# Out:
# PythonPythonPython

# %%
print("Hello", end=' ')
print("world")
# Out:
# Hello world

# %%
b=3.14
b
# Out:
# 3.14

# %%
type(b)
# Out:
# float

# %%
print(type(b))
# Out:
# <class 'float'>

# %%
a="Python"
a[0]
# Out:
# 'P'

# %%
"Python"[0]
# Out:
# 'P'

# %%
"Python Programming"[7:19]
# Out:
# 'Programming'

# %%
print("Python Programming"[7:19])
# Out:
# Programming

# %%
"Python"*3
# Out:
# 'PythonPythonPython'

# %%
print("python"*3)
# Out:
# pythonpythonpython

# %%
numbers = [1, 2, 3, 4, 5] #리스트
print(numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
numbers[0]
# Out:
# 1

# %%
numbers[-1]
# Out:
# 5

# %%
len(numbers)
# Out:
# 5

# %%
numbers.append(6)
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6, 6]

# %%
nested_list = [[1, 2, 3], [4, 5, 6], [7, 8, 9]] #중첩리스트
nested_list
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
nested_list[2][2]
# Out:
# 9

# %%
nested_tuple = ((1, 2), (3, 4, 5), (6, 7, 8, 9)) #중첩튜플
nested_tuple
# Out:
# ((1, 2), (3, 4, 5), (6, 7, 8, 9))

# %%
nested_tuple[1][1]
# Out:
# 4

# %%
person = {"name": "Alice",
          "info": {"age": 25, "city": "Seoul"}} #딕셔너리 {키:밸류}
person
# Out:
# {'name': 'Alice', 'info': {'age': 25, 'city': 'Seoul'}}

# %%
person['info']['age']
#딕셔너리에는 숫자 인덱스 없음! 키값으로 밸류 불러오기
# Out:
# 25

# %%
data={'info': [{'name': 'Alice', 'scores': (95, 88, 92)},
  {'name': 'Bob', 'scores': (78, 85, 89)}],
 'extra': {'hobbies': ['reading', 'coding'], 'location': ('Seoul', 'Busan')}}
data
# Out:
# {'info': [{'name': 'Alice', 'scores': (95, 88, 92)},
#   {'name': 'Bob', 'scores': (78, 85, 89)}],
#  'extra': {'hobbies': ['reading', 'coding'], 'location': ('Seoul', 'Busan')}}

# %%
data['info'][0]['scores'][0]
# Out:
# 95

# %%
data['info'][0]
# Out:
# {'name': 'Alice', 'scores': (95, 88, 92)}

# %%
data['info'][0]['scores'][0]
# Out:
# 95

# %%
data['info'][1]['scores'][2]
# Out:
# 89

# %%
data['extra']
# Out:
# {'hobbies': ['reading', 'coding'], 'location': ('Seoul', 'Busan')}

# %%
data['extra']['hobbies']
# Out:
# ['reading', 'coding']

# %%
data['extra']['hobbies'][1]
# Out:
# 'coding'

# %%
data['extra']['location'][1]
# Out:
# 'Busan'

# %%
list(data['info'][0]['scores'])
# Out:
# [95, 88, 92]
