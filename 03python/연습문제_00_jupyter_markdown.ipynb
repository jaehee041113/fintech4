# %% [markdown]
# # 내 첫 번째 노트북

# %% [markdown]
# ## 실습 목표

# %% [markdown]
# 데이터 분석은 질문에서 시작한다.
#
# 좋은 질문이 좋은 결과를 만든다.

# %% [markdown]
# 첫 줄
# 둘째 줄

# %% [markdown]
# **중요**

# %% [markdown]
# *주의*

# %% [markdown]
# ***핵심***

# %% [markdown]
# 변수는 `x = 10` 으로 만든다.

# %% [markdown]
# - 사과
# - 바나나
# - 포도

# %% [markdown]
# 1. 수집
# 2. 정제
# 3. 학습

# %% [markdown]
# - 과일
#     -사과
#     -바나나

# %% [markdown]
# > 측정할 수 없으면 개선할 수 없다.

# %% [markdown]
# 첫 문단이다.
#
# ---
#
# 둘째 문단이다.

# %% [markdown]
# [OpenAI](https://www.openai.com)
#
# [텍스트](URL) 형식

# %% [markdown]
# 형식 : ![대체텍스트](경로)
#
# ![sample](images/sample.png)

# %% [markdown]
# | 이름 | 나이 |
# |---|---|
# | 철수 | 20 |
# | 영희 | 21 |

# %% [markdown]
# | 왼쪽정렬 | 가운데정렬 | 오른쪽정렬 |
# |:---|:---:|---:|
# | 1 | 2 | 3 |

# %% [markdown]
# - [x] 환경 설정
# - [ ] 데이터 로드
# - [ ] 시각화

# %% [markdown]
# - 파이썬 코드블록 만들기 : ```python
#
# ```python
# print("hello")
# ```

# %% [markdown]
# - sql 코드블록 만들기 : ```sql
#
# ```sql
# SELECT * FROM film LIMIT 5;
# ```

# %% [markdown]
# - 인라인 수식 : $
#
# 직선은 $y = ax + b$ 로 표현한다.

# %% [markdown]
# - 블록 수식 : $$
#
# $$
# \sum_{i=1}^{n} x_i
# $$

# %% [markdown]
# ## 오늘 할 일
# - 노트북 정리
# - 실습
# - 복습

# %% [markdown]
# ### 진행상황
# - [x] 데이터 수집
# - [x] 전처리
# - [ ] 모델 학습

# %% [markdown]
# - 컬럼: 항목(왼쪽), 값(오른쪽)
# - 행: 정확도 0.93, 손실 0.12
#
# 정렬은 2번째 열을 ---:로 지정한다
#
# | 항목 | 값 |
# |:---|---:|
# | 정확도 | 0.93 |
# | 손실 | 0.12 |

# %% [markdown]
# # 데이터 분석 보고서
#
# ## 1. 문제 정의
# 분석 목적을 한 줄로 적는다.
#
# ## 2. 데이터
# 데이터 출처와 범위를 한 줄로 적는다.

# %% [markdown]
# ```python
# nums = [1, 2, 3]
# sum(nums)
# ```

# %% [markdown]
# - 아래 요구사항을 모두 만족하는 마크다운을 작성하라.
#
# 제목 2: “요약”
# 인용문: “결과는 재현 가능해야 한다.”
# 체크박스 2개: (첫 번째 완료) “데이터 저장”, “리포트 작성”
# 구분선 1개
# 마지막 줄에 인라인 수식 E = mc^2를 포함한 문장
# 힌트
# ##, >, - [x], ---, $...$를 모두 사용한다.
#
#
# ## 요약
#
# > 결과는 재현 가능해야 한다.
#
# - [x] 데이터 저장
# - [ ] 리포트 작성
#
# ---
#
# 마지막으로 $E = mc^2$ 를 확인한다.
